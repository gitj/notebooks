# %%
matplotlib.rcParams['lines.linewidth']=2

# %%
import kid_readout.utils.readoutnc

# %%
#rnc = kid_readout.utils.readoutnc.ReadoutNetCDF('/home/data2/2014-04-22_173927.nc')
rnc = kid_readout.utils.readoutnc.ReadoutNetCDF('/home/data2/2014-06-18_141314_test_120_seconds.nc')
#rnc = kid_readout.utils.readoutnc.ReadoutNetCDF('/home/data/2014-02-01_011449.nc')

# %%
rnc.timestream_20140201012250.epoch - rnc.timestream_20140201012250.epoch[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-233160d89406> in <module>()
# ----> 1 rnc.timestream_20140201012250.epoch - rnc.timestream_20140201012250.epoch[0]
#
# AttributeError: 'ReadoutNetCDF' object has no attribute 'timestream_20140201012250'

# %%
ts0 = rnc.timestreams[0].get_data_index(2)

# %%
ts1 = rnc.timestreams[0].get_data_index(1)

# %%
ts0 = ts0 - ts0.mean()

# %%
ts1 = ts1 - ts1.mean()

# %%
pxy,fr = mlab.csd(ts0,ts1,NFFT=2**20,Fs=256e6/2.**11)
pxx,fr = mlab.psd(ts0,NFFT=2**20,Fs=256e6/2.**11)
pyy,fr = mlab.psd(ts1,NFFT=2**20,Fs=256e6/2.**11)

# %%
pxy.shape
# Out:
# (1048576,)

# %%
plot(fr,abs(pxy/pxx))
plot(fr,abs(pxx))
xscale('symlog')
yscale('log')

# %%
plot(fr,abs(pxy)**2/(pxx*pyy)-1)
xscale('symlog')
#yscale('log')
#ylim(0.5,2)

# %%
ts0.shape
# Out:
# (16777216,)

# %%
plot(pxx/pyy)
xscale('symlog')

# %%
plot(np.unwrap(np.angle(pxy)),'.-')
xscale('symlog')
ylim(-10,10)
# Out:
# (-10, 10)

# %%
loglog(fr[2**18/2:2**18/2+1000],np.abs(pxx/pxy)[2**18/2:2**18/2+1000])
ylim(1,10)
#xscale('symlog')
#yscale('log')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-192b902c1f1d> in <module>()
# ----> 1 loglog(fr[2**18/2:2**18/2+1000],np.abs(pxx/pxy)[2**18/2:2**18/2+1000])
#       2 ylim(1,10)
#       3 #xscale('symlog')
#       4 #yscale('log')
#
# /home/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in loglog(*args, **kwargs)
#    2908         ax.hold(hold)
#    2909     try:
# -> 2910         ret = ax.loglog(*args, **kwargs)
#    2911         draw_if_interactive()
#    2912     finally:
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in loglog(self, *args, **kwargs)
#    4271         b = self._hold
#    4272         self._hold = True  # we've already processed the hold
# -> 4273         l = self.plot(*args, **kwargs)
#    4274         self._hold = b  # restore the hold
#    4275
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    4139             lines.append(line)
#    4140
# -> 4141         self.autoscale_view(scalex=scalex, scaley=scaley)
#    4142         return lines
#    4143
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in autoscale_view(self, tight, scalex, scaley)
#    1942                 x1 += delta
#    1943             if not _tight:
# -> 1944                 x0, x1 = xlocator.view_limits(x0, x1)
#    1945             self.set_xbound(x0, x1)
#    1946
#
# /home/local/lib/python2.7/site-packages/matplotlib/ticker.pyc in view_limits(self, vmin, vmax)
#    1483         if minpos <= 0 or not np.isfinite(minpos):
#    1484             raise ValueError(
# -> 1485                 "Data has no positive values, and therefore can not be "
#    1486                 "log-scaled.")
#    1487
#
# ValueError: Data has no positive values, and therefore can not be log-scaled.

# %%
pxx.shape

# %%
pxy.shape
# Out:
# (1048576,)

# %%
plot(abs(pxy))

# %%
cxy,fr = mlab.psd(ts0-ts1,NFFT=2**18,Fs=256e6/2.**11)

# %%
loglog(fr,cxy)
loglog(fr,pxx)
loglog(fr,pyy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-d6bb40455edd> in <module>()
#       1 loglog(fr,cxy)
# ----> 2 loglog(fr,pxx)
#       3 loglog(fr,pyy)
#
# /home/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in loglog(*args, **kwargs)
#    2908         ax.hold(hold)
#    2909     try:
# -> 2910         ret = ax.loglog(*args, **kwargs)
#    2911         draw_if_interactive()
#    2912     finally:
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in loglog(self, *args, **kwargs)
#    4271         b = self._hold
#    4272         self._hold = True  # we've already processed the hold
# -> 4273         l = self.plot(*args, **kwargs)
#    4274         self._hold = b  # restore the hold
#    4275
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    4135         lines = []
#    4136
# -> 4137         for line in self._get_lines(*args, **kwargs):
#    4138             self.add_line(line)
#    4139             lines.append(line)
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in _grab_next_args(self, *args, **kwargs)
#     315                 return
#     316             if len(remaining) <= 3:
# --> 317                 for seg in self._plot_args(remaining, kwargs):
#     318                     yield seg
#     319                 return
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in _plot_args(self, tup, kwargs)
#     293             x = np.arange(y.shape[0], dtype=float)
#     294
# --> 295         x, y = self._xy_from_xy(x, y)
#     296
#     297         if self.command == 'plot':
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in _xy_from_xy(self, x, y)
#     235         y = np.atleast_1d(y)
#     236         if x.shape[0] != y.shape[0]:
# --> 237             raise ValueError("x and y must have same first dimension")
#     238         if x.ndim > 2 or y.ndim > 2:
#     239             raise ValueError("x and y can be no greater than 2-D")
#
# ValueError: x and y must have same first dimension

# %%
from sklearn.decomposition import FastICA

# %%
ica = FastICA()

# %%
S = ica.fit(np.vstack((ts0,ts1)).T.real).transform(np.vstack((ts0,ts1)).T.real)

# %%
ica.mixing_
# Out:
# array([[ 1.01775992, -0.66098356],
#        [ 0.72654855,  1.20806432]], dtype=float32)

# %%
S.shape
# Out:
# (16777216, 2)

# %%
plot(S[:1000,:])
# Out:
# [<matplotlib.lines.Line2D at 0x85f5e90>,
#  <matplotlib.lines.Line2D at 0x85f54d0>]

# %%
plot(np.vstack((ts0,ts1)).T.real[:1000,:])
# Out:
# [<matplotlib.lines.Line2D at 0x29eb68d0>,
#  <matplotlib.lines.Line2D at 0x29eb6c50>]

# %%
blah = psd(S[:,0],NFFT=2**18)
blah = psd(S[:,1],NFFT=2**18)
xscale('log')

# %%
blah = hist(abs(ts0),log=True,bins=100)
blah = hist(abs(ts1),log=True,bins=100)

# %%
plot(abs(ts0),abs(ts1),'.')

# %%
loglog(fr,pxx-abs(pxy)**2/pyy)
loglog(fr,pyy-abs(pxy)**2/pxx)
#loglog(fr,pxx-pyy)
loglog(fr,abs(pxy)**2/pxx)
loglog(fr,pyy)
ylim(1e-12,1e-7)
#ylim(5e-13,1e-11)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-b8a76eb75506> in <module>()
# ----> 1 loglog(fr,pxx-abs(pxy)**2/pyy)
#       2 loglog(fr,pyy-abs(pxy)**2/pxx)
#       3 #loglog(fr,pxx-pyy)
#       4 loglog(fr,abs(pxy)**2/pxx)
#       5 loglog(fr,pyy)
#
# /home/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in loglog(*args, **kwargs)
#    2908         ax.hold(hold)
#    2909     try:
# -> 2910         ret = ax.loglog(*args, **kwargs)
#    2911         draw_if_interactive()
#    2912     finally:
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in loglog(self, *args, **kwargs)
#    4271         b = self._hold
#    4272         self._hold = True  # we've already processed the hold
# -> 4273         l = self.plot(*args, **kwargs)
#    4274         self._hold = b  # restore the hold
#    4275
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    4135         lines = []
#    4136
# -> 4137         for line in self._get_lines(*args, **kwargs):
#    4138             self.add_line(line)
#    4139             lines.append(line)
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in _grab_next_args(self, *args, **kwargs)
#     315                 return
#     316             if len(remaining) <= 3:
# --> 317                 for seg in self._plot_args(remaining, kwargs):
#     318                     yield seg
#     319                 return
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in _plot_args(self, tup, kwargs)
#     293             x = np.arange(y.shape[0], dtype=float)
#     294
# --> 295         x, y = self._xy_from_xy(x, y)
#     296
#     297         if self.command == 'plot':
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in _xy_from_xy(self, x, y)
#     235         y = np.atleast_1d(y)
#     236         if x.shape[0] != y.shape[0]:
# --> 237             raise ValueError("x and y must have same first dimension")
#     238         if x.ndim > 2 or y.ndim > 2:
#     239             raise ValueError("x and y can be no greater than 2-D")
#
# ValueError: x and y must have same first dimension

# %%
loglog(fr,pxx-abs(pxy)**2/pyy)
loglog(fr,pyy-abs(pxy)**2/pxx)
#loglog(fr,pxx-pyy)
#loglog(fr,abs(pxy)**2/pxx)
#loglog(fr,pyy)
#ylim(1e-12,1e-7)
#ylim(5e-13,1e-11)
grid()

# %%
loglog(fr,abs(pxy)**2/pxx,lw=1)
loglog(fr,abs(pxy)**2/pyy,lw=1)
ylim(1e-14,1e-7)

# %%
import kid_readout.analysis.iqnoise

# %%
frl = kid_readout.analysis.iqnoise.make_freq_bins(fr)

# %%
fr.shape

# %%
(fr[1]-fr[0])*100

# %%
blah = hist(np.diff(frl),bins=100,log=True)

# %%
frl.shape
# Out:
# (131219,)

# %%
semilogy(np.diff(frl))

# %%
fr[:10]
# Out:
# array([-62500.        , -62499.52316284, -62499.04632568, -62498.56948853,
#        -62498.09265137, -62497.61581421, -62497.13897705, -62496.66213989,
#        -62496.18530273, -62495.70846558])

# %%
frl,plx = kid_readout.analysis.iqnoise.log_bin(fr[2**19:],(pxx-abs(pxy)**2/pyy)[2**19:])
frl,ply = kid_readout.analysis.iqnoise.log_bin(fr[2**19:],(pyy-abs(pxy)**2/pxx)[2**19:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-9d5c7a441bd3> in <module>()
# ----> 1 frl,plx = kid_readout.analysis.iqnoise.log_bin(fr[2**19:],(pxx-abs(pxy)**2/pyy)[2**19:])
#       2 frl,ply = kid_readout.analysis.iqnoise.log_bin(fr[2**19:],(pyy-abs(pxy)**2/pxx)[2**19:])
#
# /home/gjones/kid_readout/kid_readout/analysis/iqnoise.pyc in log_bin(freqs, data)
#      35
#      36 def log_bin(freqs,data):
# ---> 37     freq_bins = make_freq_bins(freqs)
#      38     bin_idxs = np.digitize(freqs,freq_bins)
#      39     if type(data) is list:
#
# /home/gjones/kid_readout/kid_readout/analysis/iqnoise.pyc in make_freq_bins(fr)
#       5 def make_freq_bins(fr):
#       6     scale = 2
# ----> 7     fmax = fr.max()
#       8     fout = []
#       9     fdiff = fr[1]-fr[0]
#
# /home/local/lib/python2.7/site-packages/numpy/core/_methods.pyc in _amax(a, axis, out, keepdims)
#      24 # small reductions
#      25 def _amax(a, axis=None, out=None, keepdims=False):
# ---> 26     return umr_maximum(a, axis, None, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
loglog(frl,plx)
loglog(frl,ply)
grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-93dc176b2c01> in <module>()
# ----> 1 loglog(frl,plx)
#       2 loglog(frl,ply)
#       3 grid()
#
# NameError: name 'plx' is not defined

# %%
loglog(fr,abs(pxy)**2/pxx)
#ylim(5e-13,1e-11)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-cac789127c9b> in <module>()
# ----> 1 loglog(fr,abs(pxy)**2/pxx)
#       2 #ylim(5e-13,1e-11)
#
# /home/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in loglog(*args, **kwargs)
#    2908         ax.hold(hold)
#    2909     try:
# -> 2910         ret = ax.loglog(*args, **kwargs)
#    2911         draw_if_interactive()
#    2912     finally:
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in loglog(self, *args, **kwargs)
#    4271         b = self._hold
#    4272         self._hold = True  # we've already processed the hold
# -> 4273         l = self.plot(*args, **kwargs)
#    4274         self._hold = b  # restore the hold
#    4275
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    4135         lines = []
#    4136
# -> 4137         for line in self._get_lines(*args, **kwargs):
#    4138             self.add_line(line)
#    4139             lines.append(line)
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in _grab_next_args(self, *args, **kwargs)
#     315                 return
#     316             if len(remaining) <= 3:
# --> 317                 for seg in self._plot_args(remaining, kwargs):
#     318                     yield seg
#     319                 return
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in _plot_args(self, tup, kwargs)
#     293             x = np.arange(y.shape[0], dtype=float)
#     294
# --> 295         x, y = self._xy_from_xy(x, y)
#     296
#     297         if self.command == 'plot':
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in _xy_from_xy(self, x, y)
#     235         y = np.atleast_1d(y)
#     236         if x.shape[0] != y.shape[0]:
# --> 237             raise ValueError("x and y must have same first dimension")
#     238         if x.ndim > 2 or y.ndim > 2:
#     239             raise ValueError("x and y can be no greater than 2-D")
#
# ValueError: x and y must have same first dimension

# %%
loglog(fr,pxx)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-65a05daf1626> in <module>()
# ----> 1 loglog(fr,pxx)
#
# /home/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in loglog(*args, **kwargs)
#    2908         ax.hold(hold)
#    2909     try:
# -> 2910         ret = ax.loglog(*args, **kwargs)
#    2911         draw_if_interactive()
#    2912     finally:
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in loglog(self, *args, **kwargs)
#    4271         b = self._hold
#    4272         self._hold = True  # we've already processed the hold
# -> 4273         l = self.plot(*args, **kwargs)
#    4274         self._hold = b  # restore the hold
#    4275
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    4135         lines = []
#    4136
# -> 4137         for line in self._get_lines(*args, **kwargs):
#    4138             self.add_line(line)
#    4139             lines.append(line)
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in _grab_next_args(self, *args, **kwargs)
#     315                 return
#     316             if len(remaining) <= 3:
# --> 317                 for seg in self._plot_args(remaining, kwargs):
#     318                     yield seg
#     319                 return
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in _plot_args(self, tup, kwargs)
#     293             x = np.arange(y.shape[0], dtype=float)
#     294
# --> 295         x, y = self._xy_from_xy(x, y)
#     296
#     297         if self.command == 'plot':
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in _xy_from_xy(self, x, y)
#     235         y = np.atleast_1d(y)
#     236         if x.shape[0] != y.shape[0]:
# --> 237             raise ValueError("x and y must have same first dimension")
#     238         if x.ndim > 2 or y.ndim > 2:
#     239             raise ValueError("x and y can be no greater than 2-D")
#
# ValueError: x and y must have same first dimension

# %%
rnc2 = kid_readout.utils.readoutnc.ReadoutNetCDF('/home/data/2014-02-01_011449.nc')

# %%
d = rnc2.timestream_20140201012250.get_data_index(0)

# %%
d.shape
# Out:
# (67108864,)
