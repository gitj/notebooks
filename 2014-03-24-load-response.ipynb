# %%
matplotlib.rcParams['font.size']=16

# %%
import kid_readout.utils.parse_srs

# %%
dt,d = kid_readout.utils.parse_srs.get_load_log('/home/heather/SRS/20140331-085747.txt')

# %%
plot(dt[-1000:],d[-1000:,-4])

# %%
d[-1,-4]
# Out:
# 20.66

# %%
figure()
since = -2000
plot(dt[since:],d[since:,1])
figure()
plot(dt[since:],d[since:,2])
figure()
plot(dt[since:],d[since:,-4])

# %%
d.shape
plot(d[2500:3000,-4],d[2500:3000,-1])
xlim(1.5,1.65)
# Out:
# (1.5, 1.65)

# %%
plot(d[23500:,-1])

# %%
fig = plt.figure(figsize=(8,8))
ax= fig.add_subplot(211)
plot(d[msk,0]-tstart,d[msk,1],label='Absorber',lw=2)
ax.grid()
ax.legend(loc='lower right')
ax.set_ylabel('Diode Temp [K]')
ax= fig.add_subplot(212,sharex=ax)
plot(d[msk,0]-tstart,d[msk,2],label='Copper',lw=2)
ax.grid()
ax.legend(loc='lower right')
ax.set_ylabel('Diode Temp [K]')
ax.set_xlabel('Time [s]')
#ax.set_xlim(735315,73515.706)
#fig.autofmt_xdate()
#print ax.get_xlim()
#ax.xaxis.set_major_formatter(DateFormatter('HHMMSS'))
#display(fig)

# %%
n

# %%
figure()

# %%
figure()

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
display(gcf())

# %%
)
