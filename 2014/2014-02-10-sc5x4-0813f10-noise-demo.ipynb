# %%
4/5.
# Out:
# 0.8

# %%
import kid_readout.analysis.noise_summary

# %%
nms = kid_readout.analysis.noise_summary.load_noise_pkl('/home/data/noise_2014-02-02_105100.pkl')

# %%
nm = nms[-1]

# %%
loglog(nm.fr_fine[1:],nm.pii_fine[1:])
loglog(nm.fr_fine[1:],nm.prr_fine[1:])

# %%
plot(nm.s21.real,nm.s21.imag,'.-')
plot(nm.tsl_raw.real,nm.tsl_raw.imag,'r')
plot((nm.s21m+nm.s0).real,(nm.s21m+nm.s0).imag,'.-')
