# %%
matplotlib.rcParams['figure.figsize']=(10,6)

# %%
import kid_readout.analysis.noise_archive
# Out:
# updated file list
# /home/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
df = kid_readout.analysis.noise_archive.load_archive('/home/data/archive/sc5x4_0813f12_mmwnoise.npy')

# %%
df.shape
# Out:
# (928, 105)

# %%
dfr = df[df.sweep_primary_package_temperature < 0.19]

# %%
plot(dfr.sweep_secondary_load_temperature)

# %%
rr = dfr[dfr.resonator_id==0]
plot(rr.sweep_secondary_load_temperature,rr.noise_on_f_0,'.')

# %%
rr = rr.sort(['zbd_voltage','noise_on_f_0'])
powersweep = rr[rr.zbd_voltage > 2e-4]
tempsweep = rr[rr.zbd_voltage < 2e-4]

# %%
#plot(tempsweep.sweep_secondary_load_temperature,tempsweep.noise_on_f_0,'.')
pp = np.polyfit(powersweep.noise_on_f_0,powersweep.zbd_voltage,3)
plot(powersweep.zbd_voltage*1e6/2000,powersweep.noise_on_f_0,'o')
plot(np.polyval(pp,powersweep.noise_on_f_0)*1e6/2000,powersweep.noise_on_f_0)
grid()
print pp
plot(np.polyval(pp,tempsweep.noise_on_f_0)*1e6/2000,tempsweep.noise_on_f_0,'r.')
# Out:
# [  1.04658353e+03  -2.43263512e+05   1.88477159e+07  -4.86764791e+08]

# %%
plot(tempsweep.sweep_secondary_load_temperature,np.polyval(pp,tempsweep.noise_on_f_0)*1e6/2000,'o')
pp2 = np.polyfit(tempsweep.sweep_secondary_load_temperature,np.polyval(pp,tempsweep.noise_on_f_0)*1e6/2000,2)
x = np.linspace(tempsweep.sweep_secondary_load_temperature.min(),tempsweep.sweep_secondary_load_temperature.max(),100)
plot(x,np.polyval(pp2,x))
print pp2
grid()
# Out:
# [ 0.23871327 -0.74982958 -0.28380166]
