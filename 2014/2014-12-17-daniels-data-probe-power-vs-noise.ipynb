# %%
import kid_readout.analysis.archive
# Out:
# updated file list
# /home/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
df = kid_readout.analysis.archive.build_simple_archive('/home/data/pkl/2014-12-16_100225_load_step_with_mmw_noise.pkl')
# Out:
# skipping non noise measurement for now
# skipping non noise measurement for now
# skipping non noise measurement for now
# skipping non noise measurement for now
# skipping non noise measurement for now
# skipping non noise measurement for now
# skipping non noise measurement for now
# skipping non noise measurement for now
# skipping non noise measurement for now
# skipping non noise measurement for now
# skipping non noise measurement for now
# skipping non noise measurement for now
# skipping non noise measurement for now
# skipping non noise measurement for now
# skipping non noise measurement for now
# skipping non noise measurement for now

# %%
df.shape
# Out:
# (240, 90)

# %%
r0 = df[df.resonator_id==0]

# %%
r0.shape
# Out:
# (15, 90)

# %%
for k,row in r0.iterrows():
    loglog(row.pca_freq,row.pca_eigvals[1,:]-row.pca_eigvals[1,-10:].mean(),color=plt.cm.copper((42-row.atten)/10.))
ylim(1e-21,1e-16)
# Out:
# (1e-21, 1e-16)

# %%
df = kid_readout.analysis.archive.add_noise_fits(df)

# %%
df = kid_readout.analysis.archive.add_noise_summary(df)

# %%
r0 = df[df.resonator_id==0]

# %%
loglog(1-r0.f_0/r0.f_0.max(),r0.noise_fit_device_noise,'.')

# %%
r0 = r0.sort(['power_dbm'])
semilogy(r0.power_dbm,r0.noise_fit_device_noise,'.')
semilogy(r0.power_dbm,r0.device_noise-r0.amplifier_noise,'x')
semilogy(r0.power_dbm,9e-24*(10**(r0.power_dbm/10))**-0.5)
semilogy(r0.power_dbm,9e-22*(10**(r0.power_dbm/10))**-0.3)
semilogy(r0.power_dbm,4.5e-24*(10**(r0.power_dbm/10))**-0.5+0.6e-18)
ylim(1e-19,1e-17)
# Out:
# (1e-19, 1e-17)

# %%
plot(df.resonator_id,df.noise_fit_fc,'.')

# %%
semilogy(df.power_dbm,df.noise_fit_device_noise,'.')
semilogy(df.power_dbm,df.device_noise-df.amplifier_noise,'x')
ylim(1e-19,1e-17)
# Out:
# (1e-19, 1e-17)

# %%
for k,row in r0.iterrows():
    if np.all(np.isfinite(row.folded_projected_timeseries)):
        print k,row.folded_projected_timeseries.shape
        plot(np.real(row.folded_projected_timeseries).mean(0))
#xlim(100,120)
# Out:
# 224 (512, 128)

# %%
r0.folded_projected_timeseries
# Out:
# 0                                                    NaN
# 112                                                  NaN
# 224    [[(46.6504+17.3509j), (27.8916-29.8287j), (23....
# 1                                                    NaN
# 113                                                  NaN
# 2                                                    NaN
# 114                                                  NaN
# 3                                                    NaN
# 115                                                  NaN
# 4                                                    NaN
# 116                                                  NaN
# 5                                                    NaN
# 117                                                  NaN
# 6                                                    NaN
# 118                                                  NaN
# Name: folded_projected_timeseries, dtype: object

# %%
r0.zbd_voltage
# Out:
# 0           NaN
# 112    0.000053
# 224    0.000053
# 1           NaN
# 113    0.000053
# 2           NaN
# 114    0.000053
# 3           NaN
# 115    0.000053
# 4           NaN
# 116    0.000053
# 5           NaN
# 117    0.000053
# 6           NaN
# 118    0.000053
# Name: zbd_voltage, dtype: float64

# %%
plot(df.zbd_voltage,'.')
