# %%
from kid_readout.utils import easync

# %%
nc = easync.EasyNetCDF4('/home/gjones/2014-05-19_16-54-28.nc')

# %%
lakeshore_res=nc.sim900.bridge_res_value[:]
lakeshore_time=nc.sim900.time[:]
lakeshore_bridge_temp = nc.sim900.bridge_temp_value[:]

# %%
plot(lakeshore_time,lakeshore_res)

# %%
glitches = np.abs(np.diff(lakeshore_res))

# %%
plot(glitches)
ylim(0,1000)
# Out:
# (0, 1000)

# %%
glitch_mask = (glitches<400)
glitch_mask = glitch_mask[1:] & glitch_mask[:-1]

# %%
lakeshore_res = lakeshore_res[:-2][glitch_mask]
lakeshore_time = lakeshore_time[:-2][glitch_mask]

# %%
plot(lakeshore_time,lakeshore_res)

# %%
plot(np.diff(lakeshore_res))

# %%
lines = open('/home/gjones/20140519-170118.txt').readlines()

# %%
len(lines)
# Out:
# 11285

# %%
lines[0]
# Out:
# 'time, diode ch1 temp, dio ch 2 temp, dio 3 temp, dio 4 temp, dio 1 volts, dio2, volts, dio3 volts, dio 4 volts, rox 1 temp, rox 1 res, rox 2 temp, rox 2 res, sim921 pos 4 temp, sim921 pos 4 res\n'

# %%
lines[1]
# Out:
# '20140519-170124 3.300560E+02, 3.300560E+02, 0.000000E+00, 0.000000E+00 7.700000E-05, 7.500000E-05, 0.000000E+00, 0.000000E+00 0.07469999 786455.8 3.197442 1498.439 3.055336 1473.343\n'

# %%
import time

# %%
def unixtime(tstr):
    return time.mktime(time.strptime(tstr,'%Y%m%d-%H%M%S'))

# %%
time.ctime(unixtime('20140519-170124'))
# Out:
# 'Mon May 19 17:01:24 2014'

# %%
sec_time = []
si_cal_res = []
si_50mK_res = []
for line in lines[1:]:
    parts = line.split(' ')
    sec_time.append(unixtime(parts[0]))
    si_50mK_res.append(float(parts[-1].strip()))
    si_cal_res.append(float(parts[-3]))
sec_time = np.array(sec_time)
si_cal_res = np.array(si_cal_res)
si_50mK_res = np.array(si_50mK_res)

# %%
lakeshore_interp_res = np.interp(sec_time,lakeshore_time,lakeshore_res)

# %%
plot(sec_time,si_cal_res)
plot(sec_time,si_50mK_res)
plot(sec_time,lakeshore_interp_res)

# %%
plot(lakeshore_interp_res,si_50mK_res,'.')
#plot(lakeshore_interp_res,si_cal_res,'.')
#plot(si_cal_res,si_50mK_res,'.')
#plot(si_cal_res,si_cal_res,',')

# %%
si_cal_curve = np.genfromtxt('/home/gjones/Downloads/cal_3882.txt')

# %%
si_cal_curve.shape
# Out:
# (225, 2)

# %%
plot(si_cal_curve[:,1],si_cal_curve[:,0])
xlim(0,4)
# Out:
# (0, 4)

# %%
si_cal_temp = np.interp(si_cal_res,si_cal_curve[:,0],si_cal_curve[:,1])

# %%
plot(si_cal_temp)
ylim(0,.1)
# Out:
# (0, 0.1)

# %%
si_std_curve = np.genfromtxt('/home/gjones/Downloads/ro600.txt')

# %%
si_cal_std_temp = np.interp(si_cal_res,si_std_curve[:,0],si_std_curve[:,1])

# %%
si_50mK_std_temp = np.interp(si_50mK_res,si_std_curve[:,0],si_std_curve[:,1])

# %%
plot(si_cal_temp)
plot(si_cal_std_temp)
plot(si_50mK_std_temp)
plot()
ylim(0.04,1)
# Out:
# (0.04, 1)

# %%
plot(si_50mK_std_temp,(si_50mK_std_temp-si_cal_temp)/si_50mK_std_temp,'.')
plot(si_50mK_std_temp,(si_50mK_std_temp-si_cal_std_temp)/si_50mK_std_temp,'.')
ylim(-.2,.2)
# Out:
# (-0.2, 0.2)

# %%
plot(si_50mK_std_temp,(si_50mK_std_temp-si_cal_temp),'.')
plot(si_50mK_std_temp,(si_50mK_std_temp-si_cal_std_temp),'.')
#plot(si_50mK_std_temp,)
ylim(-.1,.1)
xlim(0,1)
# Out:
# (0, 1)

# %%
semilogx(lakeshore_interp_res,si_cal_temp,'.')
semilogx(lakeshore_interp_res,si_cal_std_temp,'.')
semilogx(lakeshore_interp_res,si_50mK_std_temp,'.')
ylim(0,0.5)
# Out:
# (0, 0.5)

# %%
plot(sec_time,si_cal_temp)
plot(sec_time,si_50mK_std_temp)
plot(lakeshore_time,lakeshore_bridge_temp)
ylim(0,.4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-e832056cfe0a> in <module>()
#       1 plot(sec_time,si_cal_temp)
#       2 plot(sec_time,si_50mK_std_temp)
# ----> 3 plot(lakeshore_time,lakeshore_bridge_temp)
#       4 ylim(0,.4)
#
# /home/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    2985         ax.hold(hold)
#    2986     try:
# -> 2987         ret = ax.plot(*args, **kwargs)
#    2988         draw_if_interactive()
#    2989     finally:
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    4135         lines = []
#    4136
# -> 4137         for line in self._get_lines(*args, **kwargs):
#    4138             self.add_line(line)
#    4139             lines.append(line)
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in _grab_next_args(self, *args, **kwargs)
# ...

# %%
np.interp(5393,si_std_curve[:,0],si_std_curve[:,1])
# Out:
# 0.30480152775883235

# %%
loglog(si_std_curve[:,0],si_std_curve[:,1])

# %%
1/np.log(9.)
# Out:
# 0.45511961331341866
