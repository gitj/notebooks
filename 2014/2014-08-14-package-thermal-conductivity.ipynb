# %%
matplotlib.rcParams['font.size']=16

# %%
import kid_readout.utils.parse_srs
reload(kid_readout.utils.parse_srs)
import glob

# %%
dt,d = kid_readout.utils.parse_srs.get_load_log('/home/heather/SRS/20140814-091429.txt')

# %%
calcurve = np.genfromtxt('/home/heather/SRS/cal_3882.txt')

# %%
loglog(calcurve[:,0],calcurve[:,1])

# %%
d.shape
# Out:
# (4892, 15)

# %%
4490-500
# Out:
# 3990

# %%
plot(dt[4000:],d[4000:,-4])
plot(dt[4000:],d[4000:,-2])

ylim(0,.5)
#plot(dt[-100:],d[-100:,-2])
# Out:
# (0, 0.5)

# %%
package = d[4000:4800,-4]
stage = d[4000:4800,-2]
stagecal = np.interp(d[4000:4800,-1],calcurve[:,0],calcurve[:,1])
ut = d[4000:4800,0]
ts = ut-ut[0]

# %%
plot(stage-stagecal)
#plot(stagecal)

# %%
plot(ts/60.,package,lw=2,label='package')
plot(ts/60.,stage,lw=2,label='stage')
xlabel('minutes')
ylabel('K')
grid()
legend(loc='lower right')

# %%
plot(stage)
plot(stage[140:])
plot(stage[400:])
xlim(0,150)
title('stage')
xlabel('sample number')
ylabel('K')

# %%
plot(package)
plot(package[140:])
plot(package[400:])
xlim(0,150)

title('package')
xlabel('sample number')
ylabel('K')

# %%
plot(stage,'r')
plot(stage[140:],'r')
plot(stage[400:],'r')
plot(package,'b')
plot(package[140:],'b')
plot(package[400:],'b')
xlim(0,100)

title('package vs stage')
xlabel('sample number')
ylabel('K')
# Out:
# (0, 100)
