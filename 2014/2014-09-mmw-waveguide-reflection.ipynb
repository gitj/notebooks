# %%
d = np.load('/home/gjones/mmw_source/reflect.npz')

# %%
freq = d['freq']
power = d['power']

# %%
plot(freq,power)
xlim(147,152)
# Out:
# (147, 152)

# %%
ff = np.abs(np.fft.rfft(power-power.mean()))

# %%
plot(ff)

# %%
np.diff(freq)
# Out:
# array([ 0.012,  0.012,  0.012, ...,  0.012,  0.012,  0.012])

# %%
2e10/0.012e9
# Out:
# 1666.6666666666667

# %%
llcm = (1.88e10/0.012e9)*np.arange(len(ff))/float(len(ff))

# %%
plot(llcm*2,ff,'r',lw=2)
xlim(0,600)
ylim(1e-7,4e-4)
grid()
ax = gca()
ax.axvline(76/2.)
ax.axvline(71.)
ax.axvline(71.*2)
ax.axvline(71.*3)
ax.axvline(71.*4)

# %%
llcm[ff.argmax()]*2
# Out:
# 71.537290715372919

# %%
llcm[1]
# Out:
# 1.9025875190258752

# %%
1e-9/(.761*.25/2e8)
# Out:
# 1.0512483574244416

# %%
(12+10+3+2+1+1+1+2)*2.54
# Out:
# 81.28

# %%
(1e-9/.18)*1.88e8*4
# Out:
# 4.177777777777778

# %%
np.sqrt(1-(3e10/(2*.165*150e9)))
# Out:
# 0.62764591446084783

# %%
_*3e8
# Out:
# 188293774.33825436

# %%
0.012*len(freq)
# Out:
# 21.012

# %%
31/150.
# Out:
# 0.20666666666666667

# %%
2e8/160e6
# Out:
# 1.25
