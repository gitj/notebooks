# %%
matplotlib.rcParams['font.size']=16

# %%
import kid_readout.utils.parse_srs
reload(kid_readout.utils.parse_srs)
import glob

# %%
latest = sorted(glob.glob('/home/data/SRS/2*.txt'))[-1]
latest = '/home/data/SRS/20140912-130952.txt'
print latest
dt,d = kid_readout.utils.parse_srs.get_load_log(latest)
# Out:
# /home/data/SRS/20140912-130952.txt

# %%
figure(figsize=(12,6))
plot(dt[-100000:],d[-100000:,-4])
ax = gca()
ax.xaxis.set_major_formatter(DateFormatter('%m-%d-%H%M'))
#plot(dt[-400:],d[-400:,-2])

ylim(0,.5)
#plot(dt[-100:],d[-100:,-2])
# Out:
# (0, 0.5)

# %%
figure(figsize=(12,6))
plot(dt[-100000:],d[-100000:,2])
plot(dt[-100000:],d[-100000:,-4]*5)
ax = gca()
ax.xaxis.set_major_formatter(DateFormatter('%m-%d-%H%M'))
ylim(0,5)
# Out:
# (0, 5)

# %%
print d[-1,-4],d[-1,-2]
print dt[-1]
# Out:
# 0.2012035 300.0
# 2014-10-01 15:24:09

# %%
figure()
since = -5000
plot(dt[since:],d[since:,1])
#ylim(0,6)
figure()
plot(dt[since:],d[since:,2])
#ylim(0,6)
gcf().autofmt_xdate()
figure()
plot(dt[since:],d[since:,-4])
gcf().autofmt_xdate()
#ylim(0,.3)
#plot(dt[since:],d[since:,-2])

# %%
f = figure()

# %%
np.sqrt(np.linspace(0,2**2,6))
# Out:
# array([ 0.        ,  0.89442719,  1.26491106,  1.54919334,  1.78885438,  2.        ])

# %%
plot(d[-1000:,-4])
ylim(0,.3)
# Out:
# (0, 0.3)

# %%
plot(d[:,-4],d[:,-1],'.')
xlim(1.4,1.5)
ylim(0,1000)
# Out:
# (0, 1000)

# %%
import time

# %%
time.strftime("udp_skip_%Y-%m-%d_%H%M%S.pkl")
# Out:
# 'udp_skip_2014-08-21_133643.pkl'

# %%
plot(d[:16000,-1])
#ylim(0,1)

# %%
d[0,-1]
# Out:
# 249.72730000000001

# %%
semilogy(d[:,-4],d[:,-1],'.')

# %%
plot(d[:,-4],d[:,-2]-d[:,-4],'.-')
ylim(-0.02,0.05)
xlim(0.1,1)
# Out:
# (0.1, 1)

# %%
plot(d[:,-2],d[:,1],'.')
plot(d[:,-4],d[:,1],'.')
ylim(3.9,10)
xlim(0.18,0.215)
# Out:
# (0.18, 0.215)

# %%
semilogx(d[23500:,2],d[23500:,-1])
semilogx(d[2500:3000,-4],d[2500:3000,-1])
ylim(5e4,1e5)
grid()

# %%
fig = plt.figure(figsize=(8,8))
ax= fig.add_subplot(211)
plot(d[msk,0]-tstart,d[msk,1],label='Absorber',lw=2)
ax.grid()
ax.legend(loc='lower right')
ax.set_ylabel('Diode Temp [K]')
ax= fig.add_subplot(212,sharex=ax)
plot(d[msk,0]-tstart,d[msk,2],label='Copper',lw=2)
ax.grid()
ax.legend(loc='lower right')
ax.set_ylabel('Diode Temp [K]')
ax.set_xlabel('Time [s]')
#ax.set_xlim(735315,73515.706)
#fig.autofmt_xdate()
#print ax.get_xlim()
#ax.xaxis.set_major_formatter(DateFormatter('HHMMSS'))
#display(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-5cbf26275329> in <module>()
#       1 fig = plt.figure(figsize=(8,8))
#       2 ax= fig.add_subplot(211)
# ----> 3 plot(d[msk,0]-tstart,d[msk,1],label='Absorber',lw=2)
#       4 ax.grid()
#       5 ax.legend(loc='lower right')
#
# NameError: name 'msk' is not defined

# %%
n

# %%
figure()

# %%
figure()

# %%
# %pylab inline

# %%
display(gcf())

# %%
figure(figsize=(6,6))
msk = (d[:,-4] < 0.263) & (d[:,-4] >0.255)
plot(d[msk,2],d[msk,-4],'.',label='copper')
plot(d[msk,1],d[msk,-4],'.',label='absorber')
legend(loc='lower right')
xlabel('Load temperature [K]')
ylabel('Package temperature [K]')
title('Absorber load temperature\neffect on package temperature\n2014-04-07')
grid()
savefig('/home/gjones/2014-04-07-package-temp-vs-load-temp.png',bbox_inches='tight')

# %%
1e-5*130e6

# %%
14e-5*25/50

# %%
1-21e-5

# %%
350-40
