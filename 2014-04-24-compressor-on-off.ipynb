# %%
import kid_readout.utils.readoutnc
reload(kid_readout.utils.readoutnc)
import kid_readout.analysis.resonator
reload(kid_readout.analysis.resonator)
# Out:
# <module 'kid_readout.analysis.resonator' from '/home/gjones/workspace/kid_readout/analysis/resonator.pyc'>

# %%
'//home/data2/2014-05

# %%
nc = kid_readout.utils.readoutnc.ReadoutNetCDF('/home/data2/2014-04-23_071613_compressor_onoff.nc')

# %%
ts = nc.timestreams[0]

# %%
import kid_readout.utils.fftfilt
import scipy.signal

# %%
plot(ts.get_data_index(0).real[:256*500])

# %%
for k in range(20):
    figure(figsize=(12,4))
    plot(kid_readout.utils.fftfilt.fftfilt(scipy.signal.firwin(1024,1/64.),ts.get_data_index(k)).real[1024::64])

# %%
plot(ts.get_data_index(1).real[:10000])
