# %%
X,Y = np.meshgrid(np.linspace(0,1,1000),np.linspace(0,1,1000))

# %%
X.shape
# Out:
# (1000, 1000)

# %%
Z = np.zeros((1000,1000))

# %%
centers = np.random.rand(7,2)*0.5

# %%
centers
# Out:
# array([[ 0.12163024,  0.4546876 ],
#        [ 0.07881723,  0.17195732],
#        [ 0.34213224,  0.45665651],
#        [ 0.27152286,  0.38365956],
#        [ 0.2083014 ,  0.07385806],
#        [ 0.18383558,  0.20667427],
#        [ 0.1581995 ,  0.284253  ]])

# %%
msk = np.zeros((1000,1000),dtype=np.bool)
for k in range(centers.shape[0]):
    msk = msk | ((X-centers[k,0])**2 + (Y-centers[k,1])**2 < 0.025**2)

# %%
Z = np.zeros((1000,1000))
Z[msk] = 1
Z = Z - Z.mean()

# %%
figure(figsize=(8,8))
imshow(Z)

# %%
Zf = np.abs(np.fft.fftshift(np.fft.fft2(Z)))

# %%
figure(figsize=(8,8))
imshow(Zf)
xlim(400,600)
ylim(400,600)
# Out:
# (400, 600)

# %%
figure(figsize=(8,8))
imshow(log(Zf))
xlim(400,600)
ylim(400,600)
# Out:
# (400, 600)

# %%
Z = np.random.randn(1000,1000)*0.05
Z[msk] = 1
Z = Z - Z.mean()

# %%
figure(figsize=(8,8))
imshow(Z)

# %%
Zf = np.abs(np.fft.fftshift(np.fft.fft2(Z)))

# %%
figure(figsize=(8,8))
imshow(Zf)
xlim(400,600)
ylim(400,600)
# Out:
# (400, 600)

# %%
figure(figsize=(8,8))
imshow(log(Zf))
xlim(400,600)
ylim(400,600)
# Out:
# (400, 600)

# %%
Z = 1/((X-0.5)*(Y-0.5))

# %%
imshow(Z)
