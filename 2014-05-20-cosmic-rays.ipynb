# %%
from kid_readout.utils import readoutnc

# %%
rnc = readoutnc.ReadoutNetCDF('/home/data2/2014-05-12_134152_net_compressor_onoff.nc')

# %%
d0 = rnc.timestream_20140512134423.get_data_index(19)

# %%
d0.shape
# Out:
# (1048576,)

# %%
blah = hist(abs(d0.real-d0.real.mean()),bins=100,log=True)

# %%
crs = np.flatnonzero(abs(d0.real-d0.real.mean()) > 0.007)

# %%
crs.shape
# Out:
# (31,)

# %%
locs = crs[1:][(np.diff(crs.real)>100)]

# %%
if not len(locs):
    locs = [crs[0]]

# %%
for loc in locs:
    plot(np.imag(d0[loc-200:loc+500]-d0.mean())/d0.std())
