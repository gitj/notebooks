# %%
from kid_readout.utils import readoutnc

# %%
rnc = readoutnc.ReadoutNetCDF('/home/data2/2014-05-02_162142_net.nc')

# %%
d0 = rnc.timestream_20140502162301.get_data_index(2)

# %%
d0.shape
# Out:
# (4194304,)

# %%
blah = hist(abs(d0.real-d0.real.mean()),bins=100,log=True)

# %%
crs = np.flatnonzero(abs(d0.real-d0.real.mean()) > 0.01)

# %%
crs.shape
# Out:
# (105,)

# %%
locs = crs[1:][(np.diff(crs.real)>100)]

# %%
if not len(locs):
    locs = [crs[0]]

# %%
for loc in locs:
    plot(np.real(d0[loc-200:loc+500]-d0.mean())/d0.std())

# %%
loc = locs[0]

# %%
for loc in locs:
    plot(d0[loc-200:loc+200].real,d0[loc-200:loc+200].imag,'.-')
