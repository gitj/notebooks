# %%
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import glob

# %%
files = glob.glob('/home/pmcroot/data1/2016-08-24_50mm_star_focus_test_100ms/*.npz')
files.sort()

# %%
len(files)
# Out:
# 31410

# %%
npz = np.load(files[0])

# %%
npz['state'][()].keys()
# Out:
# ['fmax', 'appos', 'fpos', 'exposure_counts', 'apmin', 'fmin', 'time', 'apmax']

# %%
means = []
ts = []
for fn in files[::100]:
    npz = np.load(fn)
    means.append(npz['image'].mean(dtype='float64'))
    ts.append(npz['state'][()]['time'])
means = np.array(means)
ts = np.array(ts)

# %%
plot(means,'.-')
# Out:
# <img src="data:image/png;base64,...">

# %%
files[::100][273]
# Out:
# '/home/pmcroot/data1/2016-08-24_50mm_star_focus_test_100ms/2016-08-25_055214_focus_step_0000.npz'

# %%
im = np.load(files[::100][265])['image']

# %%
import scipy.ndimage

# %%
figure()
imshow(scipy.ndimage.gaussian_filter(im,2)[::4,::4],aspect='auto',cmap=cm.gray)
#imshow(im,aspect='auto',cmap=cm.gray)
#clim(0,1000)
# Out:
# <img src="data:image/png;base64,...">

# %%
figure()
ax = gca()
txt = ax.text(0.1,0.9,'blah',transform=ax.transAxes)
txt.set_text("new")
# Out:
# <img src="data:image/png;base64,...">

# %%
txt.set_text()
