# %%
def plot_sweep(fn,ref=None):
    data = np.load(fn)
#    subplot(211)
    if ref is None:
        ref_power = 1.0
    else:
        ref_power = np.interp(data['mmw_freq'],ref['mmw_freq'],ref['power_watts'])
    plot(data['mmw_freq']/1e9,10*np.log10(data['power_watts']/ref_power)+30,label=data['comments'],lw=2)
#    subplot(212)
#    plot(data['mmw_freq']/1e9,1e6*data['zbd_voltage'])
    #suptitle(data['comments'],size='x-small')

# %%
import glob

# %%
data = np.load('/home/data2/mmw_sweeps/2014-09-08_155502_130.000_171.000_100.0.npz')

# %%
data.keys()
# Out:
# ['power_watts', 'mmw_freq', 'zbd_voltage', 'fundamental_freq', 'comments']

# %%
data['comments']
# Out:
# array('6 turns up, 01ss-90ss-01g-insulator-60g',
#       dtype='|S39')

# %%
plot(data['mmw_freq'],10*np.log10(data['power_watts']))

# %%
fns = glob.glob('/home/data2/mmw_sweeps/2014-0*.npz')
fns.sort()
print fns
# Out:
# ['/home/data2/mmw_sweeps/2014-08-29_130937_150.000_154.000_10.0.npz', '/home/data2/mmw_sweeps/2014-08-29_132700_130.000_170.000_100.0.npz', '/home/data2/mmw_sweeps/2014-08-29_135649_130.000_170.000_100.0.npz', '/home/data2/mmw_sweeps/2014-08-29_152820_130.000_170.000_100.0.npz', '/home/data2/mmw_sweeps/2014-08-29_160147_130.000_170.000_10.0.npz', '/home/data2/mmw_sweeps/2014-08-29_203740_130.000_170.000_10.0.npz', '/home/data2/mmw_sweeps/2014-09-03_115959_140.000_161.000_10.0.npz', '/home/data2/mmw_sweeps/2014-09-03_124330_155.000_156.000_1.0.npz', '/home/data2/mmw_sweeps/2014-09-03_124926_140.000_161.000_50.0.npz', '/home/data2/mmw_sweeps/2014-09-03_134430_140.000_161.000_10.0.npz', '/home/data2/mmw_sweeps/2014-09-03_140348_140.000_161.000_10.0.npz', '/home/data2/mmw_sweeps/2014-09-03_142916_140.000_161.000_10.0.npz', '/home/data2/mmw_sweeps/2014-09-03_150009_140.000_161.000_10.0.npz', '/home/data2/mmw_sweeps/2014-09-03_152302_140.000_161.000_10.0.npz', '/home/data2/mmw_sweeps/2014-
# ...

# %%
figure(figsize=(16,6))
for fn in fns:
    plot_sweep(fn)
legend(loc='lower right',prop=dict(size='small'))
xlim(140,180)
# Out:
# (140, 180)

# %%
d.keys()
# Out:
# ['power_watts', 'mmw_freq', 'zbd_voltage', 'fundamental_freq', 'comments']

# %%
fns = glob.glob('/home/data2/mmw_sweeps/2014-09-04*.npz')
fns.sort()
print fns
# Out:
# ['/home/data2/mmw_sweeps/2014-09-04_111108_130.000_171.000_100.0.npz', '/home/data2/mmw_sweeps/2014-09-04_111850_130.000_171.000_100.0.npz', '/home/data2/mmw_sweeps/2014-09-04_112314_130.000_171.000_100.0.npz', '/home/data2/mmw_sweeps/2014-09-04_112819_130.000_165.000_100.0.npz', '/home/data2/mmw_sweeps/2014-09-04_113729_130.000_165.000_100.0.npz', '/home/data2/mmw_sweeps/2014-09-04_114131_130.000_165.000_100.0.npz', '/home/data2/mmw_sweeps/2014-09-04_120509_130.000_165.000_100.0.npz', '/home/data2/mmw_sweeps/2014-09-04_121134_140.000_161.000_25.0.npz', '/home/data2/mmw_sweeps/2014-09-04_122011_140.000_161.000_100.0.npz', '/home/data2/mmw_sweeps/2014-09-04_122838_130.000_161.000_50.0.npz', '/home/data2/mmw_sweeps/2014-09-04_123324_130.000_161.000_50.0.npz', '/home/data2/mmw_sweeps/2014-09-04_124207_130.000_161.000_50.0.npz', '/home/data2/mmw_sweeps/2014-09-04_125110_130.000_161.000_50.0.npz', '/home/data2/mmw_sweeps/2014-09-04_125703_130.000_161.000_50.0.npz', '/home/data2/mmw_sweeps
# ...

# %%
ref = np.load('/home/data2/mmw_sweeps/2014-09-04_111108_130.000_171.000_100.0.npz')

# %%
figure(figsize=(16,10))
for fn in fns[:6]:
    plot_sweep(fn,ref=ref)
legend(loc='lower right',prop=dict(size='small'))
xlim(140,180)
#ylim(-90,-60)
# Out:
# (140, 180)

# %%
ref = np.load(fns[7])
figure(figsize=(16,10))
for fn in fns[6:-2]:
    plot_sweep(fn,ref=ref)
legend(loc='lower right',prop=dict(size='small'))
xlim(140,162)
#ylim(-15,-6)
grid()

# %%
ref = None# np.load(fns[-2])
figure(figsize=(16,10))
for fn in fns[-3:]:
    plot_sweep(fn,ref=ref)
legend(loc='lower right',prop=dict(size='small'))
xlim(140,162)
#ylim(-15,-6)
grid()

# %%
1e8/0.5e9
# Out:
# 0.2

# %%
8000/5.
# Out:
# 1600.0

# %%
rcParams['font.size']=16

# %%
fns = glob.glob('/home/data2/mmw_sweeps/2014-09-09*.npz')
fns += [#'/home/data2/mmw_sweeps/2014-08-29_132700_130.000_170.000_100.0.npz',
        '/home/data2/mmw_sweeps/2014-08-29_135649_130.000_170.000_100.0.npz']
fns.sort()
print fns
ref = None# np.load(fns[-2])
figure(figsize=(16,10))
for fn in fns:
    plot_sweep(fn,ref=ref)
plot(d[:,0]*30,10*np.log10(d[:,1])-40,label='filter data from Cardiff, shifted down by 40 dB')
legend(loc='lower right',prop=dict(size='x-small'))
xlim(120,200)
ylim(-70,-10)
ylabel('zbd power [dBm]')
xlabel('GHz')
grid()
savefig('/home/gjones/2014-09-09-mmw-source-without-filter-and-with-metal-mesh.pdf',bbox_inches='tight')
# Out:
# ['/home/data2/mmw_sweeps/2014-08-29_135649_130.000_170.000_100.0.npz', '/home/data2/mmw_sweeps/2014-09-09_091712_100.000_180.000_50.0.npz', '/home/data2/mmw_sweeps/2014-09-09_094454_120.000_180.000_100.0.npz', '/home/data2/mmw_sweeps/2014-09-09_095434_120.000_180.000_100.0.npz']

# %%
fns = glob.glob('/home/data2/mmw_sweeps/2014-09-10*.npz')
fns += glob.glob('/home/data2/mmw_sweeps/2014-09-03*.npz')
#fns += [#'/home/data2/mmw_sweeps/2014-08-29_132700_130.000_170.000_100.0.npz',
#        '/home/data2/mmw_sweeps/2014-08-29_135649_130.000_170.000_100.0.npz']
fns.sort()
print fns
ref = None# np.load(fns[-2])
figure(figsize=(16,10))
for fn in fns[5:]:
    plot_sweep(fn,ref=ref)
#plot(d[:,0]*30,10*np.log10(d[:,1])-40,label='filter data from Cardiff, shifted down by 40 dB')
legend(loc='lower right',prop=dict(size='x-small'))
xlim(135,165)
ylim(-60,-35)
ylabel('zbd power [dBm]')
xlabel('GHz')
grid()
#savefig('/home/gjones/2014-09-09-mmw-source-without-filter-and-with-metal-mesh.pdf',bbox_inches='tight')
# Out:
# ['/home/data2/mmw_sweeps/2014-09-03_115959_140.000_161.000_10.0.npz', '/home/data2/mmw_sweeps/2014-09-03_124330_155.000_156.000_1.0.npz', '/home/data2/mmw_sweeps/2014-09-03_124926_140.000_161.000_50.0.npz', '/home/data2/mmw_sweeps/2014-09-03_134430_140.000_161.000_10.0.npz', '/home/data2/mmw_sweeps/2014-09-03_140348_140.000_161.000_10.0.npz', '/home/data2/mmw_sweeps/2014-09-03_142916_140.000_161.000_10.0.npz', '/home/data2/mmw_sweeps/2014-09-03_150009_140.000_161.000_10.0.npz', '/home/data2/mmw_sweeps/2014-09-03_152302_140.000_161.000_10.0.npz', '/home/data2/mmw_sweeps/2014-09-03_154143_140.000_161.000_10.0.npz', '/home/data2/mmw_sweeps/2014-09-10_145835_135.000_165.000_50.0.npz', '/home/data2/mmw_sweeps/2014-09-10_152234_135.000_165.000_10.0.npz', '/home/data2/mmw_sweeps/2014-09-10_154807_135.000_165.000_10.0.npz']

# %%
fns = glob.glob('/home/data2/mmw_sweeps/2014-09-11*.npz')
#fns += glob.glob('/home/data2/mmw_sweeps/2014-09-03*.npz')
#fns += [#'/home/data2/mmw_sweeps/2014-08-29_132700_130.000_170.000_100.0.npz',
#        '/home/data2/mmw_sweeps/2014-08-29_135649_130.000_170.000_100.0.npz']
fns.sort()
print fns
ref = None# np.load(fns[-2])
figure(figsize=(16,10))
for fn in fns[:]:
    plot_sweep(fn,ref=ref)
#plot(d[:,0]*30,10*np.log10(d[:,1])-40,label='filter data from Cardiff, shifted down by 40 dB')
legend(loc='lower right',prop=dict(size='x-small'))
xlim(135,165)
ylim(-60,-30)
ylabel('zbd power [dBm]')
xlabel('GHz')
grid()
# Out:
# ['/home/data2/mmw_sweeps/2014-09-11_105355_135.000_165.000_10.0.npz', '/home/data2/mmw_sweeps/2014-09-11_111533_135.000_165.000_10.0.npz', '/home/data2/mmw_sweeps/2014-09-11_114929_135.000_165.000_10.0.npz']

# %%
filt_data_str = r"""5.02558	0.94277
5.076343	0.93717
5.127106	0.92779
5.177869	0.91548
5.228632	0.89727
5.279395	0.87542
5.330158	0.85499
5.380921	0.83253
5.431684	0.80397
5.482447	0.766
5.53321	0.71266
5.583973	0.63236
5.634736	0.51675
5.685499	0.39018
5.736262	0.28138
5.787025	0.19263
5.837788	0.12343
5.888551	0.0776
5.939314	0.05034
5.990077	0.03531
6.04084	0.02592
6.091603	0.01918
6.142366	0.01458
6.193129	0.01171
6.243892	0.01061
6.294655	0.00821
6.345418	0.00592
6.396181	0.00474
6.446944	0.00354
6.497707	0.00351
6.54847	0.00384
6.599233	0.00384
6.649996	0.0034
6.700759	0.00235
6.751522	0.00165
6.802285	0.00148
6.853048	0.00128
6.903811	0.00099
6.954574	0.00079
7.005337	0.0007
7.0561	0.00027
7.106863	0.00008
7.157626	0.00029
7.208389	0
7.259152	-0.00022
7.309915	-0.00008
7.360678	0.00009
7.411441	-0.00009
7.462204	-0.00042
7.512967	-0.0001
7.56373	0.00028
7.614493	-0.00014
