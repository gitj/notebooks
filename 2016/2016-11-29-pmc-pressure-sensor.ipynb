# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
ds = pd.read_csv('/home/pmcroot/c1/home/pmc/logs/housekeeping/labjack/2016-11-29_225057.csv',comment='#')

# %%
ds.shape
# Out:
# (3845, 11)

# %%
ds.columns
# Out:
# Index([u'epoch', u'temperature', u'ain0', u'ain1', u'ain2', u'ain3', u'ain4',
#        u'ain5', u'ain6', u'ain7', u'ain31'],
#       dtype='object')

# %%
plot(pd.rolling_mean(ds.ain6,100)*1000)
plot(pd.rolling_mean(ds.temperature,100))
# Out:
# /data/home/gjones/anaconda/envs/readout/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=100,center=False).mean()
#   if __name__ == '__main__':
# /data/home/gjones/anaconda/envs/readout/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=100,center=False).mean()
#   from ipykernel import kernelapp as app

# %%
plot(pd.rolling_mean(ds.ain4,100)/pd.rolling_mean(ds.ain7,100))
#plot(pd.rolling_mean(ds.temperature,100))
# Out:
# /data/home/gjones/anaconda/envs/readout/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=100,center=False).mean()
#   if __name__ == '__main__':

# %%
plot(pd.rolling_mean(ds.ain7,100))
#plot(pd.rolling_mean(ds.temperature,100))
# Out:
# /data/home/gjones/anaconda/envs/readout/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=100,center=False).mean()
#   if __name__ == '__main__':

# %%
plot(ds.ain6.rolling(10),',')
plot(ds.epoch,ds.temperature,',')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-c6c0779a5e6c> in <module>()
# ----> 1 plot(ds.ain6.rolling(10),',')
#       2 plot(ds.epoch,ds.temperature,',')
#
# /home/gjones/anaconda/envs/readout/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3152         ax.hold(hold)
#    3153     try:
# -> 3154         ret = ax.plot(*args, **kwargs)
#    3155     finally:
#    3156         ax.hold(washold)
#
# /home/gjones/anaconda/envs/readout/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# ...

# %%
20/4096.
# Out:
# 0.0048828125

# %%
plot(ds.epoch,ds.ain7)

# %%
plot(ds.epoch,ds.ain4/ds.ain7)
ylim(0.72,.724)
# Out:
# (0.72, 0.724)

# %%
plot(ds.ain4.values[50:],ds.ain7.values[50:],',')

# %%
plot(ds.epoch,ds.ain4)

# %%
plot(ds.epoch/86400,ds.temperature-273.15)
