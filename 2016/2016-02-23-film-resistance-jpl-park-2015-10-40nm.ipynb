# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import kid_readout.utils.starcryo_temps
# Out:
# updated file list

# %%
import pandas as pd

# %%
df  = pd.read_csv('/artemis/readout/SRS/20160211-133058.txt')

# %%
df.columns
# Out:
# Index([u'time', u' diode ch1 temp', u' dio ch 2 temp', u' dio 3 temp',
#        u' dio 4 temp', u' dio 1 volts', u' dio 2 volts', u' dio 3 volts',
#        u' dio 4 volts', u' rox 1 temp', u' rox 1 res', u' rox 2 temp',
#        u' rox 2 res', u' rox 3 temp', u' rox 3 res'],
#       dtype='object')

# %%
df.shape
# Out:
# (210459, 15)

# %%
res = df[' rox 3 res']
temp = df[' rox 1 temp']

# %%
import seaborn as sns
sns.set_context('poster',rc={'figure.figsize':(8,6)})

# %%
plot(df[' rox 3 res']/993.)
#ylim(1000,3000)
ylim(1.2,2.7)
xlim(150000,175000)
ylabel('Resistance (ohm/square)')
xlabel('time (arb)')

# %%
plot(df[' rox 3 res'])
ylim(1000,3000)
#ylim(1.2,2.7)
xlim(150000,175000)
ylabel('Resistance (ohm/square)')
xlabel('time (arb)')

# %%
plot(temp,res/993.,'.')
#ylim(1000,3000)
ylim(.4,2.7)
xlabel('Temperature (K)')
ylabel('Resistance (ohm/square)')
xscale('log')

# %%
1
# Out:
# 1
