# %%
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import seaborn as sns
sns.set_context('poster')
rcParams['lines.linewidth']=1

# %%
from kid_readout.interactive import *
# Out:
# INFO: 2016-06-21 11:34:14,651 - kid_readout.<module>:13  kid_readout logging setup with default stream handler

# %%
import glob

# %%
fns = glob.glob('/artemis/readout/2016-06-21_*_scan_lo_*_MHz.nc')
print fns
# Out:
# ['/artemis/readout/2016-06-21_112639_scan_lo_830.0_MHz.nc', '/artemis/readout/2016-06-21_112721_scan_lo_1020.0_MHz.nc', '/artemis/readout/2016-06-21_112802_scan_lo_1210.0_MHz.nc', '/artemis/readout/2016-06-21_112844_scan_lo_1400.0_MHz.nc']

# %%
fns = ['/artemis/readout/2016-06-19_223038_scan_lo_830.0_MHz.nc', '/artemis/readout/2016-06-19_223140_scan_lo_1020.0_MHz.nc', '/artemis/readout/2016-06-19_223243_scan_lo_1210.0_MHz.nc', '/artemis/readout/2016-06-19_223346_scan_lo_1400.0_MHz.nc',
      '/artemis/readout/2016-06-21_112639_scan_lo_830.0_MHz.nc', '/artemis/readout/2016-06-21_112721_scan_lo_1020.0_MHz.nc', '/artemis/readout/2016-06-21_112802_scan_lo_1210.0_MHz.nc', '/artemis/readout/2016-06-21_112844_scan_lo_1400.0_MHz.nc']

# %%
sas = []
ncs = []
for fn in fns:
    nc = NCFile(fn)
    ncs.append(nc)
    sas.append(nc.SweepArray0)

# %%
figure(figsize=(18,6))
for sa in sas:
    plot(sa.frequency_MHz,20*np.log10(np.abs(sa.s21_point)))

# %%
sa.s21_raw.shape
# Out:
# (16384, 8192)

# %%
fold = sa.s21_raw.reshape(16384,-1,256).mean(1)

# %%
fold.shape
# Out:
# (16384, 256)

# %%
def get_fractional_frequency_response(folded):
    period = folded.shape[-1]
    template = np.ones((period,),dtype='float')
    template[:period//2] = -1
    response = np.abs(np.fft.ifft(np.fft.fft(template)*np.fft.fft(folded,axis=-1),axis=-1)*2./period).max(-1)
    return response

# %%
#figure()#(figsize=(18,6))
fig,(ax1,ax2) = subplots(2,1,sharex=True)
for k,sa in enumerate(sas):
    fold = sa.s21_raw.reshape(sa.s21_raw.shape[0],-1,256).mean(1)
    response = get_fractional_frequency_response(fold)
    if k >= 4:
        color = 'r'
        scale = 20
    else:
        color='k'
        scale = 0
    ax1.plot(sa.frequency_MHz.reshape((-1,4)).mean(1),response.reshape((-1,4)).mean(1),color=color)
    ax2.plot(sa.frequency_MHz,20*np.log10(np.abs(sa.s21_point))-scale,color=color)
    
ax2.set_ylim(-30,5)
ax2.set_xlim(870,1465)
ax2.set_xlabel('MHz')
ax1.set_ylabel('Optical response (arb)')
ax2.set_ylabel('|S21| dB')
#axvline(1016)
# Out:
# <img src="data:image/png;base64,...">

# %%
sa = sas[-2]

# %%
mag = np.abs(sa.s21_point)

# %%
from kid_readout.analysis import detect_peaks

# %%
np.any(np.diff(sa.frequency[np.flatnonzero(np.diff(sa.frequency)==0)])==0)
# Out:
# False

# %%
mask = np.flatnonzero(np.diff(sa.frequency)!=0)

# %%
np.unique(sa.frequency)
# Out:
# (14344,)

# %%
detect_peaks.detect_peaks(-mag[mask],show=True,valley=False,threshold=3,kpsh=False,edge='both')
# Out:
# <img src="data:image/png;base64,...">
# array([  206,   414,   543,   591,   616,   653,   700,   739,   918,
#         1011,  1014,  1084,  1136,  1256,  1510,  1557,  1900,  2118,
#         2151,  2175,  2512,  2536,  2538,  2751,  2919,  2997,  3048,
#         3050,  3180,  3373,  3451,  3505,  3596,  3604,  3814,  3818,
#         4454,  4602,  4924,  4931,  4999,  5094,  5096,  5314,  5544,
#         5735,  5738,  5922,  5948,  6202,  6261,  6268,  6372,  6375,
#         6377,  6563,  6782,  6834,  7016,  7047,  7134,  7553,  7584,
#         7655,  7662,  7901,  8298,  8457,  8936,  8938,  9383,  9446,
#         9508,  9574,  9576,  9578,  9595,  9923,  9959, 10148, 10216,
#        10218, 10324, 10358, 10490, 10537, 10671, 10717, 10854, 10857,
#        10988, 11064, 11248, 11301, 11333, 11429, 11496, 11674, 12107,
#        12130, 12136, 12138, 12445, 12458, 12531, 12742, 12774, 12776,
#        12778, 13225, 13415, 13417, 13652, 14030, 14054, 14056, 14285])

# %%
response = get_fractional_frequency_response(fold)

# %%
np.convolve(response,np.ones(5)/5.).argsort()[-5:]
# Out:
# array([5646, 5647, 5648, 7958, 7959])

# %%
figure()#(figsize=(18,6))
for sa in sas:
    fold = sa.s21_raw.reshape(16384,-1,256).mean(1)
    response = get_fractional_frequency_response(fold)
    plot(sa.frequency_MHz.reshape((-1,4)).mean(1),response.reshape((-1,4)).mean(1))
#axvline(1016)
# Out:
# <img src="data:image/png;base64,...">

# %%
fns = glob.glob('/artemis/readout/2016-06-19_22*_scan_lo_*_MHz.nc')
print fns
# Out:
# ['/artemis/readout/2016-06-19_223038_scan_lo_830.0_MHz.nc', '/artemis/readout/2016-06-19_223140_scan_lo_1020.0_MHz.nc', '/artemis/readout/2016-06-19_223243_scan_lo_1210.0_MHz.nc', '/artemis/readout/2016-06-19_223346_scan_lo_1400.0_MHz.nc', '/artemis/readout/2016-06-19_224847_scan_lo_830.0_MHz.nc', '/artemis/readout/2016-06-19_225151_scan_lo_1020.0_MHz.nc', '/artemis/readout/2016-06-19_225459_scan_lo_1210.0_MHz.nc', '/artemis/readout/2016-06-19_225814_scan_lo_1400.0_MHz.nc']

# %%
fns = ['/artemis/readout/2016-06-19_224847_scan_lo_830.0_MHz.nc', '/artemis/readout/2016-06-19_225151_scan_lo_1020.0_MHz.nc', '/artemis/readout/2016-06-19_225459_scan_lo_1210.0_MHz.nc', '/artemis/readout/2016-06-19_225814_scan_lo_1400.0_MHz.nc']

# %%
sas = []
ncs = []
for fn in fns:
    nc = NCFile(fn)
    ncs.append(nc)
    sas.append(nc.SweepArray0)

# %%
sa = sas[0]

# %%
sa.s21_raw.shape
# Out:
# (16384, 32768)

# %%
fold = sa.s21_raw.reshape(sa.s21_raw.shape[0],-1,256).mean(1)

# %%
response = get_fractional_frequency_response(fold)

# %%
np.where?

# %%
maxs = np.zeros(sa.frequency.shape)
for sa in sas:
    maxs = np.where(np.abs(sa.s21_point) > maxs, np.abs(sa.s21_point), maxs)

# %%
import scipy.signal

# %%
scipy.signal.resample?

# %%
bandpass = scipy.signal.resample(scipy.signal.resample(maxs,100),16384)

# %%
plot(scipy.signal.resample(scipy.signal.resample(maxs,100),16384))
# Out:
# <img src="data:image/png;base64,...">

# %%
maxs.shape
# Out:
# (16384,)

# %%
#figure()#(figsize=(18,6))
fig,(ax1,ax2) = subplots(2,1,sharex=True)
for sa in sas:
    fold = sa.s21_raw.reshape(sa.s21_raw.shape[0],-1,256).mean(1)
    response = get_fractional_frequency_response(fold)
    ax1.plot(sa.frequency_MHz.reshape((-1,4)).mean(1),response.reshape((-1,4)).mean(1))
    ax2.plot(sa.frequency_MHz,20*np.log10(np.abs(sa.s21_point/bandpass)))
    
ax2.set_ylim(-30,5)
ax2.set_xlim(870,1465)
ax2.set_xlabel('MHz')
ax1.set_ylabel('Optical response (arb)')
ax2.set_ylabel('|S21| dB')
#axvline(1016)
# Out:
# <img src="data:image/png;base64,...">

# %%
sa.s21_raw.shape
# Out:
# (16384, 32768)

# %%
3000/200.
# Out:
# 15.0
