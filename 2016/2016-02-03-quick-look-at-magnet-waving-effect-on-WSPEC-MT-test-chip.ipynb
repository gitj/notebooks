# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import kid_readout.analysis.archive
# Out:
# /home/gjones/anaconda/envs/readout/lib/python2.7/site-packages/matplotlib/__init__.py:1350: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# /home/gjones/anaconda/envs/readout/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# no data directory set up for clouds defaulting to /data
# updated file list

# %%
snms = kid_readout.analysis.archive.load_noise_pkl('/artemis/readout/pkl/2016-02-03_160026_dark.pkl')

# %%
len(snms)
# Out:
# 144

# %%
144/16.
# Out:
# 9.0

# %%
s0 = snms[0]
s16 = snms[16+1]
s6 = snms[6]
s22 = snms[6+16]

# %%
blah = s0.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-e40de156e3bd> in <module>()
# ----> 1 blah = s0.plot()
#
# /home/gjones/kid_readout/kid_readout/analysis/noise_measurement.pyc in plot(self, fig, title)
#     619         ax1b.plot(frm,20*np.log10(abs(self.sweep_model_normalized_s21)))
#     620
# --> 621         freqs_fine,prr_fine,pii_fine = self.get_projected_fractional_fluctuation_spectra(NFFT=2**18)
#     622         #ax2.loglog(freqs_fine[1:],prr_fine[1:],'b',label='Srr')
#     623         #ax2.loglog(freqs_fine[1:],pii_fine[1:],'g',label='Sii')
#
# /home/gjones/kid_readout/kid_readout/analysis/noise_measurement.pyc in get_projected_fractional_fluctuation_spectra(self, NFFT, window)
#     486             frequency fluctuation spectrum. Units are 1/Hz
#     487         """
# ...

# %%
def smooth_ts(snm,smooth=512):
    y = snm.normalized_timeseries.real.reshape((-1,smooth)).mean(1)
    y = y-y.mean()
    return y

# %%
plot(smooth_ts(s0))
plot(smooth_ts(s16))
plot(smooth_ts(s6))
plot(smooth_ts(s22))
