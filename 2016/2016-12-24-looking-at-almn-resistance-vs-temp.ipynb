# %%
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
d = pd.read_csv('/artemis/readout/SRS/20161130-122320.txt',skipinitialspace=True)

# %%
rox1 = d['rox 2 temp']
d1 = d['diode ch1 temp']
d2 = d['dio ch 2 temp']
rox2 = d['rox 1 temp']
res1 = d['rox 1 res']
res2 = d['rox 2 res']
res3 = d['rox 3 res']

# %%
list(d.columns)
# Out:
# ['time',
#  'diode ch1 temp',
#  'dio ch 2 temp',
#  'dio 3 temp',
#  'dio 4 temp',
#  'dio 1 volts',
#  'dio 2 volts',
#  'dio 3 volts',
#  'dio 4 volts',
#  'rox 1 temp',
#  'rox 1 res',
#  'rox 2 temp',
#  'rox 2 res',
#  'rox 3 temp',
#  'rox 3 res']

# %%
figure()
plot(rox1)
plot(rox2)
plot(d2)
ylim(0,20)
# Out:
# <img src="data:image/png;base64,...">
# (0, 20)

# %%
figure()
plot(res3)
ylim(0,1000)
# Out:
# <img src="data:image/png;base64,...">
# (0, 1000)

# %%
figure()
plot(rox1,res3,'.')
ylim(0,1000)
xlim(0,20)
# Out:
# <img src="data:image/png;base64,...">
# (0, 20)

# %%
figure()
plot(d2,res3,'.')
ylim(0,1000)
xlim(0,300)
# Out:
# <img src="data:image/png;base64,...">
# (0, 300)

# %%
d.tail()
# Out:
#                    time   diode ch1 temp   dio ch 2 temp   dio 3 temp  \
# 403852  20161004-221750            3.314           4.803        475.0
# 403853  20161004-221754            3.314           4.803        475.0
# 403854  20161004-221759            3.314           4.803        475.0
# 403855  20161004-221804            3.314           4.803        475.0
# 403856  20161004-221809            3.314           4.803        475.0
#
#          dio 4 temp   dio 1 volts   dio 2 volts   dio 3 volts   dio 4 volts  \
# 403852        475.0      1.616793      1.604938      0.021703      0.002510
# 403853        475.0      1.616786      1.604940      0.021749      0.002510
# 403854        475.0      1.616801      1.604967      0.021761      0.002513
# 403855        475.0      1.616787      1.604931      0.021734      0.002512
# 403856        475.0      1.616801      1.604955      0.021729      0.002511
#
#          rox 1 temp   rox 1 res   rox 2 temp   rox 2 res   rox 3 temp  \
# ...

# %%
figure()
plot(rox2[-15000:])
ylim(0,.3)
# Out:
# <img src="data:image/png;base64,...">
# (0, 0.3)

# %%
figure()
plot(rox1[-15000:])
ylim(0,.3)
# Out:
# <img src="data:image/png;base64,...">
# (0, 0.3)

# %%
180/4.
# Out:
# 45.0

# %%
figure()
plot(d1[-15000:])
plot(d2[-15000:])
# Out:
# <img src="data:image/png;base64,...">

# %%
1.5*100*200/3600.
# Out:
# 8.333333333333334

# %%
1.5*200
# Out:
# 300.0

# %%
31440896
# Out:
# 31440896

# %%
3232*4864*2
# Out:
# 31440896
