# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import kid_readout.analysis.process_mmw_response
# Out:
# no data directory set up for clouds defaulting to /data
# /home/gjones/anaconda/envs/readout/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
import joblib

# %%
pp = joblib.Parallel(n_jobs=16,verbose=5)

# %%
mmwa = [kid_readout.analysis.process_mmw_response.MmwResponse('/artemis/readout/2016-01-14_185445_mmw_frequency_sweep.nc',k) for k in range(16)]

# %%
mmwb = [kid_readout.analysis.process_mmw_response.MmwResponse('/artemis/readout/2016-01-14_212016_mmw_frequency_sweep.nc',k) for k in range(16)]

# %%
mmw = mmwb[10]

# %%
blah = mmw.plot()

# %%
mmw.aligned_data.shape
# Out:
# (500, 256)

# %%
plot(np.log10(np.abs(np.fft.rfft(mmw.mmw_frac_response))))

# %%
imshow(mmw.aligned_data.real)

# %%
plot(mmw.aligned_data.real.mean(0))

# %%
plot(mmw.zbd_voltage)
