# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import kid_readout.analysis.archive

# %%
df = kid_readout.analysis.archive.build_simple_archive(['/artemis/readout/pkl/2016-01-15_195108_sweep_and_stream.pkl'])

# %%
df.shape
# Out:
# (128, 92)

# %%
dd = df[(df.atten==20) & (df.timestream_modulation_duty_cycle==1)]
dd=dd.reset_index()

# %%
dd.shape
# Out:
# (32, 93)

# %%
fig,axs = subplots(8,4,figsize=(18,2*18))
for k,row in dd.iterrows():
    ax = axs.flatten()[k]
    ax.plot(row.sweep_freqs_MHz,20*np.log10(np.abs(row.sweep_s21)))

# %%
fig,axs = subplots(4,4,figsize=(18,18))
for k,row in dd.iterrows():
    ax = axs.flatten()[k]
    ax.plot(row.sweep_freqs_MHz,np.angle((row.sweep_s21*np.exp(-2j*np.pi*31.3*row.sweep_freqs_MHz))))
