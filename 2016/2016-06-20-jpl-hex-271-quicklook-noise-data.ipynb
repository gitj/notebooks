# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from kid_readout.interactive import *
# Out:
# INFO: 2016-06-23 11:59:18,002 - kid_readout.<module>:13  kid_readout logging setup with default stream handler

# %%
ncf = NCFile('/artemis/readout/2016-06-20_225728_off_on_cw_2_dB_dac.nc',)

# %%
# !ls -lhtr /artemis/readout/2016-06-20_225728_off_on_cw_2_dB_dac.nc
# Out:
# -rwxrwxr-x 1 500 500 1.3G Jun 20 23:01 /artemis/readout/2016-06-20_225728_off_on_cw_2_dB_dac.nc

# %%
ncf.

# %%
ssa = measurement.basic.SweepStreamArray(ncf.SweepArray0,ncf.StreamArray1)

# %%
ss = ssa.sweep_stream(29)

# %%
loglog(ss.S_frequency,ss.S_xx)

# %%
df = ssa.to_dataframe()

# %%
df.shape
# Out:
# (32, 90)

# %%
plot(df.res_f_0, df.res_Q_i,'o')

# %%
for k,row in df.iterrows():
    loglog(row.S_frequency,row.S_xx)

# %%
df.Q
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-3b7e8f1078e5> in <module>()
# ----> 1 df.Q
#
# /home/gjones/anaconda/envs/readout/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2667             if name in self._info_axis:
#    2668                 return self[name]
# -> 2669             return object.__getattribute__(self, name)
#    2670
#    2671     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Q'

# %%
ss.resonator.plot()
axvline(ss.stream.frequency)

# %%
loglog(ss.S_frequency,ss.S_xx-ss.S_yy)

loglog(ss.S_frequency,ss.S_yy)
loglog(ss.S_frequency,ss.S_xx)

# %%
np.abs(ss.stream.s21_raw).argmax()
# Out:
# 1366815

# %%
plot(ss.stream.s21_raw[1366815-100:1366815+100],'.-')

# %%
loglog(ss.S_frequency,ss.S_yy)
ss.S_frequency.max()
# Out:
# 13312.011957168579
