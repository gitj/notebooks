# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.append('/home/gjones/kid_readout')

# %%
import kid_readout.utils.readoutnc

# %%
rnc = kid_readout.utils.readoutnc.ReadoutNetCDF('/artemis/readout/2016-01-13_210104_scan_lo_1010.0_MHz_mmw_off.nc')

# %%
s21 = rnc.sweep_20160113211848.s21[:]

# %%
fr = rnc.sweep_20160113211848.frequency

# %%
figure(figsize=(18,6))
plot(fr,20*np.log10(np.abs(s21)))
ylim(-6,-3)
xlim(1035,1070)
# Out:
# (1035, 1070)

# %%
figure(figsize=(18,6))
plot(fr,20*np.log10(np.abs(s21)))
ylim(-8,-3)
xlim(1070,1135)
# Out:
# (1070, 1135)

# %%
figure(figsize=(18,6))
plot(fr,20*np.log10(np.abs(s21)))
ylim(-8,-3)
xlim(1130,1155)
# Out:
# (1130, 1155)

# %%
figure(figsize=(18,6))
plot(fr,20*np.log10(np.abs(s21)))
ylim(-20,-3)
xlim(1155,1235)
# Out:
# (1155, 1235)

# %%
fr.max()
# Out:
# 1235.9921875

# %%
rnc = kid_readout.utils.readoutnc.ReadoutNetCDF('/artemis/readout/2016-01-13_212757_scan_lo_1200.0_MHz_mmw_off.nc')
s21 = rnc.sweeps[0].s21[:]
fr = rnc.sweeps[0].frequency[:]

# %%
figure(figsize=(18,6))
plot(fr,20*np.log10(np.abs(s21)))
ylim(-10,3)
# Out:
# (-10, 3)

# %%
fr.min(),fr.max()
# Out:
# (1200.75, 1424.9921875)

# %%
figure(figsize=(18,6))
plot(fr,20*np.log10(np.abs(s21)))
ylim(-8,-3)
xlim(1320,1400)
# Out:
# (1320, 1400)

# %%
figure(figsize=(18,6))
plot(fr,20*np.log10(np.abs(s21)))
ylim(-8,0)
xlim(1260,1280)
# Out:
# (1260, 1280)

# %%
rnc = kid_readout.utils.readoutnc.ReadoutNetCDF('/artemis/readout/2016-01-13_213751_scan_lo_1390.0_MHz_mmw_off.nc')
s21 = rnc.sweeps[0].s21[:]
fr = rnc.sweeps[0].frequency[:]

# %%
fr.min(),fr.max()
# Out:
# (1390.75, 1614.9921875)

# %%
figure(figsize=(18,6))
plot(fr,20*np.log10(np.abs(s21)))
ylim(-10,2)
xlim(1400,1600)
# Out:
# (1400, 1600)

# %%
all_1_2 = np.array([1201.36, # MHz, 3 dB deep, width 600 kHz?, bad Q # no response to mmw seen

1269.15, #1 dB deep, width ~500 kHz, bad Q #no response to mmw seen

1433.5, #0.5 dB deep
1445.54, # ~0.3 dB deep #responds to mmw
1452.3, # ~0.5 dB deep # repsonds to mmw
1453.75, # < 1dB deep, ~150 kHz #responds to mmw
1465.3, # ~ 1 dB deep, ~200 kHz? wide
1494.9, # ~ 1 dB deep, 
1502.66, # ~ 0.5 dB deep, 
1503.675, # ~ 1 dB deep, ~150 kHz
1507.36, # <0.5 dB deep
1517.385, # <0.5 dB deep
1524.36, # < 0.5 dB deep #responds to mmw
1529.026, # MHz, 1.5 dB deep, width 150 kHz, Q around 10000? # responds to mmw
1531.97, # MHz, < 0.5 dB deep #responds to mmw
1537.0, # < 0.3 dB deep
1544.3, # ~1 dB
1557.4, # 1.2 dB, 200 kHz wide # responsds to mmw (1557.275 (on) → 1557.46 MHz (off))
1561.24, # 0.5 dB # responds to mmw
1588.15, # 8 dB deep, > 1 MHz wide # no obvious response to mmw
1601.5, # 3 dB deep, wide
1611.45, # 1 dB deep, #responds to mmw

1688.8, # 0.5 dB deep # no mmw response seen

1801.7, # 1 dB deep, ~1 MHz wide # no mmw response seen

1910.73, # 5 dB deep, ~200 kHz wide, Q~10000 #responds slightly to mmw

1964.6, # 0.7 dB deep

1984.731, # 4 dB deep, ~300 kHz wide
                    ])

# %%
rcParams['font.size']=18

# %%
figure(figsize=(18,6))
plot(fr,20*np.log10(np.abs(s21)))
ylim(-10,2)
xlim(1400,1600)
for res in all_1_2:
    gca().axvline(res,ymax=0.2,color='r')
    gca().axvline(res,ymin=0.8,color='r')
ylabel('S21 dB')
xlabel('MHz')
gca().xaxis.set_major_locator(MultipleLocator(10))
grid()
title('2016-01-13 JPL 2015-10-park dark cooldown')

# %%
figure(figsize=(18,6))
plot(fr,20*np.log10(np.abs(s21)))
ylim(-2,2)
xlim(1400,1450)
# Out:
# (1400, 1450)

# %%
figure(figsize=(18,6))
plot(fr,20*np.log10(np.abs(s21)))
ylim(-4,0)
xlim(1450,1500)
# Out:
# (1450, 1500)

# %%
figure(figsize=(18,6))
plot(fr,20*np.log10(np.abs(s21)))
ylim(-7,-2)
xlim(1500,1550)
# Out:
# (1500, 1550)

# %%
figure(figsize=(18,6))
plot(fr,20*np.log10(np.abs(s21)))
ylim(-9,-5)
xlim(1550,1600)
# Out:
# (1550, 1600)

# %%
figure(figsize=(18,6))
plot(fr,20*np.log10(np.abs(s21)))
ylim(-15,-12)
xlim(1600,1610)
# Out:
# (1600, 1610)

# %%
rnc = kid_readout.utils.readoutnc.ReadoutNetCDF('/artemis/readout/2016-01-13_214744_scan_lo_1580.0_MHz_mmw_off.nc')
s21 = rnc.sweeps[0].s21[:]
fr = rnc.sweeps[0].frequency[:]
fr.min(),fr.max()
# Out:
# (1580.75, 1804.9921875)

# %%
figure(figsize=(18,6))
plot(fr,20*np.log10(np.abs(s21)))

# %%
figure(figsize=(18,6))
plot(fr,20*np.log10(np.abs(s21)))
xlim(1580,1700)
ylim(-6,0)
# Out:
# (-6, 0)

# %%
rnc = kid_readout.utils.readoutnc.ReadoutNetCDF('/artemis/readout/2016-01-13_215738_scan_lo_1770.0_MHz_mmw_off.nc')
s21 = rnc.sweeps[0].s21[:]
fr = rnc.sweeps[0].frequency[:]
fr.min(),fr.max()
# Out:
# (1770.75, 1994.9921875)

# %%
figure(figsize=(18,6))
plot(fr,20*np.log10(np.abs(s21)))
ylim(-25,-7)
# Out:
# (-25, -7)

# %%
resonances_2016_01_13= np.array([
    1038.77,
    1043.49,
    1046.91,
    1050.33,
    1053.89, # very shallow
    1060.73,
    1079.19,
    #1092.14, #double
    #1092.5,
    #1096.4, # very shallow
    1098.1,
    1102.45,
    #1114.2, # double
    #1115.0, 
    1119.3, #slightly deeper
    1125.1,
    1130.95,
    1134.9,
    1144.75,
    1150.75, #deeper, 1dB
    1199.75, #4 dB deep
    
    ###
    1430.5,
    1441.4,
    #1445.13, # double
    #1445.67,
    1461.5, # double, but high Q so keep first of pair
    #1462.56, #second
    1491.1, # close, keep this one over next
    #1492.37,
    1500.4,
    1503.0,
    1515.45, # bit higher Q
    1522.3,
    1527.,
    1528.9, # small, prefer one before if they collide.
    1533.47,
    1541.9, #2.5 dB deep
    1553.4,
    1555.5,
    #1580.3, # super shallow
    1588.9, # 4 dB deep
    1605.7, # shallow
])

# %%
len(resonances_2016_01_13)
# Out:
# 32

# %%
np.save('/artemis/readout/resonances/2016-01-13-jpl-2015-10-park-dark-32-resonances-split-at-1300.npy',
       resonances_2016_01_13)

# %%
plot(np.diff(resonances_2016_01_13)/resonances_2016_01_13[1:],'o')
ylim(0,.03)
# Out:
# (0, 0.03)
