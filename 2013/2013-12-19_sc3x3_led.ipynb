# %%
import kid_readout.utils.plot_nc

# %%
swps = kid_readout.utils.plot_nc.get_all_sweeps('/home/data/2013-12-19_143516.nc')
# Out:
# failed to parse '\r' skipping
# failed to parse '\r' skipping
# failed to parse '\r' skipping

# %%
len(swps)
# Out:
# 88

# %%
for swp in swps[0:56:8]:
    #plot((swp.data*np.exp(1j*swp.delay*swp.f)).real/swp.A_mag,(swp.data*np.exp(1j*swp.delay*swp.f)).imag/swp.A_mag,'.-')
    plot(swp.f-swp.f_0,20*np.log10(abs(swp.model())))

# %%
for m in range(8):
    figure()
    semilogx([1,10,20,50,100,200,.1],[x.f_0 for x in swps[m:56:8]],'.')
