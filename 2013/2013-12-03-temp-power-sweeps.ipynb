# %%
import kid_readout.utils.plot_nc
reload(kid_readout.utils.plot_nc)
# Out:
# <module 'kid_readout.utils.plot_nc' from '/home/gjones/workspace/kid_readout/utils/plot_nc.py'>

# %%
import glob

# %%
files = ['/home/data/2013-12-03_165209.nc',
         '/home/data/2013-12-03_174822.nc',
         '/home/data/2013-12-04_094322.nc',
         '/home/data/2013-12-04_102845.nc',
         '/home/data/2013-12-04_110917.nc',
         '/home/data/2013-12-04_124749.nc',
         '/home/data/2013-12-04_142111.nc',
         '/home/data/2013-12-04_171233.nc',
         ]

# %%
swps = []
for fn in files:
    s = kid_readout.utils.plot_nc.get_all_sweeps(fn)
    swps.extend(s)
# Out:
# failed to parse '\r' skipping
# failed to parse '\r' skipping
# failed to parse '\r' skipping
# failed to parse
#  '\r' skipping
# failed to parse '\r' skipping
# failed to parse '\r' skipping
# failed to parse
#  '\r' skipping
# failed to parse '\r' skipping
# failed to parse '\r' skipping
# failed to parse
#  '\r' skipping
# failed to parse '\r' skipping
# failed to parse '\r' skipping
# failed to parse
#  '\r' skipping
# failed to parse '\r' skipping
# failed to parse '\r' skipping
# failed to parse
#  '\r' skipping
# failed to parse '\r' skipping
# failed to parse '\r' skipping
# failed to parse
#  '\r' skipping
# failed to parse '\r' skipping
# failed to parse '\r' skipping
# failed to parse
#  '\r' skipping
# failed to parse '\r' skipping
# failed to parse '\r' skipping

# %%
kid_readout.utils.plot_nc.plot_f0(swps)

# %%
kid_readout.utils.plot_nc.plot_mag_s21(swps)
# Out:
# 20

# %%
import kid_readout.analysis.noise_summary
reload(kid_readout.analysis.noise_summary)
# Out:
# <module 'kid_readout.analysis.noise_summary' from '/home/gjones/workspace/kid_readout/analysis/noise_summary.pyc'>

# %%
pkl = kid_readout.analysis.noise_summary.load_noise_pkl('/home/data/noise_2013-11-23_180536.pkl')

# %%
pkl

# %%
nn = pkl[0]

# %%
loglog(nn.fr_coarse,nn.prr_coarse)
