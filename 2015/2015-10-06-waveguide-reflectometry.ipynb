# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import glob

# %%
fns = glob.glob('/data/readout/mmw_sweeps/2015-09*.npz')
fns += glob.glob('/data/readout/mmw_sweeps/2015-10*.npz')
fns.sort()

# %%
z0 = z.copy()

# %%
zs = []
for fn in fns:
    d = np.load(fn)
    fr = d['mmw_freqs']
    z = d['zbd']
    zs.append(z)
    plot(fr/1e9,10*np.log10(z/z0))
xlim(150,155)    
#ylim(-10,0.01)
zs = np.array(zs)
# Out:
# /home/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:7: RuntimeWarning: divide by zero encountered in log10
# /home/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:7: RuntimeWarning: invalid value encountered in log10

# %%
zs.shape
# Out:
# (712, 1024)

# %%
plot(fr,zsn[-49:].T)
#plot(fr,zs[-2])
#plot(fr,zs[-1])
#yscale('log')
#ylim(1e-1,1)
xlim(150e9,152e9)
# Out:
# (150000000000.0, 152000000000.0)

# %%
plot(zs[-1]/zs[-2])
xlim(0,100)
# Out:
# (0, 100)

# %%
figure(figsize=(12,8))
imshow(zsn,aspect='auto',cmap=cm.cubehelix)
colorbar()
xlim(600,900)
# Out:
# (600, 900)

# %%
zsn = zs/zs[-2]

# %%
plot(zsn[:,610:621])

# %%
d = np.load('/data/readout/mmw_sweeps/2015-09-30_212221_cryo_waveguide_short.npz')

# %%
fr = d['mmw_freqs']
z = d['zbd']

# %%
plot(fr/1e9,10*np.log10(z),'.-')
xlim(150,155)
# Out:
# (150, 155)
