# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import kid_readout.roach.heterodyne
import kid_readout.equipment.hittite_controller

# %%
hc = kid_readout.equipment.hittite_controller.hittiteController(addr='192.168.0.200')

# %%
hc.on()

# %%
hc.set_freq(12.1e9)

# %%
ri = kid_readout.roach.heterodyne.RoachHeterodyne(adc_valon='/dev/ttyUSB0')

# %%
ri.set_lo(1230.)

# %%
ri.set_tone_freqs(np.load('/data/readout/resonances/2015-11-26-jpl-nevins-responsive-resonances.npy'),nsamp=2**16)
# Out:
# bank_offset= 0 start_offset= 0 start_offset_bytes= 0
# writing DRAM bank 0
# array([ 1126.6171875,  1138.6171875,  1144.5703125,  1149.296875 ,
#         1151.6015625,  1156.3984375,  1162.703125 ,  1169.703125 ,
#         1172.796875 ,  1178.3984375,  1184.5      ,  1193.796875 ,
#         1195.       ,  1203.6015625,  1208.203125 ,  1246.203125 ,
#         1248.25     ,  1258.8125   ,  1262.703125 ,  1265.203125 ,
#         1272.296875 ,  1273.203125 ,  1274.203125 ,  1274.796875 ,
#         1291.75     ,  1293.796875 ,  1301.796875 ,  1302.8984375,
#         1314.3984375,  1315.703125 ,  1320.296875 ,  1324.296875 ])

# %%
ri.set_dac_atten(20)

# %%
ri.set_modulation_output(7)
# Out:
# 122.0703125

# %%
ri.select_fft_bins(range(32))

# %%
ri._sync()

# %%
d,addr = ri.get_data(16)
# Out:
# detected mcnt overflow None 950277 0 65536 0 3376 950277

# %%
dm = d.reshape((-1,256,32))

# %%
imshow(dm[:,:,30].real,aspect='auto')

# %%
plot(dm.mean(0)[:,30].real)
