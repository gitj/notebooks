# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import kid_readout.roach.heterodyne
import time
import kid_readout.analysis.resonator
import kid_readout.analysis.khalil
import kid_readout.utils.data_file

# %%
ri = kid_readout.roach.heterodyne.RoachHeterodyne()

# %%
all_resonances = np.array([844.95,
             865.24,
             871.9,
             875.29,
             879.67,
             880.99,
             883.09,
             891.17,
             900.9,
             905.3,
             917.6,
             919.4,
             945.5,
             947.5,
             950.4,
             963.58,
             971.77,
             992.03,
             1002.93,
             1007.93,
             1015.6,
             1019.13,
             1027.3,
             1034.36,
             1039.54,
             ])

# %%
initial_f0s = np.concatenate((all_resonances[::2],all_resonances[1::2][0::3]))[:16]
initial_f0s.sort()
initial_f0s
# Out:
# array([  844.95,   865.24,   871.9 ,   879.67,   883.09,   891.17,
#          900.9 ,   917.6 ,   945.5 ,   947.5 ,   950.4 ,   971.77,
#         1002.93,  1015.6 ,  1027.3 ,  1039.54])

# %%
initial_atten = 30
atten_levels = [40,30,20,10,0]

# %%
ri.set_lo(930)

# %%
ri.set_fft_gain(4)

# %%
ri.lo_frequency
# Out:
# 930

# %%
import kid_readout.utils.sweeps
reload(kid_readout.utils.sweeps)
# Out:
# <module 'kid_readout.utils.sweeps' from '/home/gjones/readout/kid_readout/kid_readout/utils/sweeps.pyc'>

# %%
nsamp = 2**16
df = 512./nsamp
kid_readout.utils.sweeps.prepare_sweep(ri,center_freqs=initial_f0s,offsets=np.arange(-64,64)*df,
                                       nsamp=nsamp)
# Out:
# bank_offset= 0 start_offset= 0 start_offset_bytes= 0
# writing DRAM bank 0
# array([[  844.453125 ,   864.7421875,   871.3984375, ...,  1015.1015625,
#          1026.796875 ,  1039.0390625],
#        [  844.4609375,   864.75     ,   871.40625  , ...,  1015.109375 ,
#          1026.8046875,  1039.046875 ],
#        [  844.46875  ,   864.7578125,   871.4140625, ...,  1015.1171875,
#          1026.8125   ,  1039.0546875],
#        ...,
#        [  845.4296875,   865.71875  ,   872.375    , ...,  1016.078125 ,
#          1027.7734375,  1040.015625 ],
#        [  845.4375   ,   865.7265625,   872.3828125, ...,  1016.0859375,
#          1027.78125  ,  1040.0234375],
#        [  845.4453125,   865.734375 ,   872.390625 , ...,  1016.09375  ,
#          1027.7890625,  1040.03125  ]])

# %%
ri.set_dac_atten(initial_atten)

# %%
data_file = kid_readout.utils.data_file.DataFile(suffix='dark')

# %%
data_file.log_adc_snap(ri)
data_file.log_hw_state(ri)

# %%
tic = time.time()
swp = kid_readout.utils.sweeps.do_prepared_sweep(ri,nchan_per_step=16)
print time.time()-tic
data_file.add_sweep(swp)
# Out:
# detected mcnt overflow None 1081527 0 32768 0 48 1081527
# 67.2579779625
# 'sweep_20150626154143'

# %%
def fit_sweeps(swp):
    resonators = []
    lo = swp.blocks[0].lo
    fig,axs = subplots(4,4,figsize=(18,12))
    for k in range(swp.sweep_indexes.max()+1):
        fr,s21,err = swp.select_index(k)
        ax = axs.flatten()[k]
        fr,s21,err = swp.select_index(k)
        s21c = s21*np.exp(swp.hardware_delay_estimate*1e6j*2*np.pi*(fr-swp.lo[0]))
        res = kid_readout.analysis.resonator.fit_best_resonator(fr,s21c,errors=err,min_a=1.0)
        ax.plot(s21c.real,s21c.imag,'.-')
        modl = res.model(x=fr)
        ax.plot(modl.real,modl.imag,'.-')
        resonators.append(res)
    return resonators

# %%
resonators = fit_sweeps(swp)

# %%
updated_f0s = np.array([res.f_0 for res in resonators])
Qs = np.array([res.Q for res in resonators])
fwhm = updated_f0s/(2*Qs)
(updated_f0s - initial_f0s)*1e3
# Out:
# array([ -2.09414206,  -6.49251451,  -5.47055928,  31.5392041 ,
#         62.96473118,  -8.17220378,  45.38870704,  11.20810575,
#         15.04028218, -39.6701462 ,  22.60519189,  10.30881784,
#         20.89968863,  -1.22252243,  29.90238339,  -0.95261471])

# %%
fwhm
# Out:
# array([ 0.02840446,  0.03018044,  0.03068122,  0.0249015 ,  0.03494446,
#         0.02945839,  0.02529956,  0.03019714,  0.01567199,  0.01440139,
#         0.01227232,  0.01355717,  0.01397536,  0.01480816,  0.01644769,
#         0.01860336])

# %%
nsamp = 2**18
df = 512./nsamp
kid_readout.utils.sweeps.prepare_sweep(ri,center_freqs=updated_f0s,offsets=np.arange(-64,64)*df,
                                       nsamp=nsamp)
# Out:
# bank_offset= 0 start_offset= 0 start_offset_bytes= 0
# writing DRAM bank 0
#
# writing DRAM bank 1
# array([[  844.82226562,   865.109375  ,   871.76953125, ...,
#          1015.47460938,  1027.20507812,  1039.4140625 ],
#        [  844.82421875,   865.11132812,   871.77148438, ...,
#          1015.4765625 ,  1027.20703125,  1039.41601562],
#        [  844.82617188,   865.11328125,   871.7734375 , ...,
#          1015.47851562,  1027.20898438,  1039.41796875],
#        ...,
#        [  845.06640625,   865.35351562,   872.01367188, ...,
#          1015.71875   ,  1027.44921875,  1039.65820312],
#        [  845.06835938,   865.35546875,   872.015625  , ...,
#          1015.72070312,  1027.45117188,  1039.66015625],
#        [  845.0703125 ,   865.35742188,   872.01757812, ...,
#          1015.72265625,  1027.453125  ,  1039.66210938]])

# %%
tic = time.time()
fine_swp = kid_readout.utils.sweeps.do_prepared_sweep(ri,nchan_per_step=16)
print time.time()-tic
new_res = fit_sweeps(fine_swp)
new_f0s = np.array([res.f_0 for res in new_res])
# Out:
# detected mcnt overflow None 1605821 0 32768 0 448 1605821
# detected mcnt overflow None 1736894 0 32768 0 304 1736894
# 67.4593968391

# %%
ri.add_tone_freqs(new_f0s)
# Out:
# bank_offset= 2 start_offset= 67108864 start_offset_bytes= 0
# writing DRAM bank 2
# array([  844.94726562,   865.23242188,   871.88085938,   879.70117188,
#          883.15429688,   891.16210938,   900.9453125 ,   917.61132812,
#          945.515625  ,   947.4609375 ,   950.42382812,   971.78125   ,
#         1002.95117188,  1015.59960938,  1027.33007812,  1039.54101562])

# %%
sweeps = []
for atten in atten_levels:
    ri.set_dac_atten(atten)
    print "atten",atten
    tic = time.time()
    fine_swp = kid_readout.utils.sweeps.do_prepared_sweep(ri,nchan_per_step=16)
    print time.time()-tic
    sweeps.append(fine_swp)
    data_file.add_sweep(fine_swp)
    resonators = fit_sweeps(fine_swp)
    fit_f0s = np.array([res.f_0 for res in resonators])
    print "difference in resonant frequency, ppm:",(1e6*(new_f0s-fit_f0s)/new_f0s)
    ri.select_bank(ri.tone_bins.shape[0]-1)
    ri.select_fft_bins(range(ri.fft_bins.shape[1]))
    ri._sync()
    time.sleep(1)
    t0 = time.time()
    d,addr = ri.get_data(128)
    tsg = data_file.add_timestream_data(d,ri,t0)
    print time.time()-tic
# Out:
# atten 40
# detected mcnt overflow None 1474747 0 32768 0 320 1474747
# detected mcnt overflow None 1999036 0 32768 0 96 1999036
# 68.0275490284
# difference in resonant frequency, ppm: [-19.45887832  -5.72510735   0.64802143  -0.17438193   0.08209731
#   -0.97476615   1.81439117   0.03591988  -0.28373896  -0.58725708
#   -3.95013862   0.04393288   0.67646183  -0.22164367  -0.41500242
#    0.20033324]
# detected mcnt overflow None 32957 0 32768 0 12608 32957
# 102.052237988
# atten 30
# detected mcnt overflow None 1081531 0 32768 0 400 1081531
# detected mcnt overflow None 1212604 0 32768 0 336 1212604
# detected mcnt overflow None 1212605 0 32768 0 176 1212605
# detected mcnt overflow None 1474750 0 32768 0 128 1474750
# 67.8522319794
# difference in resonant frequency, ppm: [ 0.03992035 -0.26003916 -0.03429066  0.02442819  0.02576678  0.0135402
#  -0.03588272  0.09510284 -0.15794801 -0.27589768 -0.31275555  0.01268021
#  -0.09364598  0.08875037 -0.24116878 -0.15202913]
# detected mcnt overflow None 164029 0 32768 0 10240 164029
# 101.833692789
# atten 20
# detected mcnt overflow None 1736894 0 32768 0 448 1736894
# 67.8692851067
# difference in resonant frequency, ppm: [  4.48852089   2.48699367  -1.29120979  -0.34465887  -0.54902361
#    0.21515599  -0.5494891   -0.08958285  -0.71245131  -0.57105503
#   25.46163856  -0.58204333  -0.91285426  -0.7388547   -1.90378602
#   -0.4271946 ]
# detected mcnt overflow None 426173 0 32768 0 8272 426173
# 101.430037022
# atten 10
# detected mcnt overflow None 950462 0 32768 0 464 950462
# 67.961288929
# difference in resonant frequency, ppm: [  4.88107145   3.25955293  -3.28172493  -2.01186203  -3.04963802
#   -0.87078414  -2.17441767  -1.08671574  -2.8781281    1.53755941
#   91.80630348  -2.42741155  -2.82541631  -3.25241504  -3.2271879
#   -2.20922032]
# detected mcnt overflow None 164029 0 32768 0 5632 164029
# 101.83581686
# atten 0
# detected mcnt overflow None 1999036 0 32768 0 432 1999036
# detected mcnt overflow None 950461 0 32768 0 272 950461
# detected mcnt overflow None 1605822 0 32768 0 112 1605822
# 67.8646690845
# difference in resonant frequency, ppm: [   2.74002051    2.19865569   -2.5543291     4.03126193    1.22470371
#    -0.53473771    7.5191494    -1.21736218    1.8391618    26.87768697
#  -295.51682258    3.49859423    6.88157775    6.56257876   17.37519775
#    -1.38195424]
# detected mcnt overflow None 1867965 0 32768 0 3120 1867965
# 101.77317214

# %%
data_file.close()

# %%
import kid_readout.analysis.iqnoise
import kid_readout.utils.despike

# %%
dmod=d
fig,axs = subplots(4,4,figsize=(18,12))
for k in range(16):
    ax = axs.flatten()[k]
    despike = kid_readout.utils.despike.deglitch_window(dmod[:,k]-dmod[:,k].mean(),2**14)
    fr,S,evals,evects,angles,piq=kid_readout.analysis.iqnoise.pca_noise(despike,Fs=512e6/2**14)
    ax.loglog(fr,evals.T)
# Out:
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# /home/gjones/readout/kid_readout/kid_readout/analysis/iqnoise.py:75: ComplexWarning: Casting complex values to real discards the imaginary part
#   S[0,k] = ss[0,0]
# /home/gjones/readout/kid_readout/kid_readout/analysis/iqnoise.py:76: ComplexWarning: Casting complex values to real discards the imaginary part
#   S[1,k] = ss[1,1]

# %%
ri.tone_bins.shape
# Out:
# (129, 16)

# %%
new_res = fit_sweeps(fine_swp)

# %%
fr,s21,err = fine_swp.select_index(0)
fr.ptp()
# Out:
# 0.1240234375

# %%
new_f0s = np.array([res.f_0 for res in new_res])
newQs = np.array([res.Q for res in new_res])
fwhm = new_f0s/(2*newQs)
(new_f0s - initial_f0s)*1e3
# Out:
# array([ -2.75036198,  -8.36499499, -18.1566517 ,  27.45684   ,
#         29.52417282,   6.18154885,  62.34624514,  -7.40309064,
#         44.37014026,  -3.04533981,  11.30370433, -10.9906153 ,
#         13.04140384, -44.33065046,  19.85448771,   7.9253936 ])

# %%
fwhm
# Out:
# array([ 0.02912425,  0.03078778,  0.02714933,  0.0302079 ,  0.02514165,
#         0.02601062,  0.03599471,  0.02899567,  0.02582677,  0.02677329,
#         0.03062127,  0.03108903,  0.01615045,  0.01502604,  0.01341793,
#         0.01315327])

# %%
[res.delay for res in new_res]
# Out:
# [0.45141720942144958,
#  0.094586777665206123,
#  0.014686151981272174,
#  0.017796887808216814,
#  0.00043724074656971993,
#  0.011191579245233058,
#  0.0094185496420942927,
#  0.05758960001641613,
#  -0.0033176609419354351,
#  0.007291893632622024,
#  0.0079508120551642324,
#  -0.00077998325721197539,
#  0.0041570727965430238,
#  0.00093343481198936889,
#  -0.00047656048102172777,
#  0.011198239856341578]

# %%
newQs
# Out:
# array([ 14505.90628717,  14051.54439249,  16057.1507388 ,  14488.21970183,
#         17494.86702526,  16935.31803672,  12267.80757015,  15367.16899379,
#         17442.06407264,  16906.71882743,  14983.23560798,  14786.38738301,
#         29272.02800418,  31527.12783064,  35416.04611583,  36629.2168434 ])

# %%
Qs
# Out:
# array([ 14512.79042247,  13616.48574293,  15691.05110949,  14375.85548433,
#         17343.44571994,  17473.09661493,  12115.91118983,  15196.59562753,
#         17542.05628817,  16683.89496554,  14765.47493265,  14619.13718965,
#         27945.16383875,  29094.679821  ,  33561.02764402,  34569.66638804])

# %%
new_f0s
# Out:
# array([ 844.94724964,  865.23163501,  871.88184335,  875.31745684,
#         879.69952417,  880.99618155,  883.15234625,  891.16259691,
#         900.94437014,  905.29695466,  917.6113037 ,  919.38900938,
#         945.5130414 ,  947.45566935,  950.41985449,  963.58792539])

# %%
ri.set_tone_freqs(new_f0s,nsamp=2**18)
# Out:
# bank_offset= 0 start_offset= 0 start_offset_bytes= 0
# writing DRAM bank 0
# array([ 844.94726562,  865.23242188,  871.8828125 ,  875.31835938,
#         879.69921875,  880.99609375,  883.15234375,  891.16210938,
#         900.9453125 ,  905.296875  ,  917.61132812,  919.38867188,
#         945.51367188,  947.45507812,  950.41992188,  963.58789062])

# %%
ri.select_fft_bins(range(16))

# %%
ri.set_dac_atten(10)

# %%
dmod,addr = ri.get_data(128)
# Out:
# detected mcnt overflow None 1310485 0 32768 0 26224 1310485

# %%
dmod.shape
# Out:
# (524288, 16)

# %%
import kid_readout.analysis.iqnoise
import kid_readout.utils.despike

# %%
dmod = d

# %%
fig,axs = subplots(4,4,figsize=(18,12))
for k in range(16):
    ax = axs.flatten()[k]
    despike = kid_readout.utils.despike.deglitch_window(dmod[:,k]-dmod[:,k].mean(),2**14)
    fr,S,evals,evects,angles,piq=kid_readout.analysis.iqnoise.pca_noise(despike,Fs=512e6/2**14)
    ax.loglog(fr,evals.T)
#    ax.xaxis.set_scale('symlog')
# Out:
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10
# using NFFT: 2** 16.0
# 10

# %%
ts = dmod[:,3]
despike = kid_readout.utils.despike.deglitch_window(dmod[:,3]-dmod[:,3].mean(),2**14)

# %%
Qs
# Out:
# array([ 14512.79042247,  13616.48574293,  15691.05110949,  14375.85548433,
#         17343.44571994,  17473.09661493,  12115.91118983,  15196.59562753,
#         17542.05628817,  16683.89496554,  14765.47493265,  14619.13718965,
#         27945.16383875,  29094.679821  ,  33561.02764402,  34569.66638804])

# %%
plot(np.abs(ts))

# %%
plot(np.abs(despike))

# %%
blah = psd(despike,NFFT=2**16,Fs=512e6/2**14)
xscale('symlog')

# %%
fig,axs = subplots(4,4,figsize=(12,12))
for k in range(16):
    ax = axs.flatten()[k]
    fr,s21,err = swp.select_index(k)
    ax.plot(fr,20*np.log10(np.abs(s21)))

# %%
import kid_readout.analysis.resonator
import kid_readout.analysis.khalil

# %%
fig,axs = subplots(4,4,figsize=(12,12))
for k in range(16):
    ax = axs.flatten()[k]
    fr,s21,err = swp.select_index(k)
    s21c = s21*np.exp(-31.2j*2*np.pi*(fr-ri.lo_frequency))
    ax.plot(fr,np.angle(s21c))

# %%
fig,axs = subplots(4,4,figsize=(12,12))
for k in range(16):
    ax = axs.flatten()[k]
    fr,s21,err = swp.select_index(k)
    s21c = s21*np.exp(-31.2j*2*np.pi*(fr-ri.lo_frequency))
    ax.plot(s21c.real,s21c.imag,'.-')

# %%
fig,axs = subplots(4,4,figsize=(18,12))
for k in range(16):
    ax = axs.flatten()[k]
    fr,s21,err = swp.select_index(k)
    s21c = s21*np.exp(-31.3j*2*np.pi*(fr-ri.lo_frequency))
    print fr.max(),fr.min()
    res = kid_readout.analysis.resonator.fit_best_resonator(fr,s21c,errors=err,min_a=1.0)
    ax.plot(s21c.real,s21c.imag,'.-')
    modl = res.model(x=fr)
    ax.plot(modl.real,modl.imag,'.-')
    print res.Q,res.Q_i,res.Q_e_real,res.Q_e_imag,res.delay
    try:
        ax.set_title(str(res.a))
    except:
        pass
# Out:
# 845.1953125 844.703125
# 14509.7893985 14510.444072 0.472129867535 -12322.2285727 0.0800919642239
# 865.484375 864.9921875
# 13217.4273966 13217.884756 0.760819793999 -17047.7298542 0.0100592267738
# 872.140625 871.6484375
# 15307.4575411 16953.022477 783.67883999 -11089.3188141 0.000493518101752
# 875.53125 875.0390625
# 13887.2248591 31777.5032586 1563.03520456 6009.36525281 0.0160531714692
# 879.9140625 879.421875
# 16758.0974406 29862.4133242 3680.38495625 11269.6055095 0.00194483158019
# 881.234375 880.7421875
# 16811.7420033 20299.9183079 7482.62873315 26001.8731006 0.00126192586539
# 883.3359375 882.84375
# 11713.1545005 28560.3193672 898.400288419 4127.01665023 -0.00358999245783
# 891.4140625 890.921875
# 14772.6694893 14773.5314117 0.368098003745 -9654.26705551 0.0142959632228
# 901.140625 900.6484375
# 16935.1407938 17823.343019 1244.08575013 20523.9908142 -0.00552956651021
# 905.5390625 905.046875
# 16206.3700044 18077.653404 444.903903596 -8334.11105078 0.00199650798053
# 917.84375 917.3515625
# 14529.9086211 16900.1738871 612.55440239 -7942.60824443 0.00121988048269
# 919.640625 919.1484375
# 14351.5065163 16683.3597428 4735.90239217 -21537.1051022 -0.00363068073597
# 945.7421875 945.25
# 25598.3024867 26147.4362025 916.290544591 -33406.7622447 0.00749992002079
# 947.7421875 947.25
# 26917.1531645 27457.0178179 9082.55947413 111136.68848 0.00318163776775
# 950.640625 950.1484375
# 30079.5107202 30944.2110397 26091.6145969 165544.389128 -0.00104425035141
# 963.8203125 963.328125
# 31406.3521038 32600.335947 965.884752194 -28763.2852163 0.00618733417802

# %%
ax = gca()
fr,s21,err = swp.select_index(4)
s21c = s21*np.exp(-31.3j*2*np.pi*(fr-ri.lo_frequency))
print fr.max(),fr.min()
res = kid_readout.analysis.resonator.fit_best_resonator(fr[25:-25],s21c[25:-25],errors=err[25:-25],min_a=1.0)
ax.plot(s21c.real,s21c.imag,'.-')
modl = res.model(x=res.freq_data)
ax.plot(modl.real,modl.imag,'.-')
print res.Q,res.Q_i,res.Q_e_real,res.Q_e_imag,res.delay
figure()
plot(fr,np.abs(s21c))
plot(res.freq_data,np.abs(modl))
plot(res.freq_data,np.abs(res.model(x=res.freq_data)))
# Out:
# 879.9140625 879.421875
# 16824.6691064 30191.5952085 3740.63904884 11320.6719853 -0.000457328720674

# %%
1/(1/res.Q-1/np.abs(res.Q_e_real+1j*res.Q_e_imag))
# Out:
# 36322.665100510239

# %%
res.Q
# Out:
# 13711.847040231984

# %%
res.Q_i
# Out:
# 15899.183778596402

# %%
blks = [blk for blk in swp.blocks if blk.sweep_index==2]

# %%
blk = blks[0]

# %%
figure(figsize=(18,4))
for blk in blks[:10]:
    pxx,frl = mlab.psd(blk.data,Fs=512e6/2**14)
    f1 = blk.tone*512e6/blk.nsamp
    plot(frl+f1+930e6,10*np.log10(pxx))

# %%
len(blks)
# Out:
# 128

# %%
by_index = [[blk for blk in swp.blocks if blk.sweep_index==k] for k in range(16)]

# %%
for idx in range(16):
    blk = by_index[idx][8]
    pxx,frl = mlab.psd(blk.data,Fs=512e6/2**14)
    f1 = blk.tone*512e6/blk.nsamp
    plot(frl+f1+930e6,10*np.log10(pxx))
xlim(944e6,951e6)
# Out:
# (944000000.0, 951000000.0)

# %%
fr,s21,err = swp.select_index(2)

# %%
fr.min()
# Out:
# 949.8984375

# %%
initial_f0s[14:15]
# Out:
# array([ 950.4])

# %%
nsamp = 2**16
df = 512./nsamp
kid_readout.utils.sweeps.prepare_sweep(ri,center_freqs=initial_f0s[14:15],offsets=np.arange(-64,64)*df,
                                       nsamp=nsamp)
# Out:
# bank_offset= 0 start_offset= 0 start_offset_bytes= 0
# writing DRAM bank 0
# array([[ 949.8984375],
#        [ 949.90625  ],
#        [ 949.9140625],
#        [ 949.921875 ],
#        [ 949.9296875],
#        [ 949.9375   ],
#        [ 949.9453125],
#        [ 949.953125 ],
#        [ 949.9609375],
#        [ 949.96875  ],
#        [ 949.9765625],
#        [ 949.984375 ],
#        [ 949.9921875],
#        [ 950.       ],
#        [ 950.0078125],
#        [ 950.015625 ],
#        [ 950.0234375],
#        [ 950.03125  ],
#        [ 950.0390625],
#        [ 950.046875 ],
#        [ 950.0546875],
#        [ 950.0625   ],
#        [ 950.0703125],
#        [ 950.078125 ],
#        [ 950.0859375],
#        [ 950.09375  ],
#        [ 950.1015625],
#        [ 950.109375 ],
#        [ 950.1171875],
#        [ 950.125    ],
#        [ 950.1328125],
#        [ 950.140625 ],
#        [ 950.1484375],
#        [ 950.15625  ],
#        [ 950.1640625],
#        [ 950.171875 ],
#        [ 950.1796875],
#        [ 950.1875   ],
#        [ 950.1953125],
#        [ 950.203125 ],
#        [ 950.2109375],
#        [ 950.21875  ],
#        [ 950.2265625],
#        [ 950.234375 ],
#        [ 950.2421875],
#        [ 950.25     ],
#        [ 950.2578125],
#        [ 950.265625 ],
#        [ 950.2734375],
#        [ 950.28125  ],
#        [ 950.2890625],
#        [ 950.296875 ],
#        [ 950.3046875],
#        [ 950.3125   ],
#        [ 950.3203125],
#        [ 950.328125 ],
#        [ 950.3359375],
#        [ 950.34375  ],
#        [ 950.3515625],
#        [ 950.359375 ],
#        [ 950.3671875],
#        [ 950.375    ],
#        [ 950.3828125],
#        [ 950.390625 ],
#        [ 950.3984375],
#        [ 950.40625  ],
#        [ 950.4140625],
#        [ 950.421875 ],
#        [ 950.4296875],
#        [ 950.4375   ],
#        [ 950.4453125],
#        [ 950.453125 ],
#        [ 950.4609375],
#        [ 950.46875  ],
#        [ 950.4765625],
#        [ 950.484375 ],
#        [ 950.4921875],
#        [ 950.5      ],
#        [ 950.5078125],
#        [ 950.515625 ],
#        [ 950.5234375],
#        [ 950.53125  ],
#        [ 950.5390625],
#        [ 950.546875 ],
#        [ 950.5546875],
#        [ 950.5625   ],
#        [ 950.5703125],
#        [ 950.578125 ],
#        [ 950.5859375],
#        [ 950.59375  ],
#        [ 950.6015625],
#        [ 950.609375 ],
#        [ 950.6171875],
#        [ 950.625    ],
#        [ 950.6328125],
#        [ 950.640625 ],
#        [ 950.6484375],
#        [ 950.65625  ],
#        [ 950.6640625],
#        [ 950.671875 ],
#        [ 950.6796875],
#        [ 950.6875   ],
#        [ 950.6953125],
#        [ 950.703125 ],
#        [ 950.7109375],
#        [ 950.71875  ],
#        [ 950.7265625],
#        [ 950.734375 ],
#        [ 950.7421875],
#        [ 950.75     ],
#        [ 950.7578125],
#        [ 950.765625 ],
#        [ 950.7734375],
#        [ 950.78125  ],
#        [ 950.7890625],
#        [ 950.796875 ],
#        [ 950.8046875],
#        [ 950.8125   ],
#        [ 950.8203125],
#        [ 950.828125 ],
#        [ 950.8359375],
#        [ 950.84375  ],
#        [ 950.8515625],
#        [ 950.859375 ],
#        [ 950.8671875],
#        [ 950.875    ],
#        [ 950.8828125],
#        [ 950.890625 ]])

# %%
ri.set_dac_atten(40)

# %%
tic = time.time()
swp = kid_readout.utils.sweeps.do_prepared_sweep(ri,nchan_per_step=1)
print time.time()-tic
# Out:
# detected mcnt overflow None 22667977 0 2048 0 16 22667977
# 55.4558930397

# %%
plot(swp.freqs,20*np.log10(np.abs(swp.data)))
