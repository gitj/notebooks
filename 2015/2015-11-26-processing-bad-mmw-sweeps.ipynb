# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import kid_readout.analysis.process_mmw_response
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
mmws = [kid_readout.analysis.process_mmw_response.MmwResponse('/data/readout/2015-11-24_172031_mmw_frequency_sweep.nc',k) for k in range(16)]

# %%
blah = mmw.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c132a28735d5> in <module>()
# ----> 1 blah = mmw.plot()
#
# NameError: name 'mmw' is not defined

# %%
for mmw in mmws:
    blah = mmw.plot()

# %%
mmw = mmws[12]

# %%
s21c = mmw.sweep_s21*np.exp(2j*np.pi*mmw.sweep_freq*31.3)

# %%
plot(s21c.real,s21c.imag)

# %%
plot(mmw.sweep_freq,np.abs(s21c))
