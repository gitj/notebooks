# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import kid_readout.utils.readoutnc

# %%
import glob

# %%
files = glob.glob('/data/detectors/2015-06-2*.nc')

# %%
files.sort()

# %%
for fn in files:
    try:
        rnc = kid_readout.utils.readoutnc.ReadoutNetCDF(fn)
        print fn,len(rnc.sweeps),len(rnc.timestreams)
        rnc.close()
    except:
        print "broken file",fn
# Out:
# broken file /data/detectors/2015-06-26_135015_dark.nc
# /data/detectors/2015-06-26_135847_dark.nc 9 5
# /data/detectors/2015-06-26_142600_dark.nc 7 6
# /data/detectors/2015-06-26_151943_dark.nc 6 5
# /data/detectors/2015-06-26_154035_dark.nc 6 5
# /data/detectors/2015-06-26_171018_dark.nc 6 5
# /data/detectors/2015-06-26_173844_dark.nc 6 5
# /data/detectors/2015-06-26_180144_dark.nc 6 5
# /data/detectors/2015-06-26_182443_dark.nc 6 5
# /data/detectors/2015-06-26_222304_dark.nc 6 5
# /data/detectors/2015-06-27_015155_dark.nc 11 10
# /data/detectors/2015-06-27_053941_dark.nc 18 17

# %%
# !rm /data/detectors/2015-06-26_135015_dark.nc

# %%
import kid_readout.utils.hpd_temps

# %%
rnc = kid_readout.utils.readoutnc.ReadoutNetCDF('/data/detectors/2015-06-26_135847_dark.nc')
for sweep in rnc.sweeps:
    fr,s21,err = sweep.select_by_index(0)
    print rnc.get_effective_dac_atten_at(sweep.end_epoch),kid_readout.utils.hpd_temps.get_temperatures_at(sweep.end_epoch)
    plot(fr,20*np.log10(np.abs(s21)))
# Out:
# (30.0, 52.04119982655925) (0.1629793301998349, None, 2.697999954223633, None)
# (30.0, 52.04119982655925) (0.1627398833779476, None, 2.6979331840562617, None)
# (30.0, 52.04119982655925) (0.16275204888312253, None, 2.6970125425848117, None)
# (30.0, 52.04119982655925) (0.16274507277351252, None, 2.697999954223633, None)
# (30.0, 52.04119982655925) (0.1627274481669332, None, 2.697000026702881, None)
# (30.0, 52.04119982655925) (0.16270765015807803, None, 2.697000026702881, None)
# (30.0, 52.04119982655925) (0.16279678795903754, None, 2.697000026702881, None)
# (30.0, 52.04119982655925) (0.16273705529741186, None, 2.697999954223633, None)
# (30.0, 52.04119982655925) (0.1628097939616982, None, 2.697000026702881, None)

# %%
rnc.close()

# %%
rnc = kid_readout.utils.readoutnc.ReadoutNetCDF('/data/detectors/2015-06-26_142600_dark.nc')
for sweep in rnc.sweeps:
    fr,s21,err = sweep.select_by_index(0)
    print rnc.get_effective_dac_atten_at(sweep.end_epoch),kid_readout.utils.hpd_temps.get_temperatures_at(sweep.end_epoch)
    plot(fr,20*np.log10(np.abs(s21)))
# Out:
# (30.0, 52.04119982655925) (0.16272833245753524, None, 2.697000026702881, None)
# (30.0, 52.04119982655925) (0.16279060428204817, None, 2.697000026702881, None)
# (30.0, 52.04119982655925) (0.16280207660535845, None, 2.697000026702881, None)
# (30.0, 52.04119982655925) (0.16281819927133728, None, 2.697000026702881, None)
# (30.0, 52.04119982655925) (0.1627461036653185, None, 2.697000026702881, None)
# (30.0, 52.04119982655925) (0.16281548027099238, None, 2.697000026702881, None)
# (30.0, 52.04119982655925) (0.16283221634999162, None, 2.697000026702881, None)

# %%
rnc.close()

# %%
#100mK
rnc = kid_readout.utils.readoutnc.ReadoutNetCDF('/data/detectors/2015-06-27_015155_dark.nc')
for sweep in rnc.sweeps:
    fr,s21,err = sweep.select_by_index(0)
    print rnc.get_effective_dac_atten_at(sweep.end_epoch),kid_readout.utils.hpd_temps.get_temperatures_at(sweep.end_epoch)
    plot(fr,20*np.log10(np.abs(s21)))
rnc.close()
# Out:
# (30.0, 52.04119982655925) (0.108646397654154, None, 2.7009999752044678, None)
# (40.0, 62.04119982655925) (0.10887099500180482, None, 2.700000047683716, None)
# (30.0, 52.04119982655925) (0.1090172875459255, None, 2.700000047683716, None)
# (20.0, 42.04119982655925) (0.10915995159863048, None, 2.700000047683716, None)
# (15.0, 37.04119982655925) (0.10934138674195869, None, 2.700000047683716, None)
# (10.0, 32.04119982655925) (0.10932156850122657, None, 2.700000047683716, None)
# (8.0, 30.04119982655925) (0.10950256117270672, None, 2.6991952888137414, None)
# (6.0, 28.04119982655925) (0.10968038493229812, None, 2.6989998817443848, None)
# (4.0, 26.04119982655925) (0.10986821618482853, None, 2.6989998817443848, None)
# (2.0, 24.04119982655925) (0.11009613081295148, None, 2.700000047683716, None)
# (0.0, 22.04119982655925) (0.11039009278019954, None, 2.6998919038423894, None)

# %%
# 150 mK
# atten_levels = [40,30,20,10,0]
rnc = kid_readout.utils.readoutnc.ReadoutNetCDF('/data/detectors/2015-06-26_151943_dark.nc')
for sweep in rnc.sweeps:
    fr,s21,err = sweep.select_by_index(0)
    print rnc.get_effective_dac_atten_at(sweep.end_epoch),kid_readout.utils.hpd_temps.get_temperatures_at(sweep.end_epoch)
    plot(fr,20*np.log10(np.abs(s21)))
rnc.close()
# Out:
# (30.0, 52.04119982655925) (0.16289804544087616, None, 2.697000026702881, None)
# (30.0, 52.04119982655925) (0.16290499697320657, None, 2.697000026702881, None)
# (30.0, 52.04119982655925) (0.1628817227096655, None, 2.697000026702881, None)
# (30.0, 52.04119982655925) (0.16294393128569082, None, 2.697000026702881, None)
# (30.0, 52.04119982655925) (0.16297238298208755, None, 2.697000026702881, None)
# (30.0, 52.04119982655925) (0.16311605071367277, None, 2.697000026702881, None)

# %%
# 160 mK
rnc = kid_readout.utils.readoutnc.ReadoutNetCDF('/data/detectors/2015-06-27_053941_dark.nc')
for sweep in rnc.sweeps:
    fr,s21,err = sweep.select_by_index(0)
    print rnc.get_effective_dac_atten_at(sweep.end_epoch),kid_readout.utils.hpd_temps.get_temperatures_at(sweep.end_epoch)
    plot(fr,20*np.log10(np.abs(s21)))
rnc.close()
# Out:
# (30.0, 52.04119982655925) (0.17397395263085122, None, 2.696000099182129, None)
# (40.0, 62.04119982655925) (0.1732980376394192, None, 2.696000099182129, None)
# (30.0, 52.04119982655925) (0.17330271860508006, None, 2.696000099182129, None)
# (20.0, 42.04119982655925) (0.17329972141883626, None, 2.696000099182129, None)
# (15.0, 37.04119982655925) (0.17327040866663682, None, 2.696000099182129, None)
# (13.0, 35.04119982655925) (0.17327109040804617, None, 2.696000099182129, None)
# (11.0, 33.04119982655925) (0.1732816300891727, None, 2.696000099182129, None)
# (10.0, 32.04119982655925) (0.17328918684839442, None, 2.696000099182129, None)
# (9.0, 31.04119982655925) (0.173311820238122, None, 2.697000026702881, None)
# (8.0, 30.04119982655925) (0.17329630162346565, None, 2.697000026702881, None)
# (7.0, 29.04119982655925) (0.17331773910010523, None, 2.6967412174931056, None)
# (6.0, 28.04119982655925) (0.1732720149041348, None, 2.696000099182129, None)
# ...

# %%
# 200 mK
# atten: [40,30,20,10,0]
rnc = kid_readout.utils.readoutnc.ReadoutNetCDF('/data/detectors/2015-06-26_154035_dark.nc')
for sweep in rnc.sweeps:
    fr,s21,err = sweep.select_by_index(0)
    print rnc.get_effective_dac_atten_at(sweep.end_epoch),kid_readout.utils.hpd_temps.get_temperatures_at(sweep.end_epoch)
    plot(fr,20*np.log10(np.abs(s21)))
rnc.close()
# Out:
# (30.0, 52.04119982655925) (0.20852490590144518, None, 2.697000026702881, None)
# (30.0, 52.04119982655925) (0.2166030015661496, None, 2.697000026702881, None)
# (30.0, 52.04119982655925) (0.21643586391607106, None, 2.6973710301229143, None)
# (30.0, 52.04119982655925) (0.21640484054672962, None, 2.697999954223633, None)
# (30.0, 52.04119982655925) (0.2163482774324669, None, 2.697000026702881, None)
# (30.0, 52.04119982655925) (0.2163218949132519, None, 2.6979835149771167, None)

# %%
# 250 mK
# atten: [40,30,20,10,0]
rnc = kid_readout.utils.readoutnc.ReadoutNetCDF('/data/detectors/2015-06-26_171018_dark.nc')
for sweep in rnc.sweeps:
    fr,s21,err = sweep.select_by_index(0)
    print rnc.get_effective_dac_atten_at(sweep.end_epoch),kid_readout.utils.hpd_temps.get_temperatures_at(sweep.end_epoch)
    plot(fr,20*np.log10(np.abs(s21)))
rnc.close()
# Out:
# (30.0, 52.04119982655925) (0.2709499866310864, None, 2.6989998817443848, None)
# (30.0, 52.04119982655925) (0.2705896595400272, None, 2.697999954223633, None)
# (30.0, 52.04119982655925) (0.27049483229857696, None, 2.697999954223633, None)
# (30.0, 52.04119982655925) (0.2704154392564111, None, 2.697999954223633, None)
# (30.0, 52.04119982655925) (0.2704586157112959, None, 2.697999954223633, None)
# (30.0, 52.04119982655925) (0.2705134512351461, None, 2.697999954223633, None)

# %%
/data/detectors/2015-06-26_173844_dark.nc  280 mK
/data/detectors/2015-06-26_180144_dark.nc 300 mK
/data/detectors/2015-06-26_182443_dark.nc 320 mK
/data/detectors/2015-06-26_222304_dark.nc 350 mK
