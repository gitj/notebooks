# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
npz = np.load('/home/gjones/2015-07-01-starcryo-nevins-initial-sweep.npz')

# %%
npz.keys()
# Out:
# ['lo', 'freq', 'data']

# %%
fr = npz['freq']
d = npz['data']

# %%
plot(fr,20*np.log10(np.abs(d)))
grid()
ylim(-40,-20)
xlim(1200,1250)
# Out:
# (1200, 1250)

# %%
plot(np.abs(d2))

# %%
fig,axs = subplots(8,4,figsize=(12,24))
for k in range(32):
    axs.flatten()[k].plot(np.abs(d[k::32]))

# %%
d2 = d.copy()

# %%
d2[::32] = np.nan
d2[2::32] = np.nan
d2[30::32] = np.nan
frmask = np.abs(fr-1330) < 3
d2[frmask] = np.nan

# %%
rcParams['font.size']=20

# %%
figure(figsize=(18,6))
plot(fr[np.isfinite(d2)],20*np.log10(np.abs(d2[np.isfinite(d2)])))
grid()
ylim(-40,-20)
xlim(1200,1460)
xlabel('MHz')
ylabel('Transmission [dB]')
savefig('/home/gjones/2015-07-06-StarCryo-dualpol-nevins-sweep.pdf',bbox_inches='tight')
