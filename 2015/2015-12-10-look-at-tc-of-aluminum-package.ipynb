# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
blah = pd.read_csv('/data/readout/SRS/20151121-181057.txt')

# %%
blah.columns
# Out:
# Index([u'time', u' diode ch1 temp', u' dio ch 2 temp', u' dio 3 temp', u' dio 4 temp', u' dio 1 volts', u' dio 2 volts', u' dio 3 volts', u' dio 4 volts', u' rox 1 temp', u' rox 1 res', u' rox 2 temp', u' rox 2 res', u' rox 3 temp', u' rox 3 res'], dtype='object')

# %%
plot(blah[' rox 3 res'],',')
ylim(0,10e-3)
# Out:
# (0, 0.01)

# %%
rcParams['font.size']=18

# %%
plot(blah[' rox 1 temp'],blah[' rox 3 res']*1e6,',')
xlim(.8,1.4)
#xscale('log')
yscale('log')
ylim(10,6000)
gca().axvline(1.08)
text(1.1,20,'$T_c\sim 1.08$ K',size='large')
ylabel('Bridge Resistance ($\mu\Omega$)')
xlabel('Package Temperature (K)')
grid()

# %%
plot(blah[' rox 1 temp'],blah[' rox 3 res']*1e6,',')
xlim(.8,20)
#xscale('log')
#yscale('log')
ylim(40,60)
# Out:
# (40, 60)
