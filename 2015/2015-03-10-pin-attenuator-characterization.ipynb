# %%
d1 = np.load('/home/data2/rtl/2015-03-10_16-14-49_pin_atten_character_4.000000_4.000000_turns.npz')
d2 = np.load('/home/data2/rtl/2015-03-10_16-20-41_pin_atten_character_4.000000_4.000000_turns.npz')
d3 = np.load('/home/data2/rtl/2015-03-10_16-47-06_pin_atten_character_5.000000_5.000000_turns.npz')
d4 = np.load('/home/data2/rtl/2015-03-10_16-56-00_pin_atten_character_6.000000_6.000000_turns.npz')

# %%
d2.keys()
# Out:
# ['zbd_voltage', 'pin_bias_voltage', 'mmw_atten_turns']

# %%
plot(d2['pin_bias_voltage'],10*np.log10(d2['zbd_voltage']/d2['zbd_voltage'].max()),'.-')
plot(d3['pin_bias_voltage'],10*np.log10(d3['zbd_voltage']/d3['zbd_voltage'].max()),'.-')
plot(d4['pin_bias_voltage'],10*np.log10(d4['zbd_voltage']/d4['zbd_voltage'].max()),'.-')
ax = gca()
ax.axhline(-3,color='k')
xlim(0,1.1)
ylim(-10,0)
grid()
