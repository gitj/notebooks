# %%
import kid_readout.utils.readoutnc

# %%
rnc = kid_readout.utils.readoutnc.ReadoutNetCDF('/home/data2/2015-05-05_093834_magnetic_pickup.nc')

# %%
rnc.timestream_20150505094612.fftbin
# Out:
# array([ 6150,  6527,  6969,  7187,  7507,  8180, 12051, 12489, 12765,
#        13124, 13379, 13990, 14056, 14075, 15088, 15348], dtype=int32)

# %%
rnc.timestream_20150505094612.tonebin
# Out:
# array([393492, 417648, 445920, 459837, 480358, 523424, 801655, 773599,
#        755950, 732961, 716637, 677530, 673295, 672102, 607231, 590612], dtype=int32)

# %%
rnc.timestream_20150505094612.measurement_freq
# Out:
# array([  96.06738281,  101.96484375,  108.8671875 ,  112.26489258,
#         117.27490234,  127.7890625 ,  195.71655273,  188.86694336,
#         184.55810547,  178.94555664,  174.96020508,  165.41259766,
#         164.37866211,  164.08740234,  148.24975586,  144.19238281])

# %%
fbin = np.fft.fftfreq(2**14,d=1/256.)
fbin[2**13:] = 128-fbin[2**13:]

# %%
fcs = fbin[rnc.timestream_20150505094612.fftbin-1]

# %%
fcs
# Out:
# array([  96.078125,  101.96875 ,  108.875   ,  112.28125 ,  117.28125 ,
#         127.796875,  195.71875 ,  188.875   ,  184.5625  ,  178.953125,
#         174.96875 ,  165.421875,  164.390625,  164.09375 ,  148.265625,
#         144.203125])

# %%
plot(fcs)

# %%
plot(fcs-rnc.timestream_20150505094612.measurement_freq)
ax = gca()
ax.axhline(256/2.**14)
ax.axhline(-256/2.**14)

# %%
rnc = kid_readout.utils.readoutnc.ReadoutNetCDF('/home/data2/2015-05-04_170050_magnetic_pickup.nc')

# %%
fcs = fbin[rnc.timestreams[0].fftbin-1]

# %%
plot(fcs-rnc.timestreams[0].measurement_freq)
ax = gca()
ax.axhline(256/2.**14)
ax.axhline(-256/2.**14)

# %%
rnc = kid_readout.utils.readoutnc.ReadoutNetCDF('/home/data2/2015-05-04_124159_mmwnoise_narrow.nc')

# %%
fcs = fbin[rnc.timestreams[0].fftbin-1]

# %%
plot(fcs-rnc.timestreams[0].measurement_freq)
ax = gca()
ax.axhline(256/2.**15)
ax.axhline(-256/2.**15)

# %%
x = np.random.randn(1e6) + 1j*np.random.randn(1e6)

# %%
np.abs(x).mean()
# Out:
# 1.2541562904052295

# %%
np.sqrt(np.pi/2)
# Out:
# 1.2533141373155001

# %%
np.abs(x).std()
# Out:
# 0.65577152745140399

# %%
_/_63
# Out:
# 0.52287863360276909

# %%
np.sqrt((4-np.pi)/2)
# Out:
# 0.65513637756203358

# %%
fx = np.fft.fft(x)/1000.

# %%
np.abs(fx).mean()
# Out:
# 1.254541783496524

# %%
np.abs(fx).std()
# Out:
# 0.65503374755833166

# %%
import kid_readout.analysis.archive
# Out:
# updated file list
# /home/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
import glob

# %%
pkls = glob.glob('/home/data/pkl/*.pkl')

# %%
len(pkls)
# Out:
# 1639

# %%
random.randint?

# %%
fn
# Out:
# '/home/data/pkl/noise_2014-03-02_210550.pkl'

# %%
fn # No pulsetube
# Out:
# '/home/data/pkl/noise_sweeps_2014-08-21_005136_net.pkl'

# %%
fn = pkls[random.randint(0,len(pkls))]
fn
# Out:
# '/home/data/pkl/2014-12-19_165412_mmwnoisestep.pkl'

# %%
pkl =kid_readout.analysis.archive.load_noise_pkl(fn)

# %%
type(pkl)
# Out:
# dict

# %%
pkl.keys()
# Out:
# ['noise_modulated_measurements', 'noise_on_measurements', 'noise_off_sweeps']

# %%
import kid_readout.analysis.noise_measurement

# %%
import os

# %%
import cPickle

# %%
1/2.
# Out:
# 0.5

# %%
for fn in pkls:
    try:
        pkl =kid_readout.analysis.archive.load_noise_pkl(fn)
    except:
        print "couldn't unpickle",fn
        continue
        nm = kid_readout.analysis.noise_measurement.SweepNoiseMeasurement('/home/data/'+os.path.splitext(os.path.split(fn)[1])[0]+'.nc')
    if type(pkl) is dict:
        if len(pkl['noise_on_measurements']):
            nm = pkl['noise_on_measurements'][0]
        else:
            print fn,"has no noise on measurements"
            continue
    else:
        if len(pkl):
            nm = pkl[0]
        else:
            print fn,"has no nms"
            continue
    if not hasattr(nm,'pca_freq'):
        if not hasattr(nm,'pca_fr'):
            print fn,"has no pca"
    del nm
    del pkl
# Out:
# /home/data/pkl/noise_2013-12-10_132548.pkl has no pca
# /home/data/pkl/noise_sweeps_2014-07-22_205258_net.pkl
#  has no nms
# /home/data/pkl/noise_sweeps_2014-06-16_235736_test.pkl
#  has no nms
# couldn't unpickle
#  /home/data/pkl/noise_2013-11-27_151641.pkl
# /home/data/pkl/noise_2013-11-23_194806.pkl
#  has no pca
# /home/data/pkl/noise_2014-02-01_144835.pkl
#  has no pca
# couldn't unpickle
#  /home/data/pkl/noise_2013-11-27_131506.pkl
# /home/data/pkl/noise_2014-02-01_011449.pkl
#  has no pca
# /home/data/pkl/noise_2013-11-22_181052.pkl has no pca
# /home/data/pkl/noise_2014-01-29_220701.pkl
#  has no pca
# /home/data/pkl/noise_2014-02-10_153924.pkl
#  has no pca
# couldn't unpickle
#  /home/data/pkl/2015-04-22_190947_mmw_frequency_sweep.pkl
# /home/data/pkl/noise_2014-02-01_010105.pkl
#  has no pca
# /home/data/pkl/noise_2014-01-29_221542.pkl
#  has no pca
# /home/data/pkl/noise_sweeps_2014-05-08_165631_net_compressor_onoff.pkl
#  has no nms
# ...

# %%
pkl = kid_readout.analysis.archive.load_noise_pkl('/home/data/pkl/noise_2014-02-01_222817.pkl')

# %%
nmold = pkl[0]

# %%
nmold.params
# Out:
# 19.5

# %%
nm  = pkl[0]

# %%
nm.f

# %%
nm.power_dbm
# Out:
# 41.0

# %%
nm.timestream_epoch
# Out:
# 1417026917.4288621

# %%
#loglog(nm.fr_fine,nm.pii_fine)
loglog(nm.fr_fine,nm.prr_fine)

# %%
nm.index
# Out:
# 0

# %%
nm.f0
# Out:
# 79.296630859375

# %%
blah = nm.plot()
# Out:
# /home/local/lib/python2.7/site-packages/numpy/core/numeric.py:462: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-3a62de36f482> in <module>()
# ----> 1 blah = nm.plot()
#
# /home/gjones/kid_readout/kid_readout/analysis/noise_summary.pyc in plot(self, fig, title)
#     302         ax2.loglog(self.fr_coarse[1:],self.prr_coarse[1:],'y',lw=2)
#     303         ax2.loglog(self.fr_coarse[1:],self.pii_coarse[1:],'m',lw=2)
# --> 304         ax2.loglog(self.pca_fr[1:],self.pca_evals[:,1:].T,'k',lw=2)
#     305         ax2.set_title(title,fontdict=dict(size='small'))
#     306
#
# AttributeError: 'NoiseMeasurement' object has no attribute 'pca_fr'

# %%
nm.chip
# Out:
# 'StarCryo_5x4_0813F10'

# %%
nm.power_dbm
# Out:
# -61.5

# %%
fn
# Out:
# '/home/data/pkl/noise_2013-11-27_151641.pkl'

# %%
pkl
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-54c7e5cfb853> in <module>()
# ----> 1 pkl
#
# NameError: name 'pkl' is not defined

# %%
nm = pkl[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-55937ea961cc> in <module>()
# ----> 1 nm = pkl[0]
#
# KeyError: 0

# %%
blah = nm.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-3a62de36f482> in <module>()
# ----> 1 blah = nm.plot()
#
# /home/gjones/kid_readout/kid_readout/analysis/noise_measurement.py in plot(self, fig, title)
#     585
#     586         freqs_fine,prr_fine,pii_fine = self.get_projected_fractional_fluctuation_spectra(NFFT=2**18)
# --> 587         ax2.loglog(freqs_fine[1:],prr_fine[1:],'b',label='Srr')
#     588         ax2.loglog(freqs_fine[1:],pii_fine[1:],'g',label='Sii')
#     589         ax2.loglog(self.freqs_coarse[1:],self.prr_coarse[1:],'y',lw=2)
#
# /home/local/lib/python2.7/site-packages/matplotlib/axes.pyc in loglog(self, *args, **kwargs)
#    4271         b = self._hold
#    4272         self._hold = True  # we've already processed the hold
# -> 4273         l = self.plot(*args, **kwargs)
#    4274         self._hold = b  # restore the hold
#    4275
#
# ...

# %%
loglog(nm.pca_freq,nm.pca_eigvals[1,:])

# %%
loglog(nm.pca_fr,nm.pca_evals[1,:])

# %%
nm.pca_eigvals[1,np.argmin(np.abs(nm.pca_freq-2.8))]
# Out:
# 8.342109075228658e-15

# %%
nm.optical_load
# Out:
# 'dark'
