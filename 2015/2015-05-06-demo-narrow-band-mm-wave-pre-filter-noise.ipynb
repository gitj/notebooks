# %%
import kid_readout.analysis.noise_measurement
import kid_readout.utils.readoutnc
# Out:
# updated file list
# /home/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
rnc = kid_readout.utils.readoutnc.ReadoutNetCDF('/home/data2/2015-05-06_163621_mmwnoise_narrow_no_output_filter.nc')

# %%
pkl = kid_readout.analysis.noise_measurement.load_noise_pkl('/home/data/pkl/2015-05-06_163621_mmwnoise_narrow_no_output_filter.pkl')

# %%
pkl.keys()
# Out:
# ['noise_modulated_measurements', 'noise_on_measurements', 'noise_off_sweeps']

# %%
nm = pkl['noise_on_measurements'][0]

# %%
blah = nm.plot()

# %%
pkl2 = kid_readout.analysis.noise_measurement.load_noise_pkl('/home/data/pkl/2015-05-06_165940_mmwnoise_narrow_no_output_filter.pkl')

# %%
nm2 = pkl2['noise_on_measurements'][26]

# %%
loglog(nm.pca_freq,nm.pca_eigvals[1,:])
loglog(nm.pca_freq,nm2.pca_eigvals[1,:])

# %%
nm2.atten
# Out:
# 26.0

# %%
for nm in pkl2['noise_on_measurements']:
    if (nm.atten == 41) & (nm.resonator_index==5):
        loglog(nm.pca_freq,nm.pca_eigvals.T,'r')
for nm in pkl['noise_on_measurements']:
    if (nm.atten == 41) & (nm.resonator_index==5):
        loglog(nm.pca_freq,nm.pca_eigvals.T,'k')

# %%
plot(nm.fractional_fluctuation_timeseries.real,nm.fractional_fluctuation_timeseries.imag,',')
