# %%
import kid_readout.analysis.archive
# Out:
# updated file list
# /home/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
import glob

# %%
npys = glob.glob('/home/gjones/detmnt/archive/2014-12-12*.npy')
npys.sort()

# %%
dfs = [kid_readout.analysis.archive.load_archive(x) for x in npys]

# %%
import pandas

# %%
df2 = kid_readout.analysis.archive.build_simple_archives('/home/gjones/detmnt/pkl/2014-12-15*.pkl')

# %%
df = pandas.concat(dfs,ignore_index=True)

# %%
df.shape
# Out:
# (2944, 91)

# %%
r0 = df[df.resonator_id==0]

# %%
import kid_readout.analysis.noise_fit

# %%
df = kid_readout.analysis.archive.add_noise_fits(df)

# %%
semilogy(df.noise_fit_fc)

# %%
semilogy(df.noise_fit_device_noise,'.')
ylim(1e-21,1e-16)
# Out:
# (1e-21, 1e-16)

# %%
r0 = df[(df.resonator_id==10) & (df.atten==45) &(df.timestream_modulation_freq==0)]

# %%
plot(df.timestream_modulation_freq)

# %%
df = kid_readout.analysis.archive.add_noise_summary(df)

# %%
loglog(1-r0.f_0/r0.f_0.max(),r0.noise_fit_device_noise,'.')
loglog(1-r0.f_0/r0.f_0.max(),r0.device_noise-r0.amplifier_noise,'x')

ylim(1e-18,1e-16)
# Out:
# (1e-18, 1e-16)

# %%
semilogy(r0.zbd_voltage,r0.noise_fit_device_noise,'.')

# %%
def add_ptp(x):
    if not np.all(np.isfinite(x.folded_projected_timeseries.iloc[0])):
        return x
    x['source_ptp'] = np.abs(x.folded_projected_timeseries.iloc[0].mean(0)).ptp()
    return x

# %%
df = df.groupby(df.index).apply(add_ptp)

# %%
r0.shape
# Out:
# (18, 97)

# %%
plot(df.source_ptp)

# %%
plot(df.f_0,df.source_ptp,'.')

# %%
semilogy(df.zbd_voltage,df.source_ptp,'.')

# %%
for k in range(16):
    print k, df[df.resonator_id==k].f_0.max()
# Out:
# 0 77.5079004266
# 1 84.6751144228
# 2 86.2996079156
# 3 92.2875738504
# 4 103.483985832
# 5 109.323051248
# 6 111.637686032
# 7 116.125171826
# 8 119.603992379
# 9 159.659580617
# 10 156.108899485
# 11 150.0092777
# 12 141.711894772
# 13 135.05431641
# 14 134.641003965
# 15 133.901848468

# %%
from kid_readout.analysis.resources.skip5x4 import coordinate_array, nominal_frequencies

# %%
156.25/nominal_frequencies
# Out:
# array([ 1.5625    ,  1.48809524,  1.42045455,  1.35869565,  1.30208333,
#         1.20192308,  1.15740741,  1.11607143,  1.07758621,  1.04166667,
#         0.9469697 ,  0.94553707,  0.94410876,  0.94268477,  0.94126506,
#         0.89285714,  0.86805556,  0.84459459,  0.82236842,  0.80128205])

# %%
semilogy(df.f_0,df.f_0_err/df.f_0,'.')

# %%
scatter(coordinate_array[:,0],coordinate_array[:,1])
for k in range(20):
    x,y = coordinate_array[k,:]
    text(x,y,str(nominal_frequencies[k]*.8))

# %%
r0.folded_projected_timeseries
# Out:
# 166     NaN
# 326     NaN
# 486     NaN
# 646     NaN
# 806     NaN
# 966     NaN
# 1126    NaN
# 1286    NaN
# 1446    NaN
# 1606    NaN
# 1766    NaN
# 1926    NaN
# 2086    NaN
# 2246    NaN
# 2406    NaN
# 2566    NaN
# 2726    NaN
# 2886    NaN
# Name: folded_projected_timeseries, dtype: object

# %%
for k,row in r0.iterrows():
    loglog(row.pca_freq,row.pca_eigvals[1,:])
ylim(1e-18,1e-15)
# Out:
# (1e-18, 1e-15)

# %%
df.shape
# Out:
# (2944, 100)

# %%
r0 = df[(df.resonator_id==10) & (df.atten==45)]# &(df.timestream_modulation_freq==0)]

# %%
plot(r0.f_0,r0.noise_fit_device_noise,'.')

# %%
plot(r0.source_ptp,r0.noise_fit_device_noise,'.')

# %%
plot(r0.f_0,'.')

# %%
plot(r0.zbd_voltage)

# %%
plot(r0.sweep_primary_package_temperature)

# %%
r0.shape
# Out:
# (18, 100)

# %%
semilogy(df.resonator_id,df.Q,'.')
ylim(1e4,1e6)
# Out:
# (10000.0, 1000000.0)

# %%
df2 = df2.sort(['sweep_epoch'])

# %%
r0 = df2[(df2.resonator_id==0) &(df2.atten==45)]

# %%
plot(1-r0.f_0/r0.f_0.max(),'.')

# %%
plot(r0.sweep_primary_package_temperature)

# %%
np.log10
# Out:
# <ufunc 'log10'>

# %%
for k,row in r0.iterrows():
    plot(row.sweep_freqs_MHz,20*np.log10(abs(row.sweep_s21)))
xlim(77.5,77.51)
# Out:
# (77.5, 77.51)
