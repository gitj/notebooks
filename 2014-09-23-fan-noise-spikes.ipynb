# %%
import kid_readout.analysis.noise_measurement
reload(kid_readout.analysis.noise_measurement)
# Out:
# Could not find any temperature log files in /home/heather/SRS/
# updated file list
# C:\Users\gjones\WinPython-64bit-2.7.6.4\python-2.7.6.amd64\lib\site-packages\matplotlib\__init__.py:1172: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# <module 'kid_readout.analysis.noise_measurement' from 'C:\Users\gjones\kid_readout\kid_readout\analysis\noise_measurement.pyc'>

# %%
import glob
fns = glob.glob('/home/data2/*mmwnoise*.nc')
fns.sort()

# %%
nms = [kid_readout.analysis.noise_measurement.SweepNoiseMeasurement(
fn,delay_estimate=-63.0, resonator_index=k
) for fn in fns for k in range(16)]
# Out:
# Could not find any temperature log files in /home/heather/SRS/
# updated file list
# Could not find any temperature log files in /home/heather/SRS/
# updated file list
# using NFFT: 2**
#  16.0
# 10
# Could not find any temperature log files in /home/heather/SRS/
# updated file list
# Could not find any temperature log files in /home/heather/SRS/
# updated file list
# using NFFT: 2**
#  16.0
# 10
# Could not find any temperature log files in /home/heather/SRS/
# updated file list
# Could not find any temperature log files in /home/heather/SRS/
# updated file list
# using NFFT: 2**
#  16.0
# 10
# Could not find any temperature log files in /home/heather/SRS/
# updated file list
# Could not find any temperature log files in /home/heather/SRS/
# updated file list
# using NFFT: 2**
#  16.0
# 10
# Could not find any temperature log files in /home/heather/SRS/
# updated file list
# Could not find any temperature log files in /home/heather/SRS/
# updated file list
# using NFFT: 2**
#  16.0
# ...

# %%
for nm in nms:
    semilogx(nm.pca_freq,nm.pca_eigvals[1,:])
ylim(1e-19,4e-17)
# Out:
# (1e-19, 4e-17)

# %%
blah = nm.plot()

# %%
nm.normalized_timeseries.shape
# Out:
# (524288L,)

# %%
plot(abs(nm.normalized_timeseries[:1000]))

# %%
plot(nm.normalized_timeseries.real,nm.normalized_timeseries.imag,',')

# %%
plot(nm.fractional_fluctuation_timeseries[:1000])
# Out:
# C:\Users\gjones\WinPython-64bit-2.7.6.4\python-2.7.6.amd64\lib\site-packages\numpy\core\numeric.py:460: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
psd(nms[0].fractional_fluctuation_timeseries.real,NFFT=2**17,Fs=256e6/2**14,
    color='r')
xlim(0,200)
ax = gca()
ax.axvline(6)
ax.axvline(25)
ax.axvline(60)
ax.axvline(70)
ax.axvline(141)
ax.axvline(1.4*2)
ax.axvline(141*4)

# %%
141*4
# Out:
# 564

# %%
print 1/(141*64e-6)
per = floor(111)
# Out:
# 110.815602837

# %%
141*np.arange(20)
# Out:
# array([   0,  141,  282,  423,  564,  705,  846,  987, 1128, 1269, 1410,
#        1551, 1692, 1833, 1974, 2115, 2256, 2397, 2538, 2679])

# %%
141/21.
# Out:
# 6.714285714285714

# %%
rr = nm.fractional_fluctuation_timeseries[:per*(len(nm.fractional_fluctuation_timeseries)//per)].reshape((-1,per))

# %%
rr.shape
# Out:
# (4723L, 111L)

# %%
rr.dtype
# Out:
# dtype('complex64')

# %%
figure(figsize=(4,12))
imshow(rr.real,aspect='auto')
colorbar()
clim(-1e-6,1e-6)

# %%
plot(rr.mean(0))

# %%
plot(nm.fractional_fluctuation_timeseries.real[::111])

# %%
plot([nm.resonator_model.Q for nm in nms])

# %%
plot([nm.resonator_index for nm in nms])

# %%
fig,axs = subplots(nrows=4,ncols=4,figsize=(18,12))
for nm in nms:
    k = nm.resonator_index
    ax = axs.flatten()[k]
    ax.loglog(nm.pca_freq,nm.pca_eigvals[1,:])
for k,ax in enumerate(axs.flatten()):
    ax.set_ylim(1e-19,1e-15)
    ax.text(0.1,0.9,('%d %.6f'%(k,nms[k].resonator_model.f_0)),size='small',transform=ax.transAxes)

# %%
nm2 = kid_readout.analysis.noise_measurement.SweepNoiseMeasurement(fns[-1],delay_estimate=-63.0,low_pass_cutoff_Hz=1000.0,deglitch_threshold=10000)
# Out:
# Could not find any temperature log files in /home/heather/SRS/
# updated file list
# Could not find any temperature log files in /home/heather/SRS/
# updated file list
# using NFFT: 2**
#  16.0
# 10

# %%
psd(nm2.low_pass_projected_timeseries.real,NFFT=2**12)
# Out:
# (array([  3.03916408e+03,   1.82438165e+03,   1.91229040e+02, ...,
#           4.68390849e-02,   3.85687661e-02,   2.60950946e-02]),
#  array([  0.00000000e+00,   4.88281250e-04,   9.76562500e-04, ...,
#           9.99023438e-01,   9.99511719e-01,   1.00000000e+00]))

# %%
nm2.low_pass_projected_timeseries.shape
# Out:
# (34885L,)

# %%
plot(nm2.low_pass_projected_timeseries.real,nm2.low_pass_projected_timeseries.imag)

# %%
plot(nm2.normalized_timeseries.real,nm2.normalized_timeseries.imag,'.')

# %%
plot(nm2.fractional_fluctuation_timeseries.real[53900:54000])
