# %%
import kid_readout.analysis.archive
# Out:
# updated file list
# /home/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
df1 = kid_readout.analysis.archive.load_archive('/home/gjones/detmnt/archive/2015-01-14_145435_continous_cooling.npy')

# %%
df1.shape
# Out:
# (672, 88)

# %%
df2 = kid_readout.analysis.archive.load_archive('/home/gjones/detmnt/archive/2015-02-13_120307_led.npy')

# %%
for resid in [0,1]:
    r1 = df1[df1.resonator_id==resid]
    r2 = df2[(df2.resonator_id==resid) & (df2.timestream_modulation_duty_cycle==1)]
    figure()
    plot(r1.sweep_primary_load_temperature,r1.f_0,'.')
    plot(r2.sweep_primary_package_temperature,r2.f_0,'x',mew=2)
    if resid==1:
        x=np.linspace(0,80,1000)
        plot(x,158/np.sqrt(1+(x/98.)**4))
    if resid==0:
        x=np.linspace(0,80,1000)
        plot(x,201.5/np.sqrt(1+(x/80.)**4))
        ylim(190,205)
    #ylim(100,2e4)
#    xscale('log')
#    yscale('log')

# %%
for k,row in df1[df1.resonator_id==1].iterrows():
    if row.f_0 < (158/np.sqrt(1+(row.sweep_primary_load_temperature/98.)**4)):
        color='k'
        lw = 1
    else:
        color = 'r'
        lw=2
    plot(row.sweep_model_freqs_MHz,20*np.log10(abs(row.sweep_model_normalized_s21)),color=color,alpha=.5,lw=lw)

# %%
10e9/64.
# Out:
# 156250000.0

# %%
160*(np.array([1-.077/2,1+0.077/2]))
# Out:
# array([ 153.84,  166.16])

# %%
140*(np.array([1-.15/2,1+0.15/2]))
# Out:
# array([ 129.5,  150.5])

# %%
140*(np.array([1-.12/2,1+0.12/2]))
# Out:
# array([ 131.6,  148.4])
