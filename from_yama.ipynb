# %%
import pyfits

# %%
import glob

# %%
files = glob.glob('///data/ebex/ld2012/flight/raw/acs_v0-0/xsc0/files/data/images/2013-01-01/*.fits')

# %%
files.sort()

# %%
len(files)
# Out:
# 1939

# %%
def get_data(fn):
    fh = pyfits.open(fn)
    x = fh[0].data[:]
    fh.close()
#    x = x/x.mean(0)[None,:]/x.mean(1)[:,None]
    return x

# %%
x = get_data(files[-100])

# %%
x.shape
# Out:
# (1024, 1536)

# %%
blah = hist(x.flatten(),bins=100)

# %%
ff = np.abs(np.fft.fftshift(np.fft.fft2(x-x.mean())))

# %%
ff.shape
# Out:
# (1024, 1536)

# %%
imshow(np.log(ff),aspect='auto')

# %%
loglog(ff[512,768:])

# %%
loglog(ff[512:,768])
ylim(1e5,1e7)
loglog(np.arange(512),np.arange(512)**-7)
grid()
