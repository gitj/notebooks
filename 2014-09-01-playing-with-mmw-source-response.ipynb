# %%
import kid_readout.analysis.noise_measurement
SweepNoiseMeasurement = kid_readout.analysis.noise_measurement.SweepNoiseMeasurement
# Out:
# updated file list
# /home/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
nm = SweepNoiseMeasurement('/home/data2/2014-08-29_230701_mmw.nc',deglitch_threshold=7000000, resonator_index=0, delay_estimate=-63)
# Out:
# updated file list
# ...
# log file is: /home/heather/SRS/20140827-155701.txt, last requested time is Fri Aug 29 23:04:48 2014
# ...
# log file is: /home/heather/SRS/20140827-155701.txt, last requested time is Fri Aug 29 23:07:28 2014
# 0 2048 rejecting 0.0
# 0 4096 rejecting 0.0
# 2048 6144 rejecting 0.0
# 4096 8192 rejecting 0.0
# using NFFT: 2** 10.0
# 10

# %%
plot(nm.sweep_freqs_MHz,np.angle(nm.sweep_normalized_s21))

# %%
plot(nm.sweep_freqs_MHz,np.angle(nm.sweep_normalized_s21))
plot(nm.sweep_model_freqs_MHz,np.angle(nm.sweep_model_normalized_s21))

# %%
plot(1/nm.timeseries_sample_rate*np.arange(nm.fractional_fluctuation_timeseries.shape[0]),1e6*nm.fractional_fluctuation_timeseries.real)
plot(1/nm.timeseries_sample_rate*np.arange(nm.fractional_fluctuation_timeseries.shape[0]),1e6*nm.fractional_fluctuation_timeseries.imag)

# %%
blah = psd(nm.fractional_fluctuation_timeseries.real,Fs=256e6/2**14,NFFT=8192)

xscale('log')

# %%
loglog(nm.pca_eigvals[1,:])
loglog(nm.pca_eigvals[0,:])

# %%
d = nm.timestream.data[:,:]

# %%
d.shape
# Out:
# (32000, 8192)

# %%
dn = nm.resonator_model.project_s21_to_delta_freq(nm.noise_measurement_freq_MHz,d,s21_already_normalized=False,use_data_mean=False)

# %%
import kid_readout.analysis.fit_pulses
reload(kid_readout.analysis.fit_pulses)
reload(kid_readout.analysis.fit_pulses.fitter)
# Out:
# <module 'kid_readout.analysis.fitter' from '/home/gjones/kid_readout/kid_readout/analysis/fitter.pyc'>

# %%
realf,imagf = kid_readout.analysis.fit_pulses.fit_complex_square_wave(dn[0,:],period=625)

# %%
import lmfit

# %%
plot(dn[0,:].real)
xlim(0,500)
# Out:
# (0, 500)

# %%
lmfit.report_fit(rr.params)
# Out:
# [[Variables]]
#      high_level:     35.794147 +/- 0.000000 (0.00%) initial =  35.794147
#      low_level:      11.360432 +/- 0.000000 (0.00%) initial =  11.360432
#      period:        fixed
#      phase:          83.834773 +/- 0.000000 (0.00%) initial =  83.834773
# [[Correlations]] (unreported correlations are <  0.100)

# %%
rr=lmfit.minimize(realf.residual,realf.result.params,method='lbfgsb')

# %%
ii = lmfit.minimize(imagf.residual,imagf.result.params,method='anneal')
lmfit.report_fit(imagf.result.params)
# Out:
# [[Variables]]
#      high_level:     1.937671 +/- 0.000000 (0.00%) initial =  9.679039
#      low_level:     -0.359693 +/- 0.000000 (-0.00%) initial = -11.750580
#      period:        fixed
#      phase:          410.207700 +/- 0.000000 (0.00%) initial =  312.500001
# [[Correlations]] (unreported correlations are <  0.100)

# %%
rr.params
# Out:
# Parameters([('period', <Parameter 'period', value=value=625 +/- 0 (fixed), bounds=[-inf:inf]>), ('low_level', <Parameter 'low_level', value=11.360431895705176 +/- 0, bounds=[-16.517209916207513:21.643209613152898]>), ('high_level', <Parameter 'high_level', value=35.794147295767331 +/- 0, bounds=[21.643209613152898:55.701921216488877]>), ('phase', <Parameter 'phase', value=83.83477256193008 +/- 0, bounds=[0:625]>)])

# %%
realf.residual()
# Out:
# array([ -2.82786376,   0.64152749,  -7.30768251, ..., -11.24263768,
#        -10.07985037,  -1.78121222])

# %%
lmfit.minimize?

# %%
plot(kid_readout.analysis.fit_pulses.square_wave_model(realf.result.params,np.arange(8192)))
plot(dn[0,:].real)
plot(kid_readout.analysis.fit_pulses.square_wave_model(realf.result.params,np.arange(8192)))
xlim(0,1000)
# Out:
# (0, 1000)

# %%
plot(imagf.residual())
plot(kid_readout.analysis.fit_pulses.square_wave_model(imagf.result.params,np.arange(8192)))

# %%
plot(realf.residual())
xlim(0,500)
# Out:
# (0, 500)

# %%
imagf.result.params
# Out:
# Parameters([('period', <Parameter 'period', value=value=625 +/- 0 (fixed), bounds=[-inf:inf]>), ('low_level', <Parameter 'low_level', value=-11.750579720054594 +/- 0, bounds=[-22.465389244768616:0.27752833369686059]>), ('high_level', <Parameter 'high_level', value=9.6790393293734507 +/- 0, bounds=[0.27752833369686059:20.393848854087473]>), ('phase', <Parameter 'phase', value=312.50000054270993 +/- 0, bounds=[0:625]>)])

# %%
nm.resonator_model.project_s21_to_delta_freq?

# %%
nm.atten
# Out:
# 39.0

# %%
plot(dn.flatten()[::1000].real)
ylim(-100,100)
# Out:
# (-100, 100)

# %%
dn.shape
# Out:
# (2000, 8192)

# %%
8192/625
# Out:
# 13

# %%
13*625
# Out:
# 8125

# %%
imshow(dn[:,:8125].reshape((-1,13,625)).mean(1).real,aspect='auto')

# %%
dnf = dn[:,:8125].reshape((-1,13,625)).mean(1)

# %%
dnf.shape
# Out:
# (2000, 625)

# %%
pdb
# Out:
# Automatic pdb calling has been turned OFF

# %%
import kid_readout.analysis.fit_pulses
reload(kid_readout.analysis.fit_pulses)
reload(kid_readout.analysis.fit_pulses.fitter)
# Out:
# <module 'kid_readout.analysis.fitter' from '/home/gjones/kid_readout/kid_readout/analysis/fitter.pyc'>

# %%
kid_readout.analysis.fit_pulses.find_high_low(dnf[110,:],debug=True,use_fraction=0.5)
# Out:
# ((27.801132061270849+0.33249633612423563j),
#  (6.0311450270895364+1.5499129384819796j))

# %%
blah = plot(np.abs(dnf[::100,:]).T)

# %%
blah = plot(np.cumsum(np.diff(np.abs(dnf[::100,:]),axis=1)>10,axis=1).T)

# %%
np.searchsorted(np.cumsum(np.diff(np.abs(dnf[100,:]))>10),.5)
# Out:
# 602

# %%
plot(np.abs(dnf[0,:]))
plot(np.median(np.abs(dnf[0,:]))*np.ones((625,)))
a = np.abs(dnf[0,:])
plot((a.max()+a.min())*0.5*np.ones((625,)))

# %%
np.where?

# %%
np.flatnonzero((a>20)[1:]&~(a>20)[:-1])
# Out:
# array([401])

# %%
plot(a[:401])

# %%
plot((np.diff((a>20).astype('int'))))

# %%
b = (a>20)
plot(np.diff(b[:-1]|b[1:]))

# %%
df = d[:,:8125].reshape((-1,13,625)).mean(1)

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
df.shape
# Out:
# (32000, 625)

# %%
a = abs(df[83,:])

# %%
plot(a)

# %%
higha = np.zeros((df.shape[0],),dtype='complex')
lowa = np.zeros((df.shape[0],),dtype='complex')
for k in range(df.shape[0]):
    h,l = kid_readout.analysis.fit_pulses.find_high_low(df[k,:])
    higha[k] = h
    lowa[k] = l

# %%
higha.shape
# Out:
# (32000,)

# %%
figure(figsize=(8,16))
resp = np.abs(higha).reshape((-1,16))
resp = resp - np.median(resp[-100:,:],0)
resp = resp/resp.max(0)
blah = plot(resp+.1*np.arange(16)[None,:])

# %%
plot(lekidf,resp/np.median(resp,1)[:,None])
ylim(0,4)
xlim(140,150)
# Out:
# (140, 150)

# %%
imshow(resp,aspect='auto',interpolation='nearest')
clim(0,1)

# %%
a = abs(df[0,:])

# %%
mid = (a.max() + a.min())/2.

# %%
plot(a)
gca().axhline(mid)
above = a>mid
tt = above[1:]& ~above[:-1]
plot(tt*.016)

# %%
kid_readout.analysis.fit_pulses.find_rising_edge((df[0,:]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-693-d2586b6a7748> in <module>()
# ----> 1 kid_readout.analysis.fit_pulses.find_rising_edge((df[0,:]))
#
# /home/gjones/kid_readout/kid_readout/analysis/fit_pulses.py in find_rising_edge(x)
#      46     above = (np.abs(x)>mid)
#      47     nonz = np.flatnonzero((above[1:] & ~above[:-1]))
# ---> 48     return nonz[0]
#      49
#      50 def wrap_period(val,period):
#
# IndexError: index out of bounds
# > /home/gjones/kid_readout/kid_readout/analysis/fit_pulses.py(48)find_rising_edge()
#      47     nonz = np.flatnonzero((above[1:] & ~above[:-1]))
# ---> 48     return nonz[0]
#      49
# ipdb> print nonz
# []
# ipdb> print mid
# (0.00481555627569+0.00352562692601j)
# ipdb> q

# %%
flow = nm.resonator_model.inverse(low)

# %%
fhigh = nm.resonator_model.inverse(high)

# %%
s0 = nm.normalized_model_s21_at_meas_freq

# %%
plot(high.real,high.imag,'.')
plot(low.real,low.imag,'.')
plot((nm.sweep_model_normalized_s21_centered/nm.normalized_ds21_df_at_meas_freq).real,
     (nm.sweep_model_normalized_s21_centered/nm.normalized_ds21_df_at_meas_freq).imag,'.-')
plot(((nm.sweep_normalized_s21-s0)/nm.normalized_ds21_df_at_meas_freq).real,
     ((nm.sweep_normalized_s21-s0)/nm.normalized_ds21_df_at_meas_freq).imag,'kx',mew=2)

# %%
high.shape
# Out:
# (2000,)

# %%
#plot(high.real)
#plot(-high.imag)
plot(nm.timestream.mmw_source_freq[::16]/1e9,abs(high))

# %%
plot(abs(low))
plot(abs(low)[abs(low)<12])

# %%
plot(abs(high))
plot(high.real)

# %%
plot(fhigh[abs(low)<12])

# %%
plot(abs(fhigh-flow))
#xlim(1000,1200)

# %%
nm.timestream.mmw_source_freq.shape
# Out:
# (32000,)

# %%
1e8/6e9
# Out:
# 0.016666666666666666

# %%
plot(nm.timestream.zbd_voltage)

# %%
figure(figsize=(16,6))
#plot(nm.timestream.mmw_source_freq[::16]/1e9,np.abs(dn[:,:8125].reshape((-1,13,625)).mean(1)).real.ptp(1),label='LEKID response')
plot(nm.timestream.mmw_source_freq[::16]/1e9,abs(high),label='LEKID response')
#plot(nm.timestream.mmw_source_freq[::16]/1e9,(dn[:,:8125].reshape((-1,13,625)).mean(1)).real.ptp(1))
plot(isol['mmw_freq']/1e9,isol['power_watts']*3e8,label='mmw source power at zbd',lw=2)
#plot(nm.timestream.mmw_source_freq[::16]/1e9,dn[:,:8125].reshape((-1,13,625)).mean(1).real.min(1))
#xlim(150,160)
grid()
legend(loc='lower right',prop=dict(size='small'))
xlabel('GHz')
xlim(135,165)
ylabel('power [arb]')
savefig('/home/gjones/2014-08-31-LEKID-mmw-freq-response.pdf',bbox_inches='tight')

# %%
lekidf = nm.timestream.mmw_source_freq[::16]/1e9
lekidres = abs(high-low)
zbdf = isol['mmw_freq']/1e9
zbdres = isol['power_watts']*1e9
zbdatlekid = np.interp(lekidf,zbdf,zbdres)
plot(lekidf,lekidres/zbdatlekid)
ylim(0,0.7)
# Out:
# (0, 0.7)

# %%
plot(abs(high-np.median(low)))

# %%
blah = plot(dn.real[::10,:].T,dn.imag[::10,:].T,',')
plot((nm.sweep_model_normalized_s21_centered/nm.normalized_ds21_df_at_meas_freq).real,
     (nm.sweep_model_normalized_s21_centered/nm.normalized_ds21_df_at_meas_freq).imag,'.-')

# %%
plot(dn.real.max(1))

# %%
nm.resonator_model.a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-395-d87d30e270f9> in <module>()
# ----> 1 nm.resonator_model.a
#
# /home/gjones/kid_readout/kid_readout/analysis/fitter.pyc in __getattr__(self, attr)
#     107             return self._functions[attr](self.result.params)
#     108         except KeyError:
# --> 109             raise AttributeError("'{0}' object has no attribute '{1}'".format(self.__class__.__name__, attr))
#     110
#     111     def __dir__(self):
#
# AttributeError: 'Resonator' object has no attribute 'a'

# %%
nm.resonator_model.delay
# Out:
# -63.310295759681509

# %%
plot(np.angle(nm.sweep_normalized_s21))

# %%
dn.shape
# Out:
# (200, 8192)

# %%
nm._timestream_file.ncroot.mmw_atten_turns
# Out:
# array([ 6.5,  6.5])

# %%
dn.shape
# Out:
# (200, 8192)

# %%
d1 = dn[1,:]

# %%
rate = 125*5
imshow(d1.real[:(d1.shape[0]/rate)*rate].reshape((-1,rate)),aspect='auto')

# %%
1/12.50
# Out:
# 0.08

# %%
plot(d1.real[:(d1.shape[0]/rate)*rate].reshape((-1,rate))[2:,:].mean(0))

# %%
plot(nm.timestream.mmw_source_freq[::16],nm.timestream.zbd_voltage[::16])

# %%
nm.timeseries_sample_rate*(1/125.)
# Out:
# 125.0

# %%
keys = ['a','b']

# %%
keys.remove('b')

# %%
keys
# Out:
# ['a']

# %%
1/0.0128
# Out:
# 78.125

# %%
noisol = np.load('/home/gjones/mmw_source/reflect_no_isol_0_0_turns.npz')
isol = np.load('/home/gjones/mmw_source/reflect_with_isol_0_0_turns.npz')

# %%
noisol.keys()
# Out:
# ['freq', 'power']

# %%
plot(noisol['freq'],noisol['power']*1e9)
plot(isol['freq'],isol['power']*1e9)

# %%
1e8/10e9
# Out:
# 0.01

# %%
noisol = np.load('/home/data2/mmw_sweeps/2014-08-29_132700_130.000_170.000_100.0.npz')
isol = np.load('/home/data2/mmw_sweeps/2014-08-29_160147_130.000_170.000_10.0.npz')
print noisol['comments']
print isol['comments']
# Out:
# source -> 90 deg twist -> zbd
# 6,6, turns (micrometers read 1.5 on each)
# source -> 90deg twist -> 2in straight -> coupler far
# coupler close -> isolator -> zbd
# coupler coupled -> 30deg twist -> 2in straight -> cryostat
# atten 6,6 1.5

# %%
plot(noisol['mmw_freq']/1e9,noisol['power_watts']*1e9)
plot(isol['mmw_freq']/1e9,isol['power_watts']*1e9)

# %%
plot(noisol['mmw_freq']/1e9,noisol['power_watts']*1e9)
plot(isol['mmw_freq']/1e9,isol['power_watts']*1e9)

# %%
plot(kid_readout.analysis.fit_pulses.square_wave(625,625,-1,1,20))
ylim(-1.5,1.5)
# Out:
# (-1.5, 1.5)
