# %%
from kid_readout.analysis import noise_measurement
# Out:
# updated file list
# /home/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
nms = noise_measurement.load_noise_pkl('/home/gjones/detmnt/noise_sweeps_2014-08-13_115239_led.pkl')

# %%
nms

# %%
nm0 = nms[5]

# %%
nm0.fit_params
# Out:
# Parameters([('f_0', <Parameter 'f_0', value=168.84481757257765 +/- 0.000543, bounds=[None:168.82861328125], expr='168.859375'>), ('A_mag', <Parameter 'A_mag', value=0.027481866005096833 +/- 0.000563, bounds=[None:0], expr='1000000.0'>), ('A_phase', <Parameter 'A_phase', value=0 +/- 0, bounds=[None:-3.141592653589793], expr='3.14159265359'>), ('Q', <Parameter 'Q', value=23418.349401012063 +/- 1.27e+03, bounds=[None:0], expr='10000000.0'>), ('Q_e_real', <Parameter 'Q_e_real', value=38318.114167139429 +/- 2.27e+03, bounds=[None:0], expr='1000000.0'>), ('Q_e_imag', <Parameter 'Q_e_imag', value=-3385.0737151574576 +/- 2.69e+03, bounds=[None:-1000000.0], expr='1000000.0'>), ('delay', <Parameter 'delay', value=-6.7531292678501247 +/- 0.575, bounds=[None:-inf], expr='inf'>), ('phi', <Parameter 'phi', value=-0.037336073118425794 +/- 0.0187, bounds=[None:-3.141592653589793], expr='3.14159265359'>), ('f_phi', <Parameter 'f_phi', value=168.8388671875 +/- 0, bounds=[None:-inf], expr='inf'>), ('a'
# ...

# %%
loglog(nm0.pca_freq,nm0.pca_eigvals.T)

# %%
nm0.timestream_filename
# Out:
# '/home/data/2014-08-13_115239_led.nc'

# %%
nm0.timestream_filename = nm0.timestream_filename.replace('/home/data','/home/gjones/detmnt')
nm0.sweep_filename = nm0.sweep_filename

# %%
nm0.original_timeseries[0]
# Out:
# (0.012114954+0.0043482385j)

# %%
ts = nm0.original_timeseries[:]

# %%
ts[0]
# Out:
# (0.012114954+0.0043482385j)

# %%
ts.shape
# Out:
# (4194304,)

# %%
125e3/25
# Out:
# 5000.0

# %%
ns = 5000

# %%
ts2 = ts[:ns*(ts.shape[0]//ns)]
ts2 = ts2.reshape((-1,ns))

# %%
ts2.shape
# Out:
# (838, 5000)

# %%
256e6/2**11
# Out:
# 125000.0

# %%
imshow(ts2.imag,aspect='auto')

# %%
plot(np.real(ts2.mean(0)))
xlim(200,800)
#xlim(2800,3500)
# Out:
# (200, 800)

# %%
psd(ts-ts.mean(),NFFT=2**18,Fs=256e6/2**11)
#xscale('symlog')
xlim(0,2000)
ylim(-110,-80)
# Out:
# (-110, -80)

# %%
blah = hist(ts2.flatten().real,log=True,bins=100)
blah = hist(ts2[:,1000:].flatten().real,log=True,bins=100)
