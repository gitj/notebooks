# %%
# %pylab inline
# Out:
# /home/gjones/miniconda2/envs/readout/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Populating the interactive namespace from numpy and matplotlib

# %%
from kid_readout.interactive import *
# Out:
# INFO     2016-08-19 09:33:45,380 - kid_readout.<module>:13  kid_readout logging setup with default stream handler

# %%
ri = hardware_tools.r2_with_mk1()
# Out:
# INFO     2016-08-19 09:40:31,557 - kid_readout.roach.interface.initialize:429  Loaded ROACH state from /data/readout/r2kid_config.npz
# INFO     2016-08-19 09:40:31,564 - kid_readout.roach.interface.initialize:459  Reinitializing system
# INFO     2016-08-19 09:40:31,694 - kid_readout.roach.interface.initialize:466  Programming r2iq2xpfb14mcr18gb_2016_Jun_30_1104.bof
# INFO     2016-08-19 09:40:35,533 - kid_readout.roach.interface.set_fft_gain:302  Set FFT gain integer to 4.
# INFO     2016-08-19 09:40:37,548 - kid_readout.roach.interface.initialize:483  Requested sampling rate 512.0 MHz. Estimated sampling rate 512.9 MHz
# INFO     2016-08-19 09:40:40,979 - kid_readout.roach.r2heterodyne.initialize:72  Succesfully recalibrated QDR

# %%
ri.initialize(use_config=False)
# Out:
# INFO     2016-08-19 09:43:49,843 - kid_readout.roach.interface.initialize:459  Reinitializing system
# INFO     2016-08-19 09:43:49,973 - kid_readout.roach.interface.initialize:466  Programming r2iq2xpfb14mcr18gb_2016_Jun_30_1104.bof
# INFO     2016-08-19 09:43:50,560 - kid_readout.roach.interface.set_fft_gain:302  Set FFT gain integer to 4.
# INFO     2016-08-19 09:43:52,575 - kid_readout.roach.interface.initialize:483  Requested sampling rate 512.0 MHz. Estimated sampling rate 513.0 MHz
# INFO     2016-08-19 09:43:55,562 - kid_readout.roach.r2heterodyne.initialize:72  Succesfully recalibrated QDR

# %%
ri.set_lo(1200.0)

# %%
ri.measure_hardware_delay(make_plots=True)
# Out:
# 7.55776
# 4.369884260757769e-07

# %%
ri.set_dac_atten(10)

# %%
ri.find_best_iq_delay(make_plot=True)
# Out:
# INFO     2016-08-19 09:43:59,684 - kid_readout.roach.tools.find_best_iq_delay_adc:129  Best delay is -1 with median rejection 18.4 dB
# (-1, 18.351628105135859)

# %%
x,y = ri.get_raw_adc()

# %%
_=psd(x+1j*y)
