# %%
d = np.load('/home/data/fts/2015-03-26_12-22-55_test.npz')

# %%
d.keys()
# Out:
# ['position', 'r', 'theta']

# %%
position = d['position']

# %%
r = d['r']

# %%
theta = d['theta']

# %%
plot(position,r,'.-')

# %%
plot(theta)

# %%
import sys

# %%
sys.path.append('/Users/gjones/fts')

# %%
import fts

# %%
f1 = fts.FTSData()
f1.load_from_npz('/home/data/fts/2015-03-26_12-46-29_full_band.npz')

# %%
f1.analyze('auto')

# %%
f1.plot_summary()
# Out:
# (<matplotlib.figure.Figure at 0xa28d550>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x0000000009FF23C8>,
# ...
#          <matplotlib.axes.AxesSubplot object at 0x000000000A4A02E8>]], dtype=object))

# %%
f2 = fts.FTSData()
f2.load_from_npz('/home/data/fts/2015-03-26_13-07-57_narrow_band.npz')
f2.analyze('auto',window=np.hamming)

# %%
f2.plot_summary()
# Out:
# (<matplotlib.figure.Figure at 0x9fde4a8>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x000000000A295F28>,
# ...
#          <matplotlib.axes.AxesSubplot object at 0x000000000BBEF828>]], dtype=object))

# %%
ax = gca()
f1.plot_spectrum(ax=ax,log=True)
f2.plot_spectrum(ax=ax,log=True)
ylim(-60,-20)
xlim(130,180)
# Out:
# (130, 180)

# %%
f3 = fts.FTSData()
f3.load_from_npz('/home/data/fts/2015-03-26_13-50-02_narrow_band_no_output_filter.npz')
f3.analyze('auto',window=np.hamming)

# %%
f3.plot_summary()
# Out:
# (<matplotlib.figure.Figure at 0xc10ff60>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x000000000BDE0080>,
# ...
#          <matplotlib.axes.AxesSubplot object at 0x000000000C370978>]], dtype=object))

# %%
f3a = fts.FTSData()
f3a.load_from_npz('/home/data/fts/2015-03-26_13-50-02_narrow_band_no_output_filter.npz')
f3a.analyze('auto',window=np.ones)
f3a.plot_summary()
# Out:
# (<matplotlib.figure.Figure at 0xc4c9b38>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x000000000C365F98>,
# ...
#          <matplotlib.axes.AxesSubplot object at 0x000000000D4446D8>]], dtype=object))

# %%
plot(f3a.windowed_visibility,'.-')
xlim(0,100)
# Out:
# (0, 100)

# %%
f4 = fts.FTSData()
f4.load_from_npz('/home/data/fts/2015-03-26_14-10-19_full_band_no_output_filter.npz')
f4.analyze('auto',window=np.hamming)
f4.plot_summary()
# Out:
# (<matplotlib.figure.Figure at 0xd623630>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x000000000D2C6CF8>,
# ...
#          <matplotlib.axes.AxesSubplot object at 0x000000000DB909B0>]], dtype=object))

# %%
f5 = fts.FTSData()
f5.load_from_npz('/home/data/fts/2015-03-26_15-08-25_12.000_GHz_no_output_filter.npz')
f5.analyze('auto',window=np.ones)
f5.plot_summary()
# Out:
# (<matplotlib.figure.Figure at 0xdd1c278>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x000000000DB820F0>,
# ...
#          <matplotlib.axes.AxesSubplot object at 0x000000000E4877B8>]], dtype=object))

# %%
f6 = fts.FTSData()
f6.load_from_npz('/home/data/fts/2015-03-26_15-40-22_11.585_GHz_no_output_filter.npz')
f6.analyze('auto',window=np.ones)
f6.plot_summary()
# Out:
# (<matplotlib.figure.Figure at 0xd2d45f8>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x000000000E75F080>,
# ...
#          <matplotlib.axes.AxesSubplot object at 0x000000000ECF77F0>]], dtype=object))

# %%
f7 = fts.FTSData()
f7.load_from_npz('/home/data/fts/2015-03-26_16-30-07_13.000_GHz_no_output_filter.npz')
f7.analyze('auto',window=np.ones)
f7.plot_summary()
# Out:
# (<matplotlib.figure.Figure at 0xd47d5c0>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x000000000EE62CC0>,
# ...
#          <matplotlib.axes.AxesSubplot object at 0x000000000EB55048>]], dtype=object))

# %%
ax = gca()
f1.plot_spectrum(ax=ax,log=True)
f2.plot_spectrum(ax=ax,log=True)
f3.plot_spectrum(ax=ax,log=True)
f4.plot_spectrum(ax=ax,log=True)
f5.plot_spectrum(ax=ax,log=True)
f6.plot_spectrum(ax=ax,log=True)
ylim(-60,0)
xlim(100,200)
ax.axvline(144)

# %%
156/12.
# Out:
# 13.0

# %%
g1 = fts.FTSData()
g1.load_from_npz('/home/data/fts/2015-04-16_15-16-11_test_broadband_no_output_filter.npz')
g1.analyze('auto',window=np.hamming)
g1.plot_summary()
# Out:
# (<matplotlib.figure.Figure at 0xeb74048>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x0000000010581EB8>,
# ...
#          <matplotlib.axes.AxesSubplot object at 0x0000000010CE8908>]], dtype=object))

# %%
g2 = fts.FTSData()
g2.load_from_npz('/home/data/fts/2015-04-16_15-57-44_test_narrow_input_filter_stack_no_output_filter_no_10dB_pad.npz')
g2.analyze('auto',window=np.ones)
g2.plot_summary()
# Out:
# (<matplotlib.figure.Figure at 0xe761be0>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x0000000010CF0C50>,
# ...
#          <matplotlib.axes.AxesSubplot object at 0x00000000112B1160>]], dtype=object))

# %%
g3 = fts.FTSData()
g3.load_from_npz('/home/data/fts/2015-04-16_17-00-07_no_input_filter_10_dB_pad_no_output_filter_160_GHz_VDI_filter.npz')
g3.analyze('auto',window=np.hamming)
g3.plot_summary()
# Out:
# (<matplotlib.figure.Figure at 0xee436d8>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x0000000011733550>,
# ...
#          <matplotlib.axes.AxesSubplot object at 0x000000001139B978>]], dtype=object))

# %%
g4 = fts.FTSData()
g4.load_from_npz('/home/data/fts/2015-04-16_17-20-20_no_input_filter_10_dB_pad_no_output_filter_160_GHz_VDI_filter_45_deg_tilt.npz')
g4.analyze('auto',window=np.hamming)
g4.plot_summary()
# Out:
# (<matplotlib.figure.Figure at 0x1090beb8>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x0000000011D7AC88>,
# ...
#          <matplotlib.axes.AxesSubplot object at 0x00000000121FF390>]], dtype=object))

# %%
g5 = fts.FTSData()
g5.load_from_npz('/home/data/fts/2015-04-16_17-41-25_blue_input_filter_10_dB_pad_no_output_filter.npz')
g5.analyze('auto',window=np.hamming)
g5.plot_summary()
# Out:
# (<matplotlib.figure.Figure at 0xee69320>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x0000000012403390>,
# ...
#          <matplotlib.axes.AxesSubplot object at 0x0000000012849D68>]], dtype=object))

# %%
g6 = fts.FTSData()
g6.load_from_npz('/home/data/fts/2015-04-17_14-36-26_blue_input_filter_10_dB_pad_no_output_filter_run2.npz')
g6.analyze('auto',window=np.hamming)
g6.plot_summary()
# Out:
# (<matplotlib.figure.Figure at 0x117558d0>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x00000000126B27F0>,
# ...
#          <matplotlib.axes.AxesSubplot object at 0x0000000012E61DA0>]], dtype=object))

# %%
g7 = fts.FTSData()
g7.load_from_npz('/home/data/fts/2015-04-17_15-09-50_no_input_filter_10_dB_pad_no_output_filter.npz')
g7.analyze('auto',window=np.hamming)
g7.plot_summary()
# Out:
# (<matplotlib.figure.Figure at 0x1128a048>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x00000000130100F0>,
# ...
#          <matplotlib.axes.AxesSubplot object at 0x000000001383ADD8>]], dtype=object))

# %%
g8 = fts.FTSData()
g8.load_from_npz('/home/data/fts/2015-04-17_15-25-44_blue_input_filter_10_dB_pad_no_output_filter.npz')
g8.analyze('auto',window=np.hamming)
g8.plot_summary()
# Out:
# (<matplotlib.figure.Figure at 0x123e43c8>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x000000001399A940>,
# ...
#          <matplotlib.axes.AxesSubplot object at 0x0000000013D157B8>]], dtype=object))

# %%
g9 = fts.FTSData()
g9.load_from_npz('/home/data/fts/2015-04-17_15-41-45_no_input_filter_10_dB_pad_no_output_filter_VDI_160_GHz_filter.npz')
g9.analyze('auto',window=np.hamming)
g9.plot_summary()
# Out:
# (<matplotlib.figure.Figure at 0x1397d240>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x0000000014020AC8>,
# ...
#          <matplotlib.axes.AxesSubplot object at 0x00000000145427F0>]], dtype=object))

# %%
g10 = fts.FTSData()
g10.load_from_npz('/home/data/fts/2015-04-17_15-54-25_no_input_filter_10_dB_pad_no_output_filter_VDI_160_GHz_filter_bigger_space.npz')
g10.analyze('auto',window=np.hamming)
g10.plot_summary()
# Out:
# (<matplotlib.figure.Figure at 0x10bc9eb8>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x0000000014C01048>,
# ...
#          <matplotlib.axes.AxesSubplot object at 0x0000000014FF6048>]], dtype=object))

# %%
g11 = fts.FTSData()
g11.load_from_npz('/home/data/fts/2015-04-17_16-09-44_no_input_filter_10_dB_pad_no_output_filter_VDI_160_GHz_filter_vertical.npz')
g11.analyze('auto',window=np.hamming)
g11.plot_summary()
# Out:
# (<matplotlib.figure.Figure at 0x136b1cc0>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x0000000014C09F98>,
# ...
#          <matplotlib.axes.AxesSubplot object at 0x000000001554F240>]], dtype=object))

# %%
g12 = fts.FTSData()
g12.load_from_npz('/home/data/fts/2015-04-17_16-38-00_no_input_filter_10_dB_pad_no_output_filter_Stycast_filter_close_to_detector.npz')
g12.analyze('auto',window=np.hamming)
g12.plot_summary()
# Out:
# (<matplotlib.figure.Figure at 0x1384f518>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x00000000157C8D30>,
# ...
#          <matplotlib.axes.AxesSubplot object at 0x0000000016022278>]], dtype=object))

# %%
g12 = fts.FTSData()
g12.load_from_npz('/home/data/fts/2015-04-17_16-55-38_blue_and_green_input_filter_10_dB_pad_no_output_filter.npz')
g12.analyze('auto',window=np.hamming)
g12.plot_summary()
# Out:
# (<matplotlib.figure.Figure at 0x1516d2e8>,
#  array([[<matplotlib.axes.AxesSubplot object at 0x000000001602FEF0>,
# ...
#          <matplotlib.axes.AxesSubplot object at 0x00000000165F9A58>]], dtype=object))

# %%
ax = gca()
f4.plot_spectrum(ax=ax,log=True)
g1.plot_spectrum(ax=ax,log=True)
g2.plot_spectrum(ax=ax,log=True)
#g3.plot_spectrum(ax=ax,log=True)
#g4.plot_spectrum(ax=ax,log=True)
g5.plot_spectrum(ax=ax,log=True)
g6.plot_spectrum(ax=ax,log=True)
g7.plot_spectrum(ax=ax,log=True)
g8.plot_spectrum(ax=ax,log=True)
xlim(100,200)
ylim(-100,-10)
# Out:
# (-100, -10)

# %%
ax = gca()
#g3.plot_spectrum(ax=ax,log=True)
#g4.plot_spectrum(ax=ax,log=True)
g7.plot_spectrum(ax=ax,log=True)
#g8.plot_spectrum(ax=ax,log=True)
g9.plot_spectrum(ax=ax,log=True)
g10.plot_spectrum(ax=ax,log=True)
g11.plot_spectrum(ax=ax,log=True)
#g12.plot_spectrum(ax=ax,log=True)
xlim(100,250)
ylim(-100,-10)
# Out:
# (-100, -10)

# %%
14.1*12
# Out:
# 169.2

# %%
g2.plot_spectrum(log=True)
xlim(130,150)
ylim(-100,-45)
grid(False)
ax = gca()
ax.axvline(11.55*12)
ax.axvline(11.61*12)

# %%
f6.plot_spectrum(log=True)
xlim(130,150)
ylim(-40,15)
grid(False)
ax = gca()
ax.axvline(11.55*12)
ax.axvline(11.61*12)

# %%
g2.raw_frequency[g2.windowed_spectrum.argmax()]
# Out:
# 139.25729442970822

# %%
11.55*12,11.61*12
# Out:
# (138.60000000000002, 139.32)

# %%
plot(g2.windowed_visibility,'.-')
xlim(0,100)
# Out:
# (0, 100)

# %%
plot(g3.raw_data[:,1])
