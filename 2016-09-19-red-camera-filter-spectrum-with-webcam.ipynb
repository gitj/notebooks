# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import scipy.ndimage

# %%
import scipy.io

# %%
a = scipy.ndimage.imread('/home/gjones/WIN_20160919_125751.JPG',mode='F')
b = scipy.ndimage.imread('/home/gjones/WIN_20160919_125757.JPG',mode='F')
c = scipy.ndimage.imread('/home/gjones/WIN_20160919_133149.JPG',mode='F')

# %%
subplot(121)
imshow(a,cmap=cm.gray,aspect='auto')
subplot(122)
imshow(b,cmap=cm.gray,aspect='auto')

# %%
a.shape
# Out:
# (480, 640)

# %%
a.dtype
# Out:
# dtype('float32')

# %%
sa = a[170:220,:550].max(0)
sb = b[170:220,:550].max(0)
sc = c[170:220,:550].max(0)

# %%
plot(sa)
plot(sb)
#plot(sc)

# %%
plot(sc)

# %%
plot(10*np.log10((sb)/(sa)))

# %%
plot(a[170:220,:,:].max(0).mean(1))
plot(b[170:220,:,:].max(0).mean(1))
xlim(400,550)
# Out:
# (400, 550)
