# %%
import sys

# %%
sys.path.append('/Users/gjones/rtlscan/')

# %%
import process_scan

# %%
import glob
import pandas as pd

# %%
fns = glob.glob('/rtlscan/data/2015-01-11*.npz')
fns.sort()

# %%
len(fns)
# Out:
# 20

# %%
df = process_scan.process_files(fns)
# Out:
# finished 0:/rtlscan/data\2015-01-11_132056.npz in 248.0 s, projected time to finish 78.5 min
# finished 1:/rtlscan/data\2015-01-11_132356.npz in 244.7 s, projected time to finish 73.9 min
# finished 2:/rtlscan/data\2015-01-11_132657.npz in 240.7 s, projected time to finish 69.3 min
# finished 3:/rtlscan/data\2015-01-11_132956.npz in 238.9 s, projected time to finish 64.8 min
# finished 4:/rtlscan/data\2015-01-11_133257.npz in 238.6 s, projected time to finish 60.5 min
# finished 5:/rtlscan/data\2015-01-11_133556.npz in 242.5 s, projected time to finish 56.5 min
# finished 6:/rtlscan/data\2015-01-11_133855.npz in 246.8 s, projected time to finish 52.6 min
# finished 7:/rtlscan/data\2015-01-11_134155.npz in 240.2 s, projected time to finish 48.5 min
# finished 8:/rtlscan/data\2015-01-11_134455.npz in 249.9 s, projected time to finish 44.6 min
# finished 9:/rtlscan/data\2015-01-11_134754.npz in 239.5 s, projected time to finish 40.5 min
# ...

# %%
df.shape
# Out:
# (2432000, 7)

# %%
np.save('/rtlscan/2015-01-11.npy',df.to_records())

# %%
df.columns
# Out:
# Index([u'freq', u'nspec', u'skurtosis', u'timestamp', u'total_power', u'scan_num', u'scan_filename'], dtype='object')

# %%
blah =hist(np.log10(df.skurtosis),bins=200,log=True)

# %%
blah = hist(np.log10(df.total_power),bins=200,log=True)

# %%
figure(figsize=(12,6))
occupied = df[df.skurtosis > (1+128/np.sqrt(df.nspec))]
cold = df[df.skurtosis < (1-4/np.sqrt(df.nspec))]
plot(df.freq,10*np.log10(df.total_power),'y,')
plot(occupied.freq,10*np.log10(occupied.total_power),'r.')
plot(cold.freq,10*np.log10(cold.total_power),'g.')
#xlim(440e6,450e6)
#xlim(494.e6,494.4e6)

# %%
figure(figsize=(12,6))
plot(df.freq,10*np.log10(df.skurtosis),',')
ax = gca()
ax.axhline(np.log10(1+128/np.sqrt(496.)),color='r')
ax.axvline(108e6,color='y')
ax.axvline(88e6,color='y')

# %%
df.nspec.iloc[0]
# Out:
# 496

# %%
occupied.shape
# Out:
# (461956, 7)

# %%
df.nspec.iloc[0]
# Out:
# 496

# %%
n2r=df[np.abs(df.freq-446.21e6)<5e3]

# %%
plot(n2r.timestamp,n2r.skurtosis)
plot(n2r.timestamp,np.log10(n2r.total_power))

# %%
blah = hist(np.log10(n2r.skurtosis.values),bins=100)
ax = gca()
ax.axvline(np.log10(1+4/np.sqrt(496.)))
ax.axvline(np.log10(1-4/np.sqrt(496.)))

# %%
plot(10*np.log10(df.total_power),np.log10(df.skurtosis),'k,',alpha=0.05)
#ylim(-.1,.1)
#xlim(10,30)

# %%
H,x,y=np.histogram2d(10*np.log10(df.total_power),np.log10(df.skurtosis),bins=50)

# %%
H.shape
# Out:
# (50L, 50L)

# %%
xx,yy = np.meshgrid(x,y)
contourf(xx[:-1,:-1],yy[:-1,:-1],np.log10(H).T)
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x00000000181D9748>

# %%
lmaxs = df.groupby(df.scan_num).apply(ambda x: np.sum(np.log10(x)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-32ffac63edbb> in <module>()
# ----> 1 maxs = df.groupby(df.scan_num).apply(lambda x: np.sum(np.log10(x)))
#
# C:\Users\gjones\WinPython-64bit-2.7.6.4\python-2.7.6.amd64\lib\site-packages\pandas\core\groupby.pyc in apply(self, func, *args, **kwargs)
#     422             return func(g, *args, **kwargs)
#     423
# --> 424         return self._python_apply_general(f)
#     425
#     426     def _python_apply_general(self, f):
#
# C:\Users\gjones\WinPython-64bit-2.7.6.4\python-2.7.6.amd64\lib\site-packages\pandas\core\groupby.pyc in _python_apply_general(self, f)
#     425
#     426     def _python_apply_general(self, f):
# --> 427         keys, values, mutated = self.grouper.apply(f, self.obj, self.axis)
#     428
#     429         return self._wrap_applied_output(keys, values,
#
# ...

# %%
maxs.shape
# Out:
# (203, 7)

# %%
type(np.log(maxs.total_power.values))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-437bbd0145f0> in <module>()
# ----> 1 type(np.log(maxs.total_power.values))
#
# AttributeError: log

# %%
plot(maxs.total_power.values)
