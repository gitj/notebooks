# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from kid_readout.interactive import *
# Out:
# INFO     2017-09-21 09:43:14,645 - kid_readout.<module>:13  kid_readout logging setup with default stream handler

# %%
ri = Roach2Baseband()
# Out:
# INFO     2017-09-21 09:43:20,037 - kid_readout.roach.interface.initialize:447  Loaded ROACH state from /data/readout/r2kid_config.npz

# %%
ri.set_tone_freqs(np.array([100.0]),nsamp=2**15)
# Out:
# array([ 100.])

# %%
ri.fft_bins
# Out:
# array([[6400]])

# %%
512e6/2**15
# Out:
# 15625.0

# %%
ri.set_loopback(True)

# %%
x,y = ri.get_raw_adc()

# %%
x.shape
# Out:
# (4096,)

# %%
plot(x[:100])

# %%
psd(x,Fs=512);

# %%
ri.set_fft_gain(0)
# Out:
# INFO     2017-09-21 09:44:58,389 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 0.

# %%
m = ri.get_measurement(0.1,demod=False)

# %%
m.s21_raw.shape
# Out:
# (1, 2048)

# %%
plot_ri(m.s21_raw[0,:],'.')

# %%
m.s21_raw
# Out:
# array([[-1128.+3207.j, -1128.+3207.j, -1128.+3207.j, ..., -1128.+3207.j,
#         -1128.+3207.j, -1128.+3207.j]], dtype=complex64)

# %%
ri.set_tone_freqs(np.array([100.0123]),nsamp=2**15)
# Out:
# array([ 100.015625])

# %%
ri.fft_bins
# Out:
# array([[6401]])

# %%
m = ri.get_measurement(0.1,demod=False)
plot_ri(m.s21_raw[0,:],'.')

# %%
print ri.set_tone_freqs(np.array([100.007]),nsamp=2**19)
print ri.fft_bins
# Out:
# [ 100.00683594]
# [[6400]]

# %%
m = ri.get_measurement(0.1,demod=False)
plot_ri(m.s21_raw[0,:],'.')

# %%
plot(m.s21_raw[0,:10])

# %%
psd(m.s21_raw[0,:]);

# %%
ri.set_fft_gain(0)
m = ri.get_measurement(0.1,demod=False)
plot_ri(m.s21_raw[0,:],'.')

ri.set_fft_gain(1)
m = ri.get_measurement(0.1,demod=False)
plot_ri(m.s21_raw[0,:],'.')

ri.set_fft_gain(2)
m = ri.get_measurement(0.1,demod=False)
plot_ri(m.s21_raw[0,:],'.')

ri.set_fft_gain(3)
m = ri.get_measurement(0.1,demod=False)
plot_ri(m.s21_raw[0,:],'.')
ri.set_fft_gain(4)
m = ri.get_measurement(0.1,demod=False)
plot_ri(m.s21_raw[0,:],'.')
# Out:
# INFO     2017-09-21 10:17:56,074 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 0.
# INFO     2017-09-21 10:17:56,374 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 1.
# INFO     2017-09-21 10:17:56,567 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 2.
# INFO     2017-09-21 10:17:56,746 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 3.
# INFO     2017-09-21 10:17:57,030 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 4.

# %%
ri.set_tone_freqs(np.array([100.]),nsamp=2**16)
ri.set_fft_gain(0)
m = ri.get_measurement(0.1,demod=False)
plot_ri(m.s21_raw[0,:],'.')

ri.set_fft_gain(1)
m = ri.get_measurement(0.1,demod=False)
plot_ri(m.s21_raw[0,:],'.')

ri.set_fft_gain(2)
m = ri.get_measurement(0.1,demod=False)
plot_ri(m.s21_raw[0,:],'.')

ri.set_fft_gain(3)
m = ri.get_measurement(0.1,demod=False)
plot_ri(m.s21_raw[0,:],'.')
ri.set_fft_gain(10)
m = ri.get_measurement(0.1,demod=False)
plot_ri(m.s21_raw[0,:],'.')
# Out:
# INFO     2017-09-21 10:27:19,706 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 0.
# INFO     2017-09-21 10:27:19,986 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 1.
# INFO     2017-09-21 10:27:20,173 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 2.
# INFO     2017-09-21 10:27:20,362 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 3.
# INFO     2017-09-21 10:27:20,549 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 10.

# %%
ri.set_fft_gain(2)
m = ri.get_measurement(0.1,demod=False)
plot_ri(m.s21_raw[0,:],'.')
# Out:
# INFO     2017-09-21 10:22:30,782 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 2.

# %%
psd(m.s21_raw[0,:]);

# %%
m = ri.get_measurement(0.1,demod=True)
plot_ri(m.s21_raw[0,:],'.')

# %%
psd(m.s21_raw[0,:]);

# %%
ri.set_tone_freqs(np.array([100.007]),nsamp=2**19)
m = ri.get_measurement(0.1,demod=False)
plot_ri(m.s21_raw[0,:],'.')
ri.set_tone_freqs(np.array([100.007]),nsamp=2**19)
m = ri.get_measurement(0.1,demod=False)
plot_ri(m.s21_raw[0,:],'.')
ri.set_tone_freqs(np.array([100.007]),nsamp=2**19)
m = ri.get_measurement(0.1,demod=False)
plot_ri(m.s21_raw[0,:],'.')
ri.set_tone_freqs(np.array([100.007]),nsamp=2**19)
m = ri.get_measurement(0.1,demod=False)
plot_ri(m.s21_raw[0,:],'.')

# %%
ri.set_tone_freqs(np.array([100.007]),nsamp=2**19)
m = ri.get_measurement(0.1)
plot_ri(m.s21_raw[0,:],'.')
ri.set_tone_freqs(np.array([100.007]),nsamp=2**19)
m = ri.get_measurement(0.1)
plot_ri(m.s21_raw[0,:],'.')
ri.set_tone_freqs(np.array([100.007]),nsamp=2**19)
m = ri.get_measurement(0.1)
plot_ri(m.s21_raw[0,:],'.')
ri.set_tone_freqs(np.array([100.007]),nsamp=2**19)
m = ri.get_measurement(0.1)
plot_ri(m.s21_raw[0,:],'.')

# %%
ri.set_tone_freqs(np.array([100.007]),nsamp=2**19)
# Out:
# array([ 100.00683594])

# %%
from kid_readout.roach import tools

# %%
tools.optimize_fft_gain(ri)
# Out:
# INFO     2017-09-21 10:29:00,008 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 0.
# INFO     2017-09-21 10:29:00,174 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 1.
# INFO     2017-09-21 10:29:00,374 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 2.
# INFO     2017-09-21 10:29:00,562 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 3.
# INFO     2017-09-21 10:29:00,842 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 2.

# %%
ri.set_tone_freqs(np.array([100.007]+np.arange(8)),nsamp=2**19)
# Out:
# array([ 100.00683594,  101.00683594,  102.00683594,  103.00683594,
#         104.00683594,  105.00683594,  106.00683594,  107.00683594])

# %%
tools.optimize_fft_gain(ri,.4)
# Out:
# INFO     2017-09-21 10:34:09,999 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 0.
# INFO     2017-09-21 10:34:10,166 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 1.
# INFO     2017-09-21 10:34:10,336 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 2.
# INFO     2017-09-21 10:34:10,512 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 3.
# INFO     2017-09-21 10:34:10,680 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 4.
# INFO     2017-09-21 10:34:10,852 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 5.
# INFO     2017-09-21 10:34:11,026 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 6.
# INFO     2017-09-21 10:34:11,196 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 7.
# INFO     2017-09-21 10:34:11,366 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 8.
# ...

# %%
for gain in range(10):
    ri.set_fft_gain(gain)
    m = ri.get_measurement(0.1,demod=False)
    plot_ri(m.s21_raw[0,:],'.')
# Out:
# INFO     2017-09-21 10:31:36,433 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 0.
# INFO     2017-09-21 10:31:36,727 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 1.
# INFO     2017-09-21 10:31:36,897 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 2.
# INFO     2017-09-21 10:31:37,053 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 3.
# INFO     2017-09-21 10:31:37,224 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 4.
# INFO     2017-09-21 10:31:37,397 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 5.
# INFO     2017-09-21 10:31:37,560 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 6.
# INFO     2017-09-21 10:31:37,718 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 7.
# INFO     2017-09-21 10:31:37,890 - kid_readout.roach.interface.set_fft_gain:320  Set FFT gain integer to 8.
# ...
