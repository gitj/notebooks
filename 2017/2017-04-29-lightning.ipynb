# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.append('/home/gjones/pmc/pmc-turbo-devel/')
from pmc_turbo.camera.image_processing import blosc_file
from pmc_turbo.camera.image_processing import jpeg
import os
import glob

# %%
fns = glob.glob('/home/pmcroot/c2/data?/2017-04-28_214438/*')
fns.sort(key = lambda x: os.path.split(x)[1])

# %%
import re

# %%
lightning = [fn for fn in fns if '2017-04-29_051934' in fn]
lightning += [fn for fn in fns if '2017-04-29_051411' in fn]

# %%
for fn in lightning:
    img,meta = blosc_file.load_blosc_image(fn)
    with open(os.path.join('/home/gjones/pmc/',os.path.split(fn)[1]+'.jpg'),'w') as fh:
        fh.write(jpeg.simple_jpeg(img))

# %%
img,meta = blosc_file.load_blosc_image(lightning[2])

# %%
figure(figsize=(12,12))
imshow(img[:,:].T,origin='lower',cmap=cm.gray)
#clim(None,10000)
colorbar()
