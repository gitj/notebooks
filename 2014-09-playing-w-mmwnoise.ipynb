# %%
import kid_readout.utils.readoutnc
import glob

# %%
files = glob.glob('/home/data2/2014-09-*mmwnoise*.nc')

# %%
files.sort()
len(files)
# Out:
# 18

# %%
import kid_readout.analysis.noise_measurement
reload(kid_readout.analysis.noise_measurement)
# Out:
# updated file list
# /home/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# <module 'kid_readout.analysis.noise_measurement' from '/home/gjones/kid_readout/kid_readout/analysis/noise_measurement.pyc'>

# %%
nms = [kid_readout.analysis.noise_measurement.SweepNoiseMeasurement(fn,
                                                                   resonator_index=1,delay_estimate=-63.0)
       for fn in files]
# Out:
# 0 8192 rejecting 0.032958984375
# 0 16384 rejecting 0.0276489257812
# 8192 24576 rejecting 0.0352783203125
# 16384 32768 rejecting 0.0372314453125
# 24576 40960 rejecting 0.0367431640625
# 32768 49152 rejecting 0.0380249023438
# 40960 57344 rejecting 0.0261840820312
# 49152 65536
# rejecting 0.0238647460938
# 57344 73728 rejecting 0.0360107421875
# 65536 81920 rejecting 0.041259765625
# 73728 90112 rejecting 0.0314331054688
# 81920 98304 rejecting 0.03076171875
# 90112 106496 rejecting 0.0320434570312
# 98304 114688 rejecting 0.0238037109375
# 106496 122880
# rejecting 0.0234375
# 114688 131072 rejecting 0.0263671875
# using NFFT: 2** 14.0
# 10
# 0
#  8192 rejecting 0.0069580078125
# 0 16384 rejecting 0.0076904296875
# 8192 24576 rejecting 0.0096435546875
# 16384 32768 rejecting 0.0131225585938
# 24576 40960 rejecting 0.013671875
# 32768 49152 rejecting 0.01025390625
# 40960 57344 rejecting 0.00860595703125
# 49152 65536
# rejecting 0.008056640625
# ...

# %%
len(nms)
# Out:
# 18

# %%
for nm in nms:
    plot(nm.sweep_freqs_MHz,abs(nm.sweep_s21))

# %%
plot([nm.resonator_model.f_0/nms[0].resonator_model.f_0 for nm in nms],'o')

# %%
for nm in nms:
    semilogx(nm.pca_freq,nm.pca_eigvals[1,:])
ylim(0,1e-16)
# Out:
# (0, 1e-16)

# %%
plot(nm.pca_freq,nm.pca_eigvals.T)
xlim(0,200)
grid()

# %%
plot([nm.pca_eigvals[1,10:20].mean() for nm in nms],'o')
plot([nm.pca_eigvals[1,-10:].mean() for nm in nms],'o')

# %%
kid_readout.analysis.noise_measurement.SweepNoiseMeasurement?

# %%
loglog(nm1.pca_freq,nm1.pca_eigvals.T)

# %%
plot(nm1.sweep_normalized_s21.real,nm1.sweep_normalized_s21.imag)

# %%
blah = nm1.plot()

# %%
figure(figsize=(12,12))
for nm in nms:
    plot(nm.normalized_timeseries.real,nm.normalized_timeseries.imag,',')
    plot(nm.sweep_normalized_s21.real,nm.sweep_normalized_s21.imag,'.-')

# %%
(2**7*2*64e-6)
# Out:
# 0.016384
