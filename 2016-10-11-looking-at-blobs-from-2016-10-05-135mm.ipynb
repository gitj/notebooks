# %%
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import glob

# %%
files = glob.glob('/home/pmcroot/data4/2016-10-05_135mm_focus_test_100_ms_evening_no_sim_sky/blobs/*.blobs')
files.sort()

# %%
len(files)
# Out:
# 278

# %%
import cPickle

# %%
def load(fn):
    with open(fn,'r') as fh:
        return cPickle.load(fh)

# %%
import sys

# %%
sys.path.append('/home/pmchome/pmc-turbo/')

# %%
all_blobs = [load(fn) for fn in files]
# Out:
# couldn't import _pyvimba

# %%
blobs = [(blob.x,blob.y,blob.peak) for bloblist in all_blobs for blob in bloblist]

# %%
blobs=np.array(blobs)

# %%
blobs.shape
# Out:
# (229138, 3)

# %%
figure()
_=hist(np.sqrt(blobs[:,2]),bins=100,log=True)
# Out:
# <img src="data:image/png;base64,...">

# %%
figure()
scatter(blobs[:,1],blobs[:,0],s=np.sqrt(blobs[:,2]),edgecolor='none')
ylim(3232,0)
# Out:
# <img src="data:image/png;base64,...">
# (3232, 0)

# %%
images = glob.glob('/home/pmcroot/data4/2016-10-05_135mm_focus_test_100_ms_evening_no_sim_sky/*.npz')

# %%
im = np.load(images[0])

# %%
im['state'][()]['timestamp']
# Out:
# 1475714000811645800L

# %%
figure()
plot(blobs[38000:,1],blobs[38000:,0],',')
ylim(3232,0)
# Out:
# <img src="data:image/png;base64,...">
# (3232, 0)

# %%
figure()
h,b=np.histogram(blobs[60000:,0],bins=range(0,3232,8))
plot(b[:-1],h)
# Out:
# <img src="data:image/png;base64,...">

# %%
figure()
plot(blobs[:,1],',')
# Out:
# <img src="data:image/png;base64,...">

# %%
figure()
plot(blobs[:,0],',')
# Out:
# <img src="data:image/png;base64,...">

# %%
blobs.shape
# Out:
# (229138, 3)

# %%
figure()
plot(blobs[:,2],',')
# Out:
# <img src="data:image/png;base64,...">
