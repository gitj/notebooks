# %%
import glob

# %%
ncfiles = [#'/home/data/2014-01-29_214456.nc',
           #'/home/data/2014-01-29_220701.nc'
           #'/home/data/2014-01-29_221542.nc'
           #'/home/data/2014-01-29_222630.nc',
           #'/home/data/2014-01-31_225704.nc'
           #'/home/data/2014-01-31_232347.nc' #good
           #'/home/data/2014-02-01_000752.nc'
           #'/home/data/2014-02-01_003639.nc'
           #'/home/data/2014-02-01_010105.nc'
           #'/home/data/2014-02-01_011449.nc'
           '/home/data/2014-02-02_092054.nc'
]
#ncfiles = ['/home/data/2013-11-27_162117.nc']

# %%
from kid_readout.utils.easync import EasyNetCDF4
import kid_readout.analysis.resonator

# %%
#run -i /home/gjones/workspace/kid_readout/analysis/noise_summary.py
import kid_readout.analysis.noise_summary
reload(kid_readout.analysis.noise_summary)
# Out:
# <module 'kid_readout.analysis.noise_summary' from '/home/gjones/workspace/kid_readout/analysis/noise_summary.pyc'>

# %%
nc = EasyNetCDF4(ncfiles[0])

# %%
idx = 3
swgrp = nc.sweeps.groups.values()[0]
msk = swgrp.variables['index'][:]==idx
f = swgrp.variables['frequency'][:][msk]
s21 = swgrp.variables['s21'][:].view('complex')[msk]#*np.exp(-1j*f*398)
tsgrp = nc.timestreams.groups.values()[0]
tsdat = tsgrp.variables['data'][idx,:].view('complex')
tsfrq = tsgrp.variables['tone'][idx]*tsgrp.variables['fs'][idx]/tsgrp.variables['nsamp'][idx]
fs = tsgrp.variables['fs'][idx]*1e6/(2*tsgrp.variables['nfft'][idx])
wavenorm = tsgrp.variables['wavenorm'][idx]
res = kid_readout.analysis.resonator.Resonator(f,s21)
s21c = s21*np.exp(2j*np.pi*f*res.delay)

# %%
psd(tsdat-tsdat.mean(),Fs=fs,NFFT=2048*16)
xscale('symlog')

# %%
plot(f,20*log10(abs(s21)),'.-')

# %%
plot(f,unwrap(angle(s21)),'.-')
plot(f,unwrap(angle(s21c)),'.-')

# %%
plot(s21.real,s21.imag,'.-')
plot(s21c.real,s21c.imag,'.-')
plot(tsdat.real[::1000]*wavenorm,tsdat.imag[::1000]*wavenorm,',')

# %%
import kid_readout.analysis.resonator

# %%
res = kid_readout.analysis.resonator.Resonator(f,s21)

# %%
f.mean()
# Out:
# 130.29158238002233

# %%
plot(f-res.f_0,abs(s21)/res.A_mag,'.-')
plot(f-res.f_0,abs(res.model())/res.A_mag,'.-')

# %%
res.delay
# Out:
# -3.3080447504453114

# %%
plot(f-res.f_0,unwrap(angle(s21)),'.-')
plot(f-res.f_0,unwrap(angle(res.model())),'.-')
plot(f-res.f_0,unwrap(angle(res.model()*np.exp(2j*np.pi*res.delay*f))),'.-')

# %%
s21c = s21*np.exp(2j*np.pi*res.delay*f)/res.A_mag

# %%
plot(s21c.real,s21c.imag,'.-')
grid()

# %%
res.Q_i
# Out:
# 47061.711083078037

# %%
for fname in ncfiles:
    kid_readout.analysis.noise_summary.plot_noise_nc(fname,chip='StarCryo_5x4_0813F10',
                                                     phasecorr=0,scale=None)
# Out:
# failed to parse '\r' skipping
# failed to parse
#  '\r' skipping
# failed to parse '\r' skipping
# get_temperature_at: updated cache
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-20-cf90c06a742e> in <module>()
#       1 for fname in ncfiles:
#       2     kid_readout.analysis.noise_summary.plot_noise_nc(fname,chip='StarCryo_5x4_0813F10',
# ----> 3                                                      phasecorr=0,scale=None)
#
# /home/gjones/workspace/kid_readout/analysis/noise_summary.pyc in plot_noise_nc(fname, chip, **kwargs)
#      35         for index in indexes:
#      36             kwargs['index'] = index
# ---> 37             nm = NoiseMeasurement(swg,tsg,hwg,chip,k,**kwargs)
#      38             nms.append(nm)
#      39             fig = nm.plot()
#
# ...
