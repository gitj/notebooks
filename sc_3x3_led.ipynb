# %%
from kid_readout.utils.easync import EasyNetCDF4

# %%
nc = EasyNetCDF4('/home/data/2013-12-20_154506.nc')

# %%
d = nc.timestreams.timestream_20131220154521.data[:].view('complex')

# %%
d.shape
# Out:
# (4, 131072)

# %%
plot(d.T.real,d.T.imag,',')

# %%
psd(d[0,:],NFFT=4096)
xscale('symlog')

# %%
nc = EasyNetCDF4('/home/data/2013-12-19_221541.nc')

# %%
fr
s21 = nc.sweeps.sweep_20131219221810.s21[:].view('complex')*np.exp(-1j*fs*397.93/2.0)

# %%
plot(s21.real,s21.imag,'o')

# %%
nsamp = nc.timestreams.timestream_20131219221922.nsamp[:]
fs = nc.timestreams.timestream_20131219221922.fs[:]
tone = nc.timestreams.timestream_20131219221922.tone[:]
freq = fs*tone/float(nsamp)
nfft = nc.timestreams.timestream_20131219221922.nfft[:]
print freq,nsamp,tone,nfft,fs/(float(2*nfft))
# Out:
# [ 77.91430664] [2097152] [319137] [2048] [ 0.125]

# %%
ts = nc.timestreams.timestream_20131219221922.data[:].view('complex')*(3.814e-6/4.0)*np.exp(-1j*fs*397.93/2.0)

# %%
ts.shape
# Out:
# (1, 8388608)

# %%
plot(s21.real,s21.imag,'o')
plot(ts[0,:1000].real,ts[0,:1000].imag,',')

# %%
2**23/67.
# Out:
# 125203.10447761194

# %%
nc = EasyNetCDF4('/home/data/2013-12-09_113911.nc')

# %%
on = nc.timestreams.timestream_20131209114251.data[:].view('complex')[0,:]
off = nc.timestreams.timestream_20131209114422.data[:].view('complex')[0,:]

# %%
psd(on,NFFT=4096*32,Fs=512e6/2**14)
psd(off,NFFT=4096*32,Fs=512e6/2**14)
xscale('log')

# %%
plot(on.real[-1000:],on.imag[-1000:],'.')
plot(off.real[:1000],off.imag[:1000],'.')

# %%
nc.group.gitinfo
# Out:
# u''

# %%
# !git log -1
# Out:
# fatal: Not a git repository (or any of the parent directories): .git

# %%
import kid_readout.utils.data_file
reload(kid_readout.utils.data_file)
# Out:
# <module 'kid_readout.utils.data_file' from '/home/gjones/workspace/kid_readout/utils/data_file.py'>

# %%
kid_readout.utils.data_file.__file__
# Out:
# '/home/gjones/workspace/kid_readout/utils/data_file.py'

# %%
# !cd /home/gjones/workspace/kid_readout/utils/; git log -1
# Out:
# commit 26aa8e7be63f1be02df591250b4b88ee886f959a
# Author: gitj <glenn.caltech@gmail.com>
# Date:   Mon Dec 23 10:24:06 2013 -0500
#
#     use bifurcation model

# %%
# !pwd
# Out:
# /home/gjones

# %%
df = kid_readout.utils.data_file.DataFile()

# %%
print df.nc.gitinfo
# Out:
# commit 26aa8e7be63f1be02df591250b4b88ee886f959a
# Author: gitj <glenn.caltech@gmail.com>
# Date:   Mon Dec 23 10:24:06 2013 -0500
#
#     use bifurcation model
