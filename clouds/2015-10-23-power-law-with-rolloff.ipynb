# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def roll_off(x,fc,beta):
    return 1/(1+(x/fc)**beta)

# %%
def power_law(x,scale,alpha):
    return (x/scale)**alpha

# %%
def model(x,red_scale,red_exp,roll_fc,roll_exp,white_noise):
    return power_law(x,red_scale,red_exp)*roll_off(x,roll_fc,roll_exp) + white_noise

# %%
x = np.logspace(-3,3,1000)

# %%
for k in range(10):
    loglog(x,roll_off(x,10.0,1.0*k))

# %%
loglog(x,model(x,red_scale=0.5,red_exp=-1,roll_fc=.1,roll_exp=2,white_noise=1e-1))
