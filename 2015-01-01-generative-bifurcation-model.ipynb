# %%
np.atleast_1d(1)
# Out:
# array([1])

# %%
run /Users/gjones/kid_readout/kid_readout/analysis/generative_bifurcation_model.py

# %%
p = make_physical_bifurcation_model()

# %%
freq = np.linspace(99.98,100.02,100)*1e6
power = 10**(np.linspace(-120,-100,5)/10 - 3)
all_freq,all_powers = np.broadcast_arrays(freq[None,:],power[:,None])

# %%
all_freq.shape
# Out:
# (5L, 100L)

# %%
all_powers[2,0]
# Out:
# 1e-14

# %%
s21 = physical_bifurcation_model(p,all_freq.flatten(),all_powers.flatten())
s21.shape = all_freq.shape

# %%
s21.shape
# Out:
# (5L, 100L)

# %%
for k in range(5):
    plot(all_freq[k],abs(s21[k]),'.-',label=('%f' % (10*np.log10(power[k])+30)))
legend()

# %%
plot(abs(s21.flatten()))
