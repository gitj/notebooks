# %%
d1 = np.load('/home/data2/rtl/2014-09-29_10-56-06.npz')

# %%
get_time_constant_from_file('/home/data2/rtl/2014-09-29_10-56-06.npz',debug=True)
# Out:
# 3077 2946 0.678756476684
# initial guess:
#  Parameters([('tau', <Parameter 'tau', 9.9990234375000009e-05, bounds=[0:0.099990234375000014]>), ('amp', <Parameter 'amp', 0.045730200120595574, bounds=[-0.049161825064819017:0.049161825064819017]>), ('offset', <Parameter 'offset', 0.059909238419418073, bounds=[0.0073157884103756121:0.15480126360483265]>), ('t_on', <Parameter 't_on', 0.0028681640624999998, bounds=[0.0:0.0099990234375000007]>), ('t_rise', <Parameter 't_rise', 9.9990234375000015e-06, bounds=[0:0.099990234375000014]>)])
# (5.6756406002706501e-05, <kid_readout.analysis.fitter.Fitter at 0x9606190>)

# %%
d1.keys()
# Out:
# ['center_freq',
#  'start_time',
#  'time',
#  'sample_rate',
#  'gain',
#  'sweep_freq',
#  'data',
#  'sweep_mag']

# %%
plot(d1['sweep_freq'],10*np.log10(d1['sweep_mag']))

# %%
d = d1['data']

# %%
d.shape
# Out:
# (2097152,)

# %%
import kid_readout.analysis.iqnoise

# %%
fr,S,evals,evects,angles,piq = kid_readout.analysis.iqnoise.pca_noise(d,Fs=d1['sample_rate'])
# Out:
# using NFFT: 2** 18.0
# 10

# %%
run /home/gjones/kid_readout/kid_readout/analysis/time_constant_from_rtl.py

# %%
demod = kid_readout.analysis.demodulate_rtl.demodulate(d,debug=True)

# %%
psd(demod,Fs=d1['sample_rate'],NFFT=2**16)
xscale('symlog')

# %%
fr,S,evals,evects,angles,piq = kid_readout.analysis.iqnoise.pca_noise(demod[2**20:],Fs=d1['sample_rate'],use_log_bins=False)
# Out:
# using NFFT: 2** 17.0

# %%
kid_readout.analysis.iqnoise.pca_noise?

# %%
loglog(fr,evals[1,:])

# %%
1/10e-3
# Out:
# 100.0

# %%
plot(fr,np.mod(angles[1,:]+0*np.pi,np.pi),'.-')
xlim(0,200)
# Out:
# (0, 200)

# %%
len(out)
# Out:
# 6

# %%
kid_readout.analysis.iqnoise??

# %%
plot(abs(demod)[4000:16000])

# %%
10e-3*d1['sample_rate']
# Out:
# 10240.0

# %%
folded = kid_readout.analysis.demodulate_rtl.fold(demod,10240)
# Out:
# 3077 2946 0.678756476684

# %%
folded.shape
# Out:
# (203, 10240)

# %%
plot(np.imag(folded).mean(0))
plot(np.real(folded).mean(0)-0.06)
plot(np.abs(folded).mean(0)-0.06)
xlim(2000,4000)
# Out:
# (2000, 4000)

# %%
rotd = (folded.mean(0)-folded.mean(0)[-1000:].mean())*np.exp(1j*np.pi*.1)

# %%
plot(rotd.real,rotd.imag,'.')

# %%
plot(rotd.imag)
plot(rotd.real)
plot((np.abs(folded).mean(0)-0.06)*1.5)
xlim(2000,4000)
# Out:
# (2000, 4000)

# %%
p = np.polyfit(folded.mean(0).real,folded.mean(0).imag,1)
np.arctan(p[0])/np.pi
# Out:
# 0.37557222137705937

# %%
np.polyfit?

# %%
f2 = folded.mean(0)
f2 = f2 - f2[-1000:].mean()

# %%
plot(f2.real,f2.imag,'.')
p = np.polyfit(f2.real[2000:4000],f2.imag[2000:4000],1)
print p
print np.arctan(p[0])/np.pi
plot(f2.real,np.polyval(p,f2.real))
# Out:
# [  2.95539043e+00   4.24458609e-04]
# 0.396144399643

# %%
f3 = f2*np.exp(-1j*np.arctan(p[0]))
plot(f3.real,f3.imag,'.')

# %%
plot(f3.real)
