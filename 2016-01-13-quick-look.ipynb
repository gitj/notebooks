# %%
import sys
sys.path.append('/home/gjones/kid_readout')

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import kid_readout.analysis.noise_measurement
# Out:
# no data directory set up for clouds defaulting to /data
# updated file list
# /home/gjones/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:1350: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
snms = kid_readout.analysis.noise_measurement.load_noise_pkl('/artemis/readout/pkl/2016-01-13_235307_sweep_and_stream.pkl')

# %%
snm = snms[2]

# %%
blah = snm.plot()
# Out:
# /home/gjones/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-ec317bb9f5f2> in <module>()
# ----> 1 blah = snm.plot()
#
# /home/gjones/kid_readout/kid_readout/analysis/noise_measurement.pyc in plot(self, fig, title)
#     657         vread = np.sqrt(50*10**(self.power_dbm/10.0)*1e-3)
#     658         alpha = 1.0
# --> 659         Qe = abs(params['Q_e_real'].value+1j*params['Q_e_imag'].value)
#     660         f0_dVdf = 4*vread*alpha*params['Q'].value**2/Qe
#     661         expected_amp_noise = (amp_noise_voltsrthz/f0_dVdf)**2
#
# KeyError: 'Q_e_real'

# %%
import kid_readout.utils.readoutnc

# %%
rnc = kid_readout.utils.readoutnc.ReadoutNetCDF('/artemis/readout/2016-01-13_232859_sweep_and_stream.nc')

# %%
swp = rnc.sweeps[3]

# %%
fr,s21,err = swp.select_by_index(0)

# %%
plot(fr,np.abs(s21))

# %%
len(snms)
# Out:
# 64

# %%
fig,axs = subplots(4,4,figsize=(18,12))
for k in range(16):
    ax = axs.flatten()[k]
    snm  = snms[k+16*3]
    ax.loglog(snm.pca_freq,snm.pca_eigvals[1,:]-snm.pca_eigvals[0,:])
#    fr,s21,err = swp.select_by_index(k)
#    ax.plot(fr,20*np.log10(np.abs(s21)))

# %%
1/(2*np.pi*5e3)
# Out:
# 3.183098861837907e-05
