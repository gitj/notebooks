# %%
import kid_readout.analysis.archive
# Out:
# updated file list
# /home/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
df = kid_readout.analysis.archive.load_archive('/home/gjones/detmnt/archive/2015-01-14_145435_continous_cooling.npy')

# %%
df.shape
# Out:
# (672, 88)

# %%
df = df[(df.Q_err/df.Q < 1)]
df = df[df.Q > 1000]
df = df[df.f_0_err/(df.f_0/df.Q) < 1e-1]
r0 = df[df.resonator_id == 0]
r1 = df[df.resonator_id ==1]

# %%
semilogy(df.Q_err/df.Q,'.')

# %%
semilogy(df.f_0_err/(df.f_0),'.')

# %%
plot(r1.sweep_primary_load_temperature,r1.f_0,'.')

# %%
loglog(r1.sweep_primary_load_temperature,1-r1.f_0/(r1.f_0.max()+0.1),'.')
loglog(r1.sweep_primary_load_temperature,1e-5*(r1.sweep_primary_load_temperature)**2)
lda = 1/np.sqrt(1-(r1.sweep_primary_load_temperature/83.)**4)
plot(r1.sweep_primary_load_temperature,(lda-1),'.')

# %%
import kid_readout.analysis.noise_measurement

# %%
import kid_readout.utils.readoutnc

# %%
rnc = kid_readout.utils.readoutnc.ReadoutNetCDF('/home/gjones/detmnt/2015-01-16_151414_led.nc')

# %%
len(rnc.sweeps)
# Out:
# 2

# %%
len(rnc.timestreams)
# Out:
# 3

# %%
fn = '/home/gjones/detmnt/2015-01-16_151414_led.nc'
nm = kid_readout.analysis.noise_measurement.SweepNoiseMeasurement(fn,
                                                                  sweep_group_index=0,timestream_group_index=1,resonator_index=1)
# Out:
# using NFFT: 2** 16.0
# 10

# %%
nmoff = kid_readout.analysis.noise_measurement.SweepNoiseMeasurement(fn,
                                                                  sweep_group_index=1,timestream_group_index=2,resonator_index=1)
# Out:
# using NFFT: 2** 16.0
# 10

# %%
nmon = kid_readout.analysis.noise_measurement.SweepNoiseMeasurement(fn,
                                                                  sweep_group_index=1,timestream_group_index=0,resonator_index=1)
# Out:
# using NFFT: 2** 16.0
# 10

# %%
loglog(nmoff.pca_freq,nmoff.pca_eigvals[1,:])
loglog(nmon.pca_freq,nmon.pca_eigvals[1,:])
loglog(nm.pca_freq,nm.pca_eigvals[1,:])

# %%
loglog(nmon.pca_freq,nmon.pca_eigvals[1,:])
loglog(nmon.pca_freq,nmon.pca_eigvals[0,:])

# %%
blah = nm.plot()

# %%
ff = nm.fractional_fluctuation_timeseries

# %%
ff.shape
# Out:
# (524288,)

# %%
nm.timestream_modulation_freq
# Out:
# 122.0703125

# %%
128*_
# Out:
# 15625.0

# %%
folded = ff.reshape((-1,256))

# %%
blah = psd(ff,NFFT=2**15,Fs=256e6/2**14)
xscale('symlog')

# %%
nm.atten
# Out:
# 33.0

# %%
plot(imag(ff)[::100])

# %%
imshow(imag(folded-folded.mean(1)[:,None]),aspect='auto')

# %%
plot(imag(ff))
xlim(0,1000)
# Out:
# (0, 1000)

# %%
plot(imag(folded.mean(0)))

# %%
plot(ff.real)

# %%
plot(ff.imag)
